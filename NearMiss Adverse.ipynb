# %%
import warnings
warnings.filterwarnings('ignore')
import os
import csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')
import os
import csv
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
from sklearn.metrics import auc,roc_auc_score,roc_curve,precision_score,recall_score,f1_score
import time as timer
from sklearn.inspection import permutation_importance
import itertools
import seaborn as sns
from sklearn.svm import LinearSVC,SVC
from sklearn.multiclass import OneVsRestClassifier
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LassoCV,LogisticRegression,SGDClassifier
from sklearn.naive_bayes import GaussianNB,BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,BaggingClassifier,AdaBoostClassifier,GradientBoostingClassifier,VotingClassifier,StackingClassifier
from sklearn.feature_selection import chi2,SelectKBest,SelectFromModel,RFE,VarianceThreshold
from sklearn.metrics import confusion_matrix,precision_recall_curve,average_precision_score,roc_curve,auc,f1_score,accuracy_score,\
classification_report,multilabel_confusion_matrix, roc_auc_score,precision_recall_fscore_support
from sklearn.model_selection import cross_val_score,train_test_split,StratifiedKFold,GridSearchCV
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler,LabelEncoder,LabelBinarizer
from scipy import interp
from itertools import cycle
plt.style.use('ggplot');
import sys
if ("/your/path/to/xelatex") not in sys.path:
    print('adding path') # I just add this to know if the path was present or not.
    sys.path.append("/your/path/to/xelatex")
# Out:
# adding path

# %%
from sklearn.metrics import precision_recall_curve
from imblearn.over_sampling import SMOTE

# %%
data = pd.read_csv('data_adverse_imputed.csv')
data
# Out:
#         Residence  Mother_education  Sex_of_HH  mobile_phone  deliver_by_CS  \
# 0               2                 0          1             0              1
# 1               1                 1          2             0              0
# 2               1                 0          2             0              0
# 3               1                 0          2             0              0
# 4               1                 1          2             0              0
# ...           ...               ...        ...           ...            ...
# 139654          2                 2          1             0              0
# 139655          2                 1          1             0              0
# 139656          2                 2          1             1              0
# 139657          2                 1          2             1              0
# 139658          2                 1          2             1              0
#
#         Smoke  Distance_to_HF  Working_status  sex_of_child  Age_of_mother  \
# 0           0               1               1             1              4
# 1           0               1               1             1              2
# 2           0               1               0             2              3
# 3           0               1               0             1              3
# 4           0               1               1             1              3
# ...       ...             ...             ...           ...            ...
# 139654      0               1               0             1              1
# 139655      0               1               0             2              3
# 139656      0               1               1             1              3
# 139657      0               1               1             2              2
# 139658      0               1               0             2              4
#
#         ...  Iron_supplementation  Type_of_pregnancy  ANC_visits  \
# 0       ...                     0                  0           0
# 1       ...                     0                  0           2
# 2       ...                     0                  0           2
# 3       ...                     0                  0           1
# 4       ...                     1                  0           0
# ...     ...                   ...                ...         ...
# 139654  ...                     1                  0           2
# 139655  ...                     1                  0           2
# 139656  ...                     1                  0           1
# 139657  ...                     1                  0           2
# 139658  ...                     0                  0           1
#
#         Birth_interval  Wanted_pregnancy  First_ANC_check  Place_of_delivery  \
# 0                    1                 1                0                  1
# 1                    1                 1                1                  1
# 2                    1                 1                1                  1
# 3                    0                 1                0                  0
# 4                    1                 1                0                  0
# ...                ...               ...              ...                ...
# 139654               1                 1                1                  1
# 139655               2                 1                0                  0
# 139656               2                 1                0                  1
# 139657               1                 1                1                  1
# 139658               1                 1                0                  1
#
#         Media_exposure  Regions  adverse_birth_outcome
# 0                    0        1                      0
# 1                    0        1                      1
# 2                    0        1                      1
# 3                    0        1                      1
# 4                    0        1                      0
# ...                ...      ...                    ...
# 139654               0        3                      0
# 139655               1        3                      0
# 139656               1        3                      0
# 139657               1        3                      0
# 139658               0        3                      0
#
# [139659 rows x 26 columns]

# %%
# "data" is the DataFrame
data.drop('Smoke', axis=1, inplace=True)
data.drop('Number_of_children', axis=1, inplace=True)

# %%
##Data Preprocessing/Feauture selection
X = data.drop('adverse_birth_outcome',axis=1)
y = data.adverse_birth_outcome
num_features_opt = 40   # the number of features that we need to choose as a result
num_features_max = 60   # the somewhat excessive number of features, which we will choose at each stage
features_best = []

# %%
from imblearn.under_sampling import NearMiss

# Create an instance of NearMiss
near_miss = NearMiss()

# Resample the data using NearMiss
X_resampled, y_resampled = near_miss.fit_resample(data.loc[:, data.columns != 'adverse_birth_outcome'], data['adverse_birth_outcome'])

# Print the shape of the resampled data
print("Shape of X_resampled: {}".format(X_resampled.shape))
print("Shape of y_resampled: {}".format(y_resampled.shape))
# Out:
# Shape of X_resampled: (89670, 23)
# Shape of y_resampled: (89670,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split
import numpy as np

def split_train_valid_test(X, y, test_size=0.2, random_state=None):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state, stratify=y)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=test_size/(1-test_size), random_state=random_state, stratify=y_train)
    return X_train, X_valid, X_test, y_train, y_valid, y_test

# Usage example
X_train_resampled, X_valid_resampled, X_test_resampled, y_train_resampled, y_valid_resampled, y_test_resampled = split_train_valid_test(X_resampled, y_resampled, test_size=0.3, random_state=42)
_, train_counts = np.unique(y_train_resampled, return_counts=True)
_, valid_counts = np.unique(y_valid_resampled, return_counts=True)
_, test_counts = np.unique(y_test_resampled, return_counts=True)
print("[train] # class 0: {} | # class 1: {}".format(train_counts[0], train_counts[1]))
print("[valid] # class 0: {} | # class 1: {}".format(valid_counts[0], valid_counts[1]))
print("[test]  # class 0: {} | # class 1: {}".format(test_counts[0], test_counts[1]))
# Out:
# [train] # class 0: 17933 | # class 1: 17934
# [valid] # class 0: 13451 | # class 1: 13451
# [test]  # class 0: 13451 | # class 1: 13450

# %%
# Scaling code
scaler = StandardScaler()
scaler = scaler.fit(X_train_resampled)

X_train_resampled_std = scaler.transform(X_train_resampled)
X_valid_resampled_std = scaler.transform(X_valid_resampled)
X_test_resampled_std = scaler.transform(X_test_resampled)

# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit

# %%
def calc_sens_spec(y_true,y_pred):
    conf_matrix = confusion_matrix(y_true,y_pred)
    TP = conf_matrix[1][1]
    TN = conf_matrix[0][0]
    FP = conf_matrix[0][1]
    FN = conf_matrix[1][0]
    # calculate the sensitivity
    sensitivity = TP / (TP + FN)    
    # calculate the specificity
    specificity = TN / (TN + FP)
    return sensitivity,specificity
from sklearn import metrics
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
import time as timer
## SVM
start = timer.time()
svm_model = SVC(kernel='rbf',probability=True)
svm_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_svm = svm_model.predict(X_test_resampled_std)
y_svm_prob = svm_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 960.92 seconds

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
from sklearn.metrics import auc,roc_auc_score,roc_curve,precision_score,recall_score,f1_score

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for SVM:\n{}".format(classification_report(y_test_resampled, y_svm)))

# Print confusion matrix
print("Confusion matrix for SVM:\n{}".format(confusion_matrix(y_test_resampled, y_svm)))

# Calculate and print accuracy score
accuracy_score_svm = accuracy_score(y_test_resampled, y_svm)
print("Accuracy score for SVM: {:.2f}".format(accuracy_score_svm))

# Calculate precision, recall, and f1 scores
prec_svm = precision_score(y_test_resampled, y_svm)
rec_svm = recall_score(y_test_resampled, y_svm)
f1_svm = f1_score(y_test_resampled, y_svm)
print("Precision score for SVM: {:.2f}".format(prec_svm))
print("Recall score for SVM: {:.2f}".format(rec_svm))
print("F1 score for SVM: {:.2f}".format(f1_svm))

# Calculate sensitivity, specificity, and AUC
sens_svm, spec_svm = calc_sens_spec(y_test_resampled, y_svm)
fpr, tpr, _ = roc_curve(y_test_resampled, y_svm_prob[:, 1])
auc_svm = roc_auc_score(y_test_resampled, y_svm_prob[:, 1])
print("Sensitivity score for SVM: {:.2f}".format(sens_svm))
print("Specificity score for SVM: {:.2f}".format(spec_svm))
print("AUC score for SVM: {:.2f}".format(auc_svm))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_svm)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (SVM)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for SVM:
#               precision    recall  f1-score   support
#
#            0       0.67      0.83      0.74     13451
#            1       0.78      0.59      0.67     13450
#
#     accuracy                           0.71     26901
#    macro avg       0.72      0.71      0.70     26901
# weighted avg       0.72      0.71      0.70     26901
#
# Confusion matrix for SVM:
# [[11188  2263]
#  [ 5570  7880]]
# Accuracy score for SVM: 0.71
# Precision score for SVM: 0.78
# Recall score for SVM: 0.59
# F1 score for SVM: 0.67
# Sensitivity score for SVM: 0.59
# Specificity score for SVM: 0.83
# AUC score for SVM: 0.77

# %%
##Logistic Regression (LR)
start = timer.time()
logit_model = LogisticRegression(solver='lbfgs', random_state=42)
logit_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_logit = logit_model.predict(X_test_resampled_std)
y_logit_prob = logit_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 0.16 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for LR:\n{}".format(classification_report(y_test_resampled, y_logit)))

# Print confusion matrix
print("Confusion matrix for LR:\n{}".format(confusion_matrix(y_test_resampled, y_logit)))

# Calculate and print accuracy score
accuracy_score_lr = accuracy_score(y_test_resampled, y_logit)
print("Accuracy score for LR: {:.2f}".format(accuracy_score_lr))

# Calculate precision, recall, and f1 scores
prec_lr = precision_score(y_test_resampled, y_logit)
rec_lr = recall_score(y_test_resampled, y_logit)
f1_lr = f1_score(y_test_resampled, y_logit)
print("Precision score for LR: {:.2f}".format(prec_lr))
print("Recall score for LR: {:.2f}".format(rec_lr))
print("F1 score for LR: {:.2f}".format(f1_lr))

# Calculate sensitivity, specificity, and AUC
sens_lr, spec_lr = calc_sens_spec(y_test_resampled, y_logit)
fpr, tpr, _ = roc_curve(y_test_resampled, y_logit_prob[:, 1])
auc_lr = roc_auc_score(y_test_resampled, y_logit_prob[:, 1])
print("Sensitivity score for LR: {:.2f}".format(sens_lr))
print("Specificity score for LR: {:.2f}".format(spec_lr))
print("AUC score for LR: {:.2f}".format(auc_lr))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_lr)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (LR)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for LR:
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.70     13451
#            1       0.71      0.58      0.64     13450
#
#     accuracy                           0.67     26901
#    macro avg       0.68      0.67      0.67     26901
# weighted avg       0.68      0.67      0.67     26901
#
# Confusion matrix for LR:
# [[10275  3176]
#  [ 5697  7753]]
# Accuracy score for LR: 0.67
# Precision score for LR: 0.71
# Recall score for LR: 0.58
# F1 score for LR: 0.64
# Sensitivity score for LR: 0.58
# Specificity score for LR: 0.76
# AUC score for LR: 0.72

# %%
## Gaussian Naive Bayes (GNB)
start = timer.time()
gnb_model = GaussianNB()
gnb_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_gnb = gnb_model.predict(X_test_resampled_std)
y_gnb_prob = gnb_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 0.03 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for GNB:\n{}".format(classification_report(y_test_resampled, y_gnb)))

# Print confusion matrix
print("Confusion matrix for GNB:\n{}".format(confusion_matrix(y_test_resampled, y_gnb)))

# Calculate and print accuracy score
accuracy_score_gnb = accuracy_score(y_test_resampled, y_gnb)
print("Accuracy score for GNB: {:.2f}".format(accuracy_score_gnb))

# Calculate precision, recall, and f1 scores
prec_gnb = precision_score(y_test_resampled, y_gnb)
rec_gnb = recall_score(y_test_resampled, y_gnb)
f1_gnb = f1_score(y_test_resampled, y_gnb)
print("Precision score for GNB: {:.2f}".format(prec_gnb))
print("Recall score for GNB: {:.2f}".format(rec_gnb))
print("F1 score for GNB: {:.2f}".format(f1_gnb))

# Calculate sensitivity, specificity, and AUC
sens_gnb, spec_gnb = calc_sens_spec(y_test_resampled, y_gnb)
fpr, tpr, _ = roc_curve(y_test_resampled, y_gnb_prob[:, 1])
auc_gnb = roc_auc_score(y_test_resampled, y_gnb_prob[:, 1])
print("Sensitivity score for GNB: {:.2f}".format(sens_gnb))
print("Specificity score for GNB: {:.2f}".format(spec_gnb))
print("AUC score for GNB: {:.2f}".format(auc_gnb))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_gnb)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (GNB)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for GNB:
#               precision    recall  f1-score   support
#
#            0       0.60      0.86      0.71     13451
#            1       0.76      0.43      0.55     13450
#
#     accuracy                           0.65     26901
#    macro avg       0.68      0.65      0.63     26901
# weighted avg       0.68      0.65      0.63     26901
#
# Confusion matrix for GNB:
# [[11635  1816]
#  [ 7653  5797]]
# Accuracy score for GNB: 0.65
# Precision score for GNB: 0.76
# Recall score for GNB: 0.43
# F1 score for GNB: 0.55
# Sensitivity score for GNB: 0.43
# Specificity score for GNB: 0.86
# AUC score for GNB: 0.72

# %%
from sklearn.tree import DecisionTreeClassifier
##  DT
start = timer.time()
dtree_model = DecisionTreeClassifier(random_state=42)
dtree_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_dtree = dtree_model.predict(X_test_resampled_std)
y_dtree_prob = dtree_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 0.43 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for DT:\n{}".format(classification_report(y_test_resampled, y_dtree)))

# Print confusion matrix
print("Confusion matrix for DT:\n{}".format(confusion_matrix(y_test_resampled, y_dtree)))

# Calculate and print accuracy score
accuracy_score_dtree = accuracy_score(y_test_resampled, y_dtree)
print("Accuracy score for DT: {:.2f}".format(accuracy_score_dtree))

# Calculate precision, recall, and f1 scores
prec_dtree = precision_score(y_test_resampled, y_dtree)
rec_dtree = recall_score(y_test_resampled, y_dtree)
f1_dtree = f1_score(y_test_resampled, y_dtree)
print("Precision score for DT: {:.2f}".format(prec_dtree))
print("Recall score for DT: {:.2f}".format(rec_dtree))
print("F1 score for DT: {:.2f}".format(f1_dtree))

# Calculate sensitivity, specificity, and AUC
sens_dtree, spec_dtree = calc_sens_spec(y_test_resampled, y_dtree)
fpr, tpr, _ = roc_curve(y_test_resampled, y_dtree_prob[:, 1])
auc_dtree = roc_auc_score(y_test_resampled, y_dtree_prob[:, 1])
print("Sensitivity score for DT: {:.2f}".format(sens_dtree))
print("Specificity score for DT: {:.2f}".format(spec_dtree))
print("AUC score for DT: {:.2f}".format(auc_dtree))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_dtree)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (DT)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for DT:
#               precision    recall  f1-score   support
#
#            0       0.61      0.66      0.63     13451
#            1       0.63      0.57      0.60     13450
#
#     accuracy                           0.61     26901
#    macro avg       0.62      0.61      0.61     26901
# weighted avg       0.62      0.61      0.61     26901
#
# Confusion matrix for DT:
# [[8867 4584]
#  [5773 7677]]
# Accuracy score for DT: 0.61
# Precision score for DT: 0.63
# Recall score for DT: 0.57
# F1 score for DT: 0.60
# Sensitivity score for DT: 0.57
# Specificity score for DT: 0.66
# AUC score for DT: 0.61

# %%
## RF
start = timer.time()
ranfor_model = RandomForestClassifier(n_estimators=100, random_state=42)
ranfor_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_ranfor = ranfor_model.predict(X_test_resampled_std)
y_ranfor_prob = ranfor_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 7.40 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for RF:\n{}".format(classification_report(y_test_resampled, y_ranfor)))

# Print confusion matrix
print("Confusion matrix for RF:\n{}".format(confusion_matrix(y_test_resampled, y_ranfor)))

# Calculate and print accuracy score
accuracy_score_ranfor = accuracy_score(y_test_resampled, y_ranfor)
print("Accuracy score for RF: {:.2f}".format(accuracy_score_ranfor))

# Calculate precision, recall, and f1 scores
prec_ranfor = precision_score(y_test_resampled, y_ranfor)
rec_ranfor = recall_score(y_test_resampled, y_ranfor)
f1_ranfor = f1_score(y_test_resampled, y_ranfor)
print("Precision score for RF: {:.2f}".format(prec_ranfor))
print("Recall score for RF: {:.2f}".format(rec_ranfor))
print("F1 score for RF: {:.2f}".format(f1_ranfor))

# Calculate sensitivity, specificity, and AUC
sens_ranfor, spec_ranfor = calc_sens_spec(y_test_resampled, y_ranfor)
fpr, tpr, _ = roc_curve(y_test_resampled, y_ranfor_prob[:, 1])
auc_ranfor = roc_auc_score(y_test_resampled, y_ranfor_prob[:, 1])
print("Sensitivity score for RF: {:.2f}".format(sens_ranfor))
print("Specificity score for RF: {:.2f}".format(spec_ranfor))
print("AUC score for RF: {:.2f}".format(auc_ranfor))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_ranfor)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (RF)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for RF:
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67     13451
#            1       0.67      0.62      0.65     13450
#
#     accuracy                           0.66     26901
#    macro avg       0.66      0.66      0.66     26901
# weighted avg       0.66      0.66      0.66     26901
#
# Confusion matrix for RF:
# [[9406 4045]
#  [5094 8356]]
# Accuracy score for RF: 0.66
# Precision score for RF: 0.67
# Recall score for RF: 0.62
# F1 score for RF: 0.65
# Sensitivity score for RF: 0.62
# Specificity score for RF: 0.70
# AUC score for RF: 0.72

# %%
start = timer.time()
xgb_model = XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_xgb = xgb_model.predict(X_test_resampled_std)
y_xgb_prob = xgb_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 0.67 seconds

# %%
print("Classification report for XGB: \n{}".format(classification_report(y_test_resampled,y_xgb)))
print("Confusion matrix for XGB: \n{}".format(confusion_matrix(y_test_resampled,y_xgb)))
# Calculate and print accuracy score
accuracy_score_xgb = accuracy_score(y_test_resampled, y_xgb)
print("Accuracy score for xgb: {:.2f}".format(accuracy_score_xgb))
# calculate precision, recall, and f1 scores
prec_xgb = precision_score(y_test_resampled,y_xgb)
rec_xgb = recall_score(y_test_resampled,y_xgb)
f1_xgb = f1_score(y_test_resampled,y_xgb)
print("Precision score for XGB: {:.2f}".format(prec_xgb))
print("Recall score for XGB: {:.2f}".format(rec_xgb))
print("F1 score for XGB: {:.2f}".format(f1_xgb))
# calculate sensitivity, specificity, and auc
sens_xgb,spec_xgb = calc_sens_spec(y_test_resampled,y_xgb)
fpr, tpr, _ = roc_curve(y_test_resampled, y_xgb_prob[:,1])
auc_xgb = roc_auc_score(y_test_resampled, y_xgb_prob[:,1])
print("Sensitivity score for XGB: {:.2f}".format(sens_xgb))
print("Specitivity score for XGB: {:.2f}".format(spec_xgb))
print("AUC score for XGB: {:.2f}".format(auc_xgb))
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_xgb)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (XGB)')
ax.legend(loc="lower right")
ax= plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for XGB:
#               precision    recall  f1-score   support
#
#            0       0.68      0.82      0.75     13451
#            1       0.78      0.62      0.69     13450
#
#     accuracy                           0.72     26901
#    macro avg       0.73      0.72      0.72     26901
# weighted avg       0.73      0.72      0.72     26901
#
# Confusion matrix for XGB:
# [[11046  2405]
#  [ 5119  8331]]
# Accuracy score for xgb: 0.72
# Precision score for XGB: 0.78
# Recall score for XGB: 0.62
# F1 score for XGB: 0.69
# Sensitivity score for XGB: 0.62
# Specitivity score for XGB: 0.82
# AUC score for XGB: 0.78

# %%
from sklearn.neighbors import KNeighborsClassifier
## KNN
start = timer.time()
knn_model = KNeighborsClassifier(n_neighbors=15)
knn_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_knn = knn_model.predict(X_test_resampled_std)
y_knn_prob = knn_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 0.01 seconds

# %%
print("Classification report for knn: \n{}".format(classification_report(y_test_resampled,y_knn)))
print("Confusion matrix for knn: \n{}".format(confusion_matrix(y_test_resampled,y_knn)))
# Calculate and print accuracy score
accuracy_score_knn = accuracy_score(y_test_resampled, y_knn)
print("Accuracy score for knn: {:.2f}".format(accuracy_score_knn))
# calculate precision, recall, and f1 scores
prec_knn = precision_score(y_test_resampled,y_knn)
rec_knn = recall_score(y_test_resampled,y_knn)
f1_knn = f1_score(y_test_resampled,y_knn)
print("Precision score for knn: {:.2f}".format(prec_knn))
print("Recall score for knn: {:.2f}".format(rec_knn))
print("F1 score for knn: {:.2f}".format(f1_knn))
# calculate sensitivity, specificity, and auc
sens_knn,spec_knn = calc_sens_spec(y_test_resampled,y_knn)
fpr, tpr, _ = roc_curve(y_test_resampled,  y_knn_prob[:,1])
auc_knn = roc_auc_score(y_test_resampled, y_knn_prob[:,1])
print("Sensitivity score for knn: {:.2f}".format(sens_knn))
print("Specitivity score for knn: {:.2f}".format(spec_knn))
print("AUC score for knn: {:.2f}".format(auc_knn))
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_knn)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (knn)')
ax.legend(loc="lower right")
ax= plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for knn:
#               precision    recall  f1-score   support
#
#            0       0.61      0.85      0.71     13451
#            1       0.76      0.46      0.57     13450
#
#     accuracy                           0.66     26901
#    macro avg       0.68      0.66      0.64     26901
# weighted avg       0.68      0.66      0.64     26901
#
# Confusion matrix for knn:
# [[11474  1977]
#  [ 7280  6170]]
# Accuracy score for knn: 0.66
# Precision score for knn: 0.76
# Recall score for knn: 0.46
# F1 score for knn: 0.57
# Sensitivity score for knn: 0.46
# Specitivity score for knn: 0.85
# AUC score for knn: 0.70

# %%
from sklearn.ensemble import AdaBoostClassifier
import time

# Create an instance of the AdaBoostClassifier model
adaboost_model = AdaBoostClassifier(n_estimators=50, random_state=42)

# Start the timer to measure the training time
start = time.time()

# Fit the AdaBoost model to the training data
adaboost_model.fit(X_train_resampled_std, y_train_resampled)

# Stop the timer and calculate the training time
end = time.time()
print("Finished training within {:.2f} seconds".format(end - start))

# Predict the labels for the test set using the trained AdaBoost model
y_adaboost = adaboost_model.predict(X_test_resampled_std)

# Predict the class probabilities for the test set using the trained AdaBoost model
y_adaboost_prob = adaboost_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 2.92 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Classification report
print("Classification report for AdaBoost:\n{}".format(classification_report(y_test_resampled, y_adaboost)))

# Confusion matrix
print("Confusion matrix for AdaBoost:\n{}".format(confusion_matrix(y_test_resampled, y_adaboost)))

# Calculate and print accuracy score
accuracy_score_adaboost = accuracy_score(y_test_resampled, y_adaboost)
print("Accuracy score for AdaBoost: {:.2f}".format(accuracy_score_adaboost))

# Precision, recall, and F1 scores
prec_adaboost = precision_score(y_test_resampled, y_adaboost)
rec_adaboost = recall_score(y_test_resampled, y_adaboost)
f1_adaboost = f1_score(y_test_resampled, y_adaboost)
print("Precision score for AdaBoost: {:.2f}".format(prec_adaboost))
print("Recall score for AdaBoost: {:.2f}".format(rec_adaboost))
print("F1 score for AdaBoost: {:.2f}".format(f1_adaboost))

# Calculate sensitivity, specificity, and AUC
def calc_sens_spec(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sens_adaboost, spec_adaboost = calc_sens_spec(y_test_resampled, y_adaboost)
print("Sensitivity score for AdaBoost: {:.2f}".format(sens_adaboost))
print("Specificity score for AdaBoost: {:.2f}".format(spec_adaboost))

# Calculate the false positive rate, true positive rate, and AUC
fpr, tpr, _ = roc_curve(y_test_resampled, y_adaboost_prob[:, 1])
auc_adaboost = roc_auc_score(y_test_resampled, y_adaboost_prob[:, 1])
print("AUC score for AdaBoost: {:.2f}".format(auc_adaboost))

# Plot the ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_adaboost)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (AdaBoost)')
ax.legend(loc="lower right")
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for AdaBoost:
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.71     13451
#            1       0.73      0.61      0.66     13450
#
#     accuracy                           0.69     26901
#    macro avg       0.70      0.69      0.69     26901
# weighted avg       0.70      0.69      0.69     26901
#
# Confusion matrix for AdaBoost:
# [[10388  3063]
#  [ 5230  8220]]
# Accuracy score for AdaBoost: 0.69
# Precision score for AdaBoost: 0.73
# Recall score for AdaBoost: 0.61
# F1 score for AdaBoost: 0.66
# Sensitivity score for AdaBoost: 0.61
# Specificity score for AdaBoost: 0.77
# AUC score for AdaBoost: 0.75

# %%
from catboost import CatBoostClassifier
import time

# CatBoost
start = time.time()
catboost_model = CatBoostClassifier(iterations=100, random_state=42)
catboost_model.fit(X_train_resampled_std, y_train_resampled)
end = time.time()
print("Finished training within {:.2f} seconds".format(end - start))

# Predicting the test set results
y_catboost = catboost_model.predict(X_test_resampled_std)
y_catboost_prob = catboost_model.predict_proba(X_test_resampled_std)
# Out:
# Learning rate set to 0.392454
# 0:	learn: 0.6362857	total: 273ms	remaining: 27.1s
# 1:	learn: 0.6168013	total: 313ms	remaining: 15.3s
# 2:	learn: 0.6035929	total: 351ms	remaining: 11.4s
# 3:	learn: 0.5935232	total: 392ms	remaining: 9.41s
# 4:	learn: 0.5866931	total: 437ms	remaining: 8.3s
# 5:	learn: 0.5805563	total: 481ms	remaining: 7.54s
# 6:	learn: 0.5769295	total: 523ms	remaining: 6.95s
# 7:	learn: 0.5734725	total: 600ms	remaining: 6.9s
# 8:	learn: 0.5691508	total: 651ms	remaining: 6.59s
# 9:	learn: 0.5666185	total: 708ms	remaining: 6.37s
# 10:	learn: 0.5624709	total: 748ms	remaining: 6.05s
# 11:	learn: 0.5596965	total: 776ms	remaining: 5.69s
# 12:	learn: 0.5577298	total: 795ms	remaining: 5.32s
# 13:	learn: 0.5555317	total: 816ms	remaining: 5.01s
# 14:	learn: 0.5527740	total: 844ms	remaining: 4.78s
# 15:	learn: 0.5514114	total: 877ms	remaining: 4.6s
# 16:	learn: 0.5499411	total: 911ms	remaining: 4.45s
# 17:	learn: 0.5485695	total: 939ms	remaining: 4.28s
# 18:	learn: 0.5465527	total: 967ms	remaining: 4.12s
# 19:	learn: 0.5456110	total: 989ms	remaining: 3.96s
# 20:	learn: 0.5450026	total: 1.01s	remaining: 3.79s
# 21:	learn: 0.5431707	total: 1.03s	remaining: 3.65s
# 22:	learn: 0.5418304	total: 1.05s	remaining: 3.52s
# 23:	learn: 0.5411013	total: 1.08s	remaining: 3.43s
# 24:	learn: 0.5399005	total: 1.15s	remaining: 3.45s
# 25:	learn: 0.5383956	total: 1.22s	remaining: 3.46s
# 26:	learn: 0.5370731	total: 1.28s	remaining: 3.46s
# 27:	learn: 0.5367421	total: 1.36s	remaining: 3.49s
# 28:	learn: 0.5353461	total: 1.43s	remaining: 3.5s
# 29:	learn: 0.5337027	total: 1.47s	remaining: 3.44s
# 30:	learn: 0.5327703	total: 1.53s	remaining: 3.41s
# 31:	learn: 0.5318621	total: 1.59s	remaining: 3.38s
# 32:	learn: 0.5310986	total: 1.64s	remaining: 3.33s
# 33:	learn: 0.5299081	total: 1.69s	remaining: 3.28s
# 34:	learn: 0.5292092	total: 1.72s	remaining: 3.19s
# 35:	learn: 0.5283111	total: 1.74s	remaining: 3.09s
# 36:	learn: 0.5274365	total: 1.76s	remaining: 3s
# 37:	learn: 0.5264864	total: 1.78s	remaining: 2.91s
# 38:	learn: 0.5256330	total: 1.8s	remaining: 2.82s
# 39:	learn: 0.5250470	total: 1.82s	remaining: 2.73s
# 40:	learn: 0.5245018	total: 1.85s	remaining: 2.66s
# 41:	learn: 0.5238368	total: 1.87s	remaining: 2.58s
# 42:	learn: 0.5231165	total: 1.89s	remaining: 2.5s
# 43:	learn: 0.5221384	total: 1.96s	remaining: 2.5s
# 44:	learn: 0.5216404	total: 2.02s	remaining: 2.47s
# 45:	learn: 0.5208727	total: 2.14s	remaining: 2.51s
# 46:	learn: 0.5203411	total: 2.19s	remaining: 2.47s
# 47:	learn: 0.5195427	total: 2.21s	remaining: 2.4s
# 48:	learn: 0.5191618	total: 2.23s	remaining: 2.32s
# 49:	learn: 0.5185599	total: 2.25s	remaining: 2.25s
# 50:	learn: 0.5179269	total: 2.27s	remaining: 2.18s
# 51:	learn: 0.5172664	total: 2.29s	remaining: 2.12s
# 52:	learn: 0.5166518	total: 2.33s	remaining: 2.06s
# 53:	learn: 0.5160744	total: 2.35s	remaining: 2s
# 54:	learn: 0.5155634	total: 2.37s	remaining: 1.94s
# 55:	learn: 0.5148323	total: 2.4s	remaining: 1.89s
# 56:	learn: 0.5143283	total: 2.43s	remaining: 1.84s
# 57:	learn: 0.5137242	total: 2.46s	remaining: 1.78s
# 58:	learn: 0.5131954	total: 2.48s	remaining: 1.73s
# 59:	learn: 0.5126267	total: 2.51s	remaining: 1.67s
# 60:	learn: 0.5120514	total: 2.53s	remaining: 1.62s
# 61:	learn: 0.5115096	total: 2.55s	remaining: 1.56s
# 62:	learn: 0.5111041	total: 2.57s	remaining: 1.51s
# 63:	learn: 0.5104997	total: 2.59s	remaining: 1.46s
# 64:	learn: 0.5099682	total: 2.61s	remaining: 1.41s
# 65:	learn: 0.5095493	total: 2.63s	remaining: 1.36s
# 66:	learn: 0.5090742	total: 2.66s	remaining: 1.31s
# 67:	learn: 0.5085719	total: 2.68s	remaining: 1.26s
# 68:	learn: 0.5081976	total: 2.69s	remaining: 1.21s
# 69:	learn: 0.5079260	total: 2.71s	remaining: 1.16s
# 70:	learn: 0.5074994	total: 2.73s	remaining: 1.11s
# 71:	learn: 0.5071380	total: 2.75s	remaining: 1.07s
# 72:	learn: 0.5065815	total: 2.76s	remaining: 1.02s
# 73:	learn: 0.5062106	total: 2.78s	remaining: 976ms
# 74:	learn: 0.5058550	total: 2.79s	remaining: 931ms
# 75:	learn: 0.5053930	total: 2.81s	remaining: 888ms
# 76:	learn: 0.5050055	total: 2.83s	remaining: 845ms
# 77:	learn: 0.5045690	total: 2.85s	remaining: 804ms
# 78:	learn: 0.5040726	total: 2.87s	remaining: 762ms
# 79:	learn: 0.5036909	total: 2.89s	remaining: 722ms
# 80:	learn: 0.5030992	total: 2.9s	remaining: 681ms
# 81:	learn: 0.5026185	total: 2.92s	remaining: 642ms
# 82:	learn: 0.5021973	total: 2.95s	remaining: 604ms
# 83:	learn: 0.5017387	total: 2.97s	remaining: 565ms
# 84:	learn: 0.5012582	total: 2.98s	remaining: 527ms
# 85:	learn: 0.5008441	total: 3s	remaining: 489ms
# 86:	learn: 0.5004465	total: 3.02s	remaining: 451ms
# 87:	learn: 0.5000824	total: 3.04s	remaining: 415ms
# 88:	learn: 0.4996174	total: 3.06s	remaining: 378ms
# 89:	learn: 0.4993742	total: 3.08s	remaining: 342ms
# 90:	learn: 0.4987914	total: 3.1s	remaining: 307ms
# 91:	learn: 0.4983565	total: 3.12s	remaining: 271ms
# 92:	learn: 0.4979634	total: 3.14s	remaining: 236ms
# 93:	learn: 0.4976773	total: 3.15s	remaining: 201ms
# 94:	learn: 0.4973652	total: 3.18s	remaining: 168ms
# 95:	learn: 0.4969889	total: 3.21s	remaining: 134ms
# 96:	learn: 0.4965456	total: 3.24s	remaining: 100ms
# 97:	learn: 0.4961366	total: 3.27s	remaining: 66.7ms
# 98:	learn: 0.4957431	total: 3.29s	remaining: 33.3ms
# 99:	learn: 0.4953825	total: 3.32s	remaining: 0us
# Finished training within 3.66 seconds

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Create and train the CatBoostClassifier model
catboost_model = CatBoostClassifier()
catboost_model.fit(X_train_resampled, y_train_resampled)

# Make predictions on the test set
y_catboost = catboost_model.predict(X_test_resampled)

# Classification report
print("Classification report for CatBoostClassifier:\n{}".format(classification_report(y_test_resampled, y_catboost)))

# Confusion matrix
print("Confusion matrix for CatBoostClassifier:\n{}".format(confusion_matrix(y_test_resampled, y_catboost)))

# Calculate and print accuracy score
accuracy_score_catboost = accuracy_score(y_test_resampled, y_catboost)
print("Accuracy score for CatBoost: {:.2f}".format(accuracy_score_catboost))

# Precision, recall, and F1 scores
prec_catboost = precision_score(y_test_resampled, y_catboost)
rec_catboost = recall_score(y_test_resampled, y_catboost)
f1_catboost = f1_score(y_test_resampled, y_catboost)
print("Precision score for CatBoostClassifier: {:.2f}".format(prec_catboost))
print("Recall score for CatBoostClassifier: {:.2f}".format(rec_catboost))
print("F1 score for CatBoostClassifier: {:.2f}".format(f1_catboost))

# Calculate sensitivity, specificity, and AUC
def calc_sens_spec(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sens_catboost, spec_catboost = calc_sens_spec(y_test_resampled, y_catboost)
print("Sensitivity score for CatBoostClassifier: {:.2f}".format(sens_catboost))
print("Specificity score for CatBoostClassifier: {:.2f}".format(spec_catboost))

# Calculate the false positive rate, true positive rate, and AUC
y_catboost_prob = catboost_model.predict_proba(X_test_resampled)[:, 1]
fpr, tpr, _ = roc_curve(y_test_resampled, y_catboost_prob)
auc_catboost = roc_auc_score(y_test_resampled, y_catboost_prob)
print("AUC score for CatBoostClassifier: {:.2f}".format(auc_catboost))

# Plot the ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_catboost)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (CatBoostClassifier)')
ax.legend(loc="lower right")
ax.set_facecolor("white")
plt.show()
# Out:
# Learning rate set to 0.04751
# 0:	learn: 0.6847305	total: 74ms	remaining: 1m 13s
# 1:	learn: 0.6763450	total: 106ms	remaining: 53.1s
# 2:	learn: 0.6699798	total: 129ms	remaining: 43s
# 3:	learn: 0.6638259	total: 153ms	remaining: 38.1s
# 4:	learn: 0.6575886	total: 197ms	remaining: 39.3s
# 5:	learn: 0.6527655	total: 245ms	remaining: 40.5s
# 6:	learn: 0.6482579	total: 274ms	remaining: 38.8s
# 7:	learn: 0.6441821	total: 307ms	remaining: 38s
# 8:	learn: 0.6399156	total: 350ms	remaining: 38.6s
# 9:	learn: 0.6365045	total: 404ms	remaining: 40s
# 10:	learn: 0.6332041	total: 439ms	remaining: 39.4s
# 11:	learn: 0.6303566	total: 459ms	remaining: 37.8s
# 12:	learn: 0.6276494	total: 478ms	remaining: 36.3s
# 13:	learn: 0.6253615	total: 499ms	remaining: 35.1s
# 14:	learn: 0.6229822	total: 523ms	remaining: 34.3s
# 15:	learn: 0.6210654	total: 552ms	remaining: 33.9s
# 16:	learn: 0.6191956	total: 576ms	remaining: 33.3s
# 17:	learn: 0.6171681	total: 596ms	remaining: 32.5s
# 18:	learn: 0.6153660	total: 627ms	remaining: 32.4s
# 19:	learn: 0.6136451	total: 659ms	remaining: 32.3s
# 20:	learn: 0.6121125	total: 684ms	remaining: 31.9s
# 21:	learn: 0.6105342	total: 709ms	remaining: 31.5s
# 22:	learn: 0.6091674	total: 732ms	remaining: 31.1s
# 23:	learn: 0.6077820	total: 767ms	remaining: 31.2s
# 24:	learn: 0.6065942	total: 792ms	remaining: 30.9s
# 25:	learn: 0.6053343	total: 820ms	remaining: 30.7s
# 26:	learn: 0.6036906	total: 938ms	remaining: 33.8s
# 27:	learn: 0.6026532	total: 977ms	remaining: 33.9s
# 28:	learn: 0.6016622	total: 999ms	remaining: 33.5s
# 29:	learn: 0.6006647	total: 1.02s	remaining: 32.9s
# 30:	learn: 0.5990437	total: 1.03s	remaining: 32.4s
# 31:	learn: 0.5978975	total: 1.05s	remaining: 31.9s
# 32:	learn: 0.5966650	total: 1.07s	remaining: 31.5s
# 33:	learn: 0.5956576	total: 1.1s	remaining: 31.2s
# 34:	learn: 0.5947037	total: 1.11s	remaining: 30.8s
# 35:	learn: 0.5938559	total: 1.13s	remaining: 30.4s
# 36:	learn: 0.5930827	total: 1.15s	remaining: 30s
# 37:	learn: 0.5921721	total: 1.17s	remaining: 29.7s
# 38:	learn: 0.5913978	total: 1.19s	remaining: 29.3s
# 39:	learn: 0.5907565	total: 1.21s	remaining: 29s
# 40:	learn: 0.5896882	total: 1.23s	remaining: 28.8s
# 41:	learn: 0.5886285	total: 1.25s	remaining: 28.5s
# 42:	learn: 0.5879774	total: 1.27s	remaining: 28.3s
# 43:	learn: 0.5873387	total: 1.3s	remaining: 28.2s
# 44:	learn: 0.5864341	total: 1.32s	remaining: 28s
# 45:	learn: 0.5857848	total: 1.35s	remaining: 27.9s
# 46:	learn: 0.5847583	total: 1.37s	remaining: 27.7s
# 47:	learn: 0.5842903	total: 1.39s	remaining: 27.6s
# 48:	learn: 0.5835571	total: 1.41s	remaining: 27.4s
# 49:	learn: 0.5828114	total: 1.43s	remaining: 27.2s
# 50:	learn: 0.5821134	total: 1.45s	remaining: 27s
# 51:	learn: 0.5812805	total: 1.47s	remaining: 26.8s
# 52:	learn: 0.5808078	total: 1.49s	remaining: 26.6s
# 53:	learn: 0.5801444	total: 1.51s	remaining: 26.5s
# 54:	learn: 0.5796479	total: 1.53s	remaining: 26.3s
# 55:	learn: 0.5788087	total: 1.55s	remaining: 26.1s
# 56:	learn: 0.5782631	total: 1.57s	remaining: 26s
# 57:	learn: 0.5777390	total: 1.59s	remaining: 25.9s
# 58:	learn: 0.5772992	total: 1.61s	remaining: 25.8s
# 59:	learn: 0.5766116	total: 1.64s	remaining: 25.7s
# 60:	learn: 0.5760999	total: 1.66s	remaining: 25.5s
# 61:	learn: 0.5757247	total: 1.68s	remaining: 25.4s
# 62:	learn: 0.5749336	total: 1.7s	remaining: 25.3s
# 63:	learn: 0.5745572	total: 1.72s	remaining: 25.1s
# 64:	learn: 0.5738973	total: 1.74s	remaining: 25s
# 65:	learn: 0.5733389	total: 1.76s	remaining: 24.9s
# 66:	learn: 0.5727280	total: 1.77s	remaining: 24.7s
# 67:	learn: 0.5723319	total: 1.79s	remaining: 24.6s
# 68:	learn: 0.5717083	total: 1.81s	remaining: 24.5s
# 69:	learn: 0.5712535	total: 1.84s	remaining: 24.4s
# 70:	learn: 0.5708951	total: 1.86s	remaining: 24.3s
# 71:	learn: 0.5704591	total: 1.88s	remaining: 24.2s
# 72:	learn: 0.5699620	total: 1.9s	remaining: 24.1s
# 73:	learn: 0.5694843	total: 1.93s	remaining: 24.1s
# 74:	learn: 0.5691030	total: 1.95s	remaining: 24s
# 75:	learn: 0.5684988	total: 1.97s	remaining: 24s
# 76:	learn: 0.5681297	total: 1.99s	remaining: 23.9s
# 77:	learn: 0.5677537	total: 2.01s	remaining: 23.8s
# 78:	learn: 0.5673111	total: 2.04s	remaining: 23.7s
# 79:	learn: 0.5669321	total: 2.05s	remaining: 23.6s
# 80:	learn: 0.5664620	total: 2.07s	remaining: 23.5s
# 81:	learn: 0.5659953	total: 2.09s	remaining: 23.4s
# 82:	learn: 0.5656898	total: 2.11s	remaining: 23.3s
# 83:	learn: 0.5653604	total: 2.13s	remaining: 23.2s
# 84:	learn: 0.5649771	total: 2.14s	remaining: 23.1s
# 85:	learn: 0.5646812	total: 2.16s	remaining: 23s
# 86:	learn: 0.5642520	total: 2.18s	remaining: 22.9s
# 87:	learn: 0.5638607	total: 2.2s	remaining: 22.8s
# 88:	learn: 0.5635410	total: 2.22s	remaining: 22.7s
# 89:	learn: 0.5632921	total: 2.24s	remaining: 22.6s
# 90:	learn: 0.5627801	total: 2.27s	remaining: 22.6s
# 91:	learn: 0.5623064	total: 2.29s	remaining: 22.6s
# 92:	learn: 0.5619928	total: 2.31s	remaining: 22.5s
# 93:	learn: 0.5616720	total: 2.32s	remaining: 22.4s
# 94:	learn: 0.5614269	total: 2.34s	remaining: 22.3s
# 95:	learn: 0.5611468	total: 2.36s	remaining: 22.2s
# 96:	learn: 0.5608404	total: 2.38s	remaining: 22.1s
# 97:	learn: 0.5605434	total: 2.39s	remaining: 22s
# 98:	learn: 0.5602624	total: 2.41s	remaining: 21.9s
# 99:	learn: 0.5598742	total: 2.43s	remaining: 21.9s
# 100:	learn: 0.5594568	total: 2.45s	remaining: 21.8s
# 101:	learn: 0.5591421	total: 2.47s	remaining: 21.7s
# 102:	learn: 0.5586742	total: 2.49s	remaining: 21.7s
# 103:	learn: 0.5585001	total: 2.51s	remaining: 21.6s
# 104:	learn: 0.5582118	total: 2.53s	remaining: 21.5s
# 105:	learn: 0.5579067	total: 2.54s	remaining: 21.5s
# 106:	learn: 0.5575773	total: 2.56s	remaining: 21.4s
# 107:	learn: 0.5571713	total: 2.59s	remaining: 21.4s
# 108:	learn: 0.5568545	total: 2.62s	remaining: 21.4s
# 109:	learn: 0.5565107	total: 2.69s	remaining: 21.8s
# 110:	learn: 0.5562374	total: 2.75s	remaining: 22s
# 111:	learn: 0.5558857	total: 2.8s	remaining: 22.2s
# 112:	learn: 0.5556333	total: 2.83s	remaining: 22.2s
# 113:	learn: 0.5553774	total: 2.86s	remaining: 22.3s
# 114:	learn: 0.5551276	total: 2.9s	remaining: 22.3s
# 115:	learn: 0.5547814	total: 2.95s	remaining: 22.5s
# 116:	learn: 0.5545317	total: 2.98s	remaining: 22.5s
# 117:	learn: 0.5541864	total: 3.02s	remaining: 22.6s
# 118:	learn: 0.5539763	total: 3.06s	remaining: 22.7s
# 119:	learn: 0.5537990	total: 3.09s	remaining: 22.7s
# 120:	learn: 0.5534920	total: 3.12s	remaining: 22.7s
# 121:	learn: 0.5531306	total: 3.14s	remaining: 22.6s
# 122:	learn: 0.5528480	total: 3.17s	remaining: 22.6s
# 123:	learn: 0.5525897	total: 3.19s	remaining: 22.5s
# 124:	learn: 0.5524428	total: 3.21s	remaining: 22.5s
# 125:	learn: 0.5522020	total: 3.24s	remaining: 22.5s
# 126:	learn: 0.5520735	total: 3.26s	remaining: 22.4s
# 127:	learn: 0.5517146	total: 3.29s	remaining: 22.4s
# 128:	learn: 0.5515388	total: 3.32s	remaining: 22.4s
# 129:	learn: 0.5513065	total: 3.34s	remaining: 22.4s
# 130:	learn: 0.5510305	total: 3.36s	remaining: 22.3s
# 131:	learn: 0.5508003	total: 3.39s	remaining: 22.3s
# 132:	learn: 0.5505385	total: 3.43s	remaining: 22.4s
# 133:	learn: 0.5502717	total: 3.45s	remaining: 22.3s
# 134:	learn: 0.5501770	total: 3.49s	remaining: 22.4s
# 135:	learn: 0.5499518	total: 3.53s	remaining: 22.4s
# 136:	learn: 0.5498069	total: 3.56s	remaining: 22.4s
# 137:	learn: 0.5495392	total: 3.6s	remaining: 22.5s
# 138:	learn: 0.5493562	total: 3.63s	remaining: 22.5s
# 139:	learn: 0.5490901	total: 3.66s	remaining: 22.5s
# 140:	learn: 0.5488913	total: 3.69s	remaining: 22.5s
# 141:	learn: 0.5486311	total: 3.72s	remaining: 22.5s
# 142:	learn: 0.5483396	total: 3.75s	remaining: 22.5s
# 143:	learn: 0.5481172	total: 3.77s	remaining: 22.4s
# 144:	learn: 0.5478054	total: 3.79s	remaining: 22.4s
# 145:	learn: 0.5476093	total: 3.82s	remaining: 22.3s
# 146:	learn: 0.5473703	total: 3.84s	remaining: 22.3s
# 147:	learn: 0.5472145	total: 3.86s	remaining: 22.2s
# 148:	learn: 0.5469658	total: 3.89s	remaining: 22.2s
# 149:	learn: 0.5467826	total: 3.92s	remaining: 22.2s
# 150:	learn: 0.5465910	total: 3.95s	remaining: 22.2s
# 151:	learn: 0.5463895	total: 3.97s	remaining: 22.2s
# 152:	learn: 0.5462015	total: 4s	remaining: 22.1s
# 153:	learn: 0.5459556	total: 4.02s	remaining: 22.1s
# 154:	learn: 0.5457883	total: 4.04s	remaining: 22s
# 155:	learn: 0.5455924	total: 4.07s	remaining: 22s
# 156:	learn: 0.5454210	total: 4.11s	remaining: 22.1s
# 157:	learn: 0.5452099	total: 4.24s	remaining: 22.6s
# 158:	learn: 0.5450314	total: 4.3s	remaining: 22.8s
# 159:	learn: 0.5449081	total: 4.36s	remaining: 22.9s
# 160:	learn: 0.5446679	total: 4.38s	remaining: 22.9s
# 161:	learn: 0.5445458	total: 4.42s	remaining: 22.9s
# 162:	learn: 0.5443987	total: 4.46s	remaining: 22.9s
# 163:	learn: 0.5442065	total: 4.5s	remaining: 22.9s
# 164:	learn: 0.5439812	total: 4.54s	remaining: 22.9s
# 165:	learn: 0.5438190	total: 4.59s	remaining: 23.1s
# 166:	learn: 0.5436474	total: 4.62s	remaining: 23.1s
# 167:	learn: 0.5435451	total: 4.64s	remaining: 23s
# 168:	learn: 0.5433403	total: 4.66s	remaining: 22.9s
# 169:	learn: 0.5431907	total: 4.71s	remaining: 23s
# 170:	learn: 0.5431804	total: 4.73s	remaining: 22.9s
# 171:	learn: 0.5429917	total: 4.77s	remaining: 22.9s
# 172:	learn: 0.5428033	total: 4.79s	remaining: 22.9s
# 173:	learn: 0.5425474	total: 4.83s	remaining: 22.9s
# 174:	learn: 0.5423199	total: 4.85s	remaining: 22.9s
# 175:	learn: 0.5421360	total: 4.87s	remaining: 22.8s
# 176:	learn: 0.5419794	total: 4.89s	remaining: 22.8s
# 177:	learn: 0.5418049	total: 4.92s	remaining: 22.7s
# 178:	learn: 0.5416361	total: 4.94s	remaining: 22.7s
# 179:	learn: 0.5415033	total: 4.97s	remaining: 22.6s
# 180:	learn: 0.5413460	total: 4.99s	remaining: 22.6s
# 181:	learn: 0.5412038	total: 5.04s	remaining: 22.6s
# 182:	learn: 0.5410363	total: 5.06s	remaining: 22.6s
# 183:	learn: 0.5409289	total: 5.08s	remaining: 22.5s
# 184:	learn: 0.5408123	total: 5.11s	remaining: 22.5s
# 185:	learn: 0.5405940	total: 5.13s	remaining: 22.4s
# 186:	learn: 0.5404309	total: 5.15s	remaining: 22.4s
# 187:	learn: 0.5402275	total: 5.17s	remaining: 22.4s
# 188:	learn: 0.5401467	total: 5.21s	remaining: 22.4s
# 189:	learn: 0.5399281	total: 5.26s	remaining: 22.4s
# 190:	learn: 0.5397916	total: 5.29s	remaining: 22.4s
# 191:	learn: 0.5395968	total: 5.32s	remaining: 22.4s
# 192:	learn: 0.5394745	total: 5.35s	remaining: 22.4s
# 193:	learn: 0.5392936	total: 5.39s	remaining: 22.4s
# 194:	learn: 0.5391173	total: 5.43s	remaining: 22.4s
# 195:	learn: 0.5389066	total: 5.45s	remaining: 22.4s
# 196:	learn: 0.5387841	total: 5.5s	remaining: 22.4s
# 197:	learn: 0.5386585	total: 5.52s	remaining: 22.4s
# 198:	learn: 0.5384660	total: 5.54s	remaining: 22.3s
# 199:	learn: 0.5383189	total: 5.57s	remaining: 22.3s
# 200:	learn: 0.5381249	total: 5.59s	remaining: 22.2s
# 201:	learn: 0.5379982	total: 5.62s	remaining: 22.2s
# 202:	learn: 0.5378862	total: 5.64s	remaining: 22.1s
# 203:	learn: 0.5377700	total: 5.66s	remaining: 22.1s
# 204:	learn: 0.5375928	total: 5.69s	remaining: 22.1s
# 205:	learn: 0.5374440	total: 5.72s	remaining: 22.1s
# 206:	learn: 0.5373791	total: 5.74s	remaining: 22s
# 207:	learn: 0.5372485	total: 5.77s	remaining: 22s
# 208:	learn: 0.5371297	total: 5.79s	remaining: 21.9s
# 209:	learn: 0.5369830	total: 5.82s	remaining: 21.9s
# 210:	learn: 0.5368594	total: 5.86s	remaining: 21.9s
# 211:	learn: 0.5367194	total: 5.89s	remaining: 21.9s
# 212:	learn: 0.5365634	total: 5.94s	remaining: 21.9s
# 213:	learn: 0.5363905	total: 5.96s	remaining: 21.9s
# 214:	learn: 0.5362596	total: 6.02s	remaining: 22s
# 215:	learn: 0.5360282	total: 6.07s	remaining: 22s
# 216:	learn: 0.5359501	total: 6.12s	remaining: 22.1s
# 217:	learn: 0.5358227	total: 6.17s	remaining: 22.1s
# 218:	learn: 0.5356930	total: 6.21s	remaining: 22.1s
# 219:	learn: 0.5356367	total: 6.24s	remaining: 22.1s
# 220:	learn: 0.5354811	total: 6.27s	remaining: 22.1s
# 221:	learn: 0.5353320	total: 6.31s	remaining: 22.1s
# 222:	learn: 0.5351918	total: 6.34s	remaining: 22.1s
# 223:	learn: 0.5350844	total: 6.37s	remaining: 22.1s
# 224:	learn: 0.5349581	total: 6.44s	remaining: 22.2s
# 225:	learn: 0.5348335	total: 6.47s	remaining: 22.2s
# 226:	learn: 0.5347350	total: 6.49s	remaining: 22.1s
# 227:	learn: 0.5346060	total: 6.52s	remaining: 22.1s
# 228:	learn: 0.5344856	total: 6.54s	remaining: 22s
# 229:	learn: 0.5343663	total: 6.56s	remaining: 22s
# 230:	learn: 0.5342260	total: 6.61s	remaining: 22s
# 231:	learn: 0.5340659	total: 6.64s	remaining: 22s
# 232:	learn: 0.5339854	total: 6.69s	remaining: 22s
# 233:	learn: 0.5339135	total: 6.72s	remaining: 22s
# 234:	learn: 0.5337548	total: 6.74s	remaining: 21.9s
# 235:	learn: 0.5336536	total: 6.76s	remaining: 21.9s
# 236:	learn: 0.5335609	total: 6.8s	remaining: 21.9s
# 237:	learn: 0.5334418	total: 6.84s	remaining: 21.9s
# 238:	learn: 0.5333385	total: 6.88s	remaining: 21.9s
# 239:	learn: 0.5332560	total: 6.91s	remaining: 21.9s
# 240:	learn: 0.5331366	total: 6.94s	remaining: 21.9s
# 241:	learn: 0.5329455	total: 6.96s	remaining: 21.8s
# 242:	learn: 0.5327878	total: 6.99s	remaining: 21.8s
# 243:	learn: 0.5326899	total: 7.02s	remaining: 21.7s
# 244:	learn: 0.5325786	total: 7.04s	remaining: 21.7s
# 245:	learn: 0.5324822	total: 7.08s	remaining: 21.7s
# 246:	learn: 0.5323331	total: 7.13s	remaining: 21.7s
# 247:	learn: 0.5321977	total: 7.16s	remaining: 21.7s
# 248:	learn: 0.5321212	total: 7.18s	remaining: 21.7s
# 249:	learn: 0.5319891	total: 7.21s	remaining: 21.6s
# 250:	learn: 0.5318470	total: 7.23s	remaining: 21.6s
# 251:	learn: 0.5316477	total: 7.27s	remaining: 21.6s
# 252:	learn: 0.5315510	total: 7.3s	remaining: 21.6s
# 253:	learn: 0.5314817	total: 7.32s	remaining: 21.5s
# 254:	learn: 0.5314011	total: 7.37s	remaining: 21.5s
# 255:	learn: 0.5312835	total: 7.4s	remaining: 21.5s
# 256:	learn: 0.5312057	total: 7.45s	remaining: 21.5s
# 257:	learn: 0.5310941	total: 7.48s	remaining: 21.5s
# 258:	learn: 0.5309921	total: 7.51s	remaining: 21.5s
# 259:	learn: 0.5308831	total: 7.54s	remaining: 21.5s
# 260:	learn: 0.5307779	total: 7.57s	remaining: 21.4s
# 261:	learn: 0.5307169	total: 7.6s	remaining: 21.4s
# 262:	learn: 0.5306337	total: 7.63s	remaining: 21.4s
# 263:	learn: 0.5304842	total: 7.67s	remaining: 21.4s
# 264:	learn: 0.5303802	total: 7.69s	remaining: 21.3s
# 265:	learn: 0.5302858	total: 7.71s	remaining: 21.3s
# 266:	learn: 0.5301672	total: 7.73s	remaining: 21.2s
# 267:	learn: 0.5300465	total: 7.75s	remaining: 21.2s
# 268:	learn: 0.5299452	total: 7.77s	remaining: 21.1s
# 269:	learn: 0.5298334	total: 7.8s	remaining: 21.1s
# 270:	learn: 0.5296568	total: 7.83s	remaining: 21.1s
# 271:	learn: 0.5295270	total: 7.85s	remaining: 21s
# 272:	learn: 0.5294295	total: 7.87s	remaining: 21s
# 273:	learn: 0.5292947	total: 7.88s	remaining: 20.9s
# 274:	learn: 0.5291898	total: 7.91s	remaining: 20.9s
# 275:	learn: 0.5290472	total: 7.93s	remaining: 20.8s
# 276:	learn: 0.5289574	total: 7.95s	remaining: 20.7s
# 277:	learn: 0.5288466	total: 7.96s	remaining: 20.7s
# 278:	learn: 0.5286551	total: 7.98s	remaining: 20.6s
# 279:	learn: 0.5285139	total: 8s	remaining: 20.6s
# 280:	learn: 0.5284236	total: 8.01s	remaining: 20.5s
# 281:	learn: 0.5283150	total: 8.04s	remaining: 20.5s
# 282:	learn: 0.5281676	total: 8.06s	remaining: 20.4s
# 283:	learn: 0.5280184	total: 8.09s	remaining: 20.4s
# 284:	learn: 0.5279002	total: 8.12s	remaining: 20.4s
# 285:	learn: 0.5277868	total: 8.14s	remaining: 20.3s
# 286:	learn: 0.5276254	total: 8.16s	remaining: 20.3s
# 287:	learn: 0.5275386	total: 8.18s	remaining: 20.2s
# 288:	learn: 0.5273591	total: 8.2s	remaining: 20.2s
# 289:	learn: 0.5272620	total: 8.21s	remaining: 20.1s
# 290:	learn: 0.5271652	total: 8.22s	remaining: 20s
# 291:	learn: 0.5270797	total: 8.24s	remaining: 20s
# 292:	learn: 0.5269919	total: 8.25s	remaining: 19.9s
# 293:	learn: 0.5268948	total: 8.26s	remaining: 19.8s
# 294:	learn: 0.5267823	total: 8.28s	remaining: 19.8s
# 295:	learn: 0.5266535	total: 8.29s	remaining: 19.7s
# 296:	learn: 0.5265266	total: 8.31s	remaining: 19.7s
# 297:	learn: 0.5263995	total: 8.32s	remaining: 19.6s
# 298:	learn: 0.5262882	total: 8.34s	remaining: 19.6s
# 299:	learn: 0.5261918	total: 8.36s	remaining: 19.5s
# 300:	learn: 0.5261041	total: 8.37s	remaining: 19.4s
# 301:	learn: 0.5259900	total: 8.39s	remaining: 19.4s
# 302:	learn: 0.5258824	total: 8.4s	remaining: 19.3s
# 303:	learn: 0.5257974	total: 8.42s	remaining: 19.3s
# 304:	learn: 0.5257206	total: 8.43s	remaining: 19.2s
# 305:	learn: 0.5256369	total: 8.45s	remaining: 19.2s
# 306:	learn: 0.5255194	total: 8.47s	remaining: 19.1s
# 307:	learn: 0.5254211	total: 8.49s	remaining: 19.1s
# 308:	learn: 0.5253117	total: 8.5s	remaining: 19s
# 309:	learn: 0.5252343	total: 8.52s	remaining: 19s
# 310:	learn: 0.5251337	total: 8.54s	remaining: 18.9s
# 311:	learn: 0.5250362	total: 8.55s	remaining: 18.9s
# 312:	learn: 0.5249366	total: 8.56s	remaining: 18.8s
# 313:	learn: 0.5248530	total: 8.58s	remaining: 18.7s
# 314:	learn: 0.5247403	total: 8.59s	remaining: 18.7s
# 315:	learn: 0.5246317	total: 8.61s	remaining: 18.6s
# 316:	learn: 0.5245653	total: 8.63s	remaining: 18.6s
# 317:	learn: 0.5244238	total: 8.65s	remaining: 18.6s
# 318:	learn: 0.5242983	total: 8.67s	remaining: 18.5s
# 319:	learn: 0.5242197	total: 8.68s	remaining: 18.5s
# 320:	learn: 0.5241502	total: 8.7s	remaining: 18.4s
# 321:	learn: 0.5240245	total: 8.71s	remaining: 18.4s
# 322:	learn: 0.5239126	total: 8.73s	remaining: 18.3s
# 323:	learn: 0.5238560	total: 8.75s	remaining: 18.3s
# 324:	learn: 0.5237762	total: 8.77s	remaining: 18.2s
# 325:	learn: 0.5236855	total: 8.78s	remaining: 18.2s
# 326:	learn: 0.5235738	total: 8.8s	remaining: 18.1s
# 327:	learn: 0.5234450	total: 8.81s	remaining: 18.1s
# 328:	learn: 0.5233557	total: 8.83s	remaining: 18s
# 329:	learn: 0.5232601	total: 8.84s	remaining: 17.9s
# 330:	learn: 0.5231621	total: 8.86s	remaining: 17.9s
# 331:	learn: 0.5230728	total: 8.87s	remaining: 17.9s
# 332:	learn: 0.5230209	total: 8.89s	remaining: 17.8s
# 333:	learn: 0.5229283	total: 8.91s	remaining: 17.8s
# 334:	learn: 0.5228109	total: 8.93s	remaining: 17.7s
# 335:	learn: 0.5226660	total: 8.95s	remaining: 17.7s
# 336:	learn: 0.5225724	total: 8.96s	remaining: 17.6s
# 337:	learn: 0.5224645	total: 8.97s	remaining: 17.6s
# 338:	learn: 0.5223560	total: 8.99s	remaining: 17.5s
# 339:	learn: 0.5222651	total: 9s	remaining: 17.5s
# 340:	learn: 0.5222022	total: 9.02s	remaining: 17.4s
# 341:	learn: 0.5221392	total: 9.03s	remaining: 17.4s
# 342:	learn: 0.5220521	total: 9.05s	remaining: 17.3s
# 343:	learn: 0.5219426	total: 9.07s	remaining: 17.3s
# 344:	learn: 0.5218341	total: 9.09s	remaining: 17.3s
# 345:	learn: 0.5217279	total: 9.11s	remaining: 17.2s
# 346:	learn: 0.5216269	total: 9.12s	remaining: 17.2s
# 347:	learn: 0.5215354	total: 9.13s	remaining: 17.1s
# 348:	learn: 0.5214604	total: 9.15s	remaining: 17.1s
# 349:	learn: 0.5213952	total: 9.16s	remaining: 17s
# 350:	learn: 0.5213414	total: 9.19s	remaining: 17s
# 351:	learn: 0.5212381	total: 9.21s	remaining: 17s
# 352:	learn: 0.5211481	total: 9.24s	remaining: 16.9s
# 353:	learn: 0.5210670	total: 9.26s	remaining: 16.9s
# 354:	learn: 0.5209659	total: 9.27s	remaining: 16.9s
# 355:	learn: 0.5208732	total: 9.29s	remaining: 16.8s
# 356:	learn: 0.5208021	total: 9.32s	remaining: 16.8s
# 357:	learn: 0.5207023	total: 9.35s	remaining: 16.8s
# 358:	learn: 0.5206146	total: 9.38s	remaining: 16.7s
# 359:	learn: 0.5204995	total: 9.4s	remaining: 16.7s
# 360:	learn: 0.5203971	total: 9.42s	remaining: 16.7s
# 361:	learn: 0.5203232	total: 9.44s	remaining: 16.6s
# 362:	learn: 0.5202085	total: 9.47s	remaining: 16.6s
# 363:	learn: 0.5201423	total: 9.49s	remaining: 16.6s
# 364:	learn: 0.5200583	total: 9.52s	remaining: 16.6s
# 365:	learn: 0.5199750	total: 9.54s	remaining: 16.5s
# 366:	learn: 0.5198972	total: 9.55s	remaining: 16.5s
# 367:	learn: 0.5197954	total: 9.57s	remaining: 16.4s
# 368:	learn: 0.5196952	total: 9.6s	remaining: 16.4s
# 369:	learn: 0.5196098	total: 9.63s	remaining: 16.4s
# 370:	learn: 0.5195178	total: 9.66s	remaining: 16.4s
# 371:	learn: 0.5194360	total: 9.68s	remaining: 16.3s
# 372:	learn: 0.5193344	total: 9.7s	remaining: 16.3s
# 373:	learn: 0.5192262	total: 9.72s	remaining: 16.3s
# 374:	learn: 0.5191393	total: 9.74s	remaining: 16.2s
# 375:	learn: 0.5190628	total: 9.76s	remaining: 16.2s
# 376:	learn: 0.5189946	total: 9.78s	remaining: 16.2s
# 377:	learn: 0.5189242	total: 9.8s	remaining: 16.1s
# 378:	learn: 0.5188305	total: 9.82s	remaining: 16.1s
# 379:	learn: 0.5187457	total: 9.84s	remaining: 16.1s
# 380:	learn: 0.5186404	total: 9.86s	remaining: 16s
# 381:	learn: 0.5185884	total: 9.87s	remaining: 16s
# 382:	learn: 0.5184930	total: 9.9s	remaining: 15.9s
# 383:	learn: 0.5184170	total: 9.92s	remaining: 15.9s
# 384:	learn: 0.5183340	total: 9.94s	remaining: 15.9s
# 385:	learn: 0.5182426	total: 9.95s	remaining: 15.8s
# 386:	learn: 0.5181680	total: 9.97s	remaining: 15.8s
# 387:	learn: 0.5180811	total: 9.98s	remaining: 15.7s
# 388:	learn: 0.5179910	total: 10s	remaining: 15.7s
# 389:	learn: 0.5179181	total: 10s	remaining: 15.7s
# 390:	learn: 0.5178122	total: 10s	remaining: 15.6s
# 391:	learn: 0.5177161	total: 10.1s	remaining: 15.6s
# 392:	learn: 0.5176404	total: 10.1s	remaining: 15.6s
# 393:	learn: 0.5175695	total: 10.1s	remaining: 15.5s
# 394:	learn: 0.5174948	total: 10.1s	remaining: 15.5s
# 395:	learn: 0.5174006	total: 10.1s	remaining: 15.5s
# 396:	learn: 0.5173232	total: 10.1s	remaining: 15.4s
# 397:	learn: 0.5172300	total: 10.2s	remaining: 15.4s
# 398:	learn: 0.5171413	total: 10.2s	remaining: 15.3s
# 399:	learn: 0.5170726	total: 10.2s	remaining: 15.3s
# 400:	learn: 0.5170079	total: 10.2s	remaining: 15.3s
# 401:	learn: 0.5169231	total: 10.2s	remaining: 15.2s
# 402:	learn: 0.5168813	total: 10.2s	remaining: 15.2s
# 403:	learn: 0.5167964	total: 10.3s	remaining: 15.1s
# 404:	learn: 0.5167140	total: 10.3s	remaining: 15.1s
# 405:	learn: 0.5166575	total: 10.3s	remaining: 15.1s
# 406:	learn: 0.5166042	total: 10.3s	remaining: 15s
# 407:	learn: 0.5165436	total: 10.3s	remaining: 15s
# 408:	learn: 0.5164796	total: 10.4s	remaining: 15s
# 409:	learn: 0.5164102	total: 10.4s	remaining: 14.9s
# 410:	learn: 0.5163520	total: 10.4s	remaining: 14.9s
# 411:	learn: 0.5162678	total: 10.5s	remaining: 15s
# 412:	learn: 0.5161877	total: 10.5s	remaining: 14.9s
# 413:	learn: 0.5161291	total: 10.5s	remaining: 14.9s
# 414:	learn: 0.5160890	total: 10.6s	remaining: 14.9s
# 415:	learn: 0.5160052	total: 10.6s	remaining: 14.8s
# 416:	learn: 0.5159318	total: 10.6s	remaining: 14.8s
# 417:	learn: 0.5158569	total: 10.6s	remaining: 14.8s
# 418:	learn: 0.5157971	total: 10.6s	remaining: 14.7s
# 419:	learn: 0.5157189	total: 10.6s	remaining: 14.7s
# 420:	learn: 0.5156505	total: 10.6s	remaining: 14.6s
# 421:	learn: 0.5155930	total: 10.7s	remaining: 14.6s
# 422:	learn: 0.5155067	total: 10.7s	remaining: 14.5s
# 423:	learn: 0.5154431	total: 10.7s	remaining: 14.5s
# 424:	learn: 0.5153389	total: 10.7s	remaining: 14.5s
# 425:	learn: 0.5152436	total: 10.7s	remaining: 14.4s
# 426:	learn: 0.5151761	total: 10.7s	remaining: 14.4s
# 427:	learn: 0.5150892	total: 10.7s	remaining: 14.3s
# 428:	learn: 0.5150174	total: 10.7s	remaining: 14.3s
# 429:	learn: 0.5149666	total: 10.8s	remaining: 14.3s
# 430:	learn: 0.5148931	total: 10.8s	remaining: 14.2s
# 431:	learn: 0.5148078	total: 10.8s	remaining: 14.2s
# 432:	learn: 0.5147256	total: 10.8s	remaining: 14.1s
# 433:	learn: 0.5146501	total: 10.8s	remaining: 14.1s
# 434:	learn: 0.5145803	total: 10.8s	remaining: 14.1s
# 435:	learn: 0.5145226	total: 10.8s	remaining: 14s
# 436:	learn: 0.5144546	total: 10.9s	remaining: 14s
# 437:	learn: 0.5143861	total: 10.9s	remaining: 14s
# 438:	learn: 0.5143372	total: 10.9s	remaining: 13.9s
# 439:	learn: 0.5142594	total: 10.9s	remaining: 13.9s
# 440:	learn: 0.5141849	total: 10.9s	remaining: 13.9s
# 441:	learn: 0.5141207	total: 11s	remaining: 13.8s
# 442:	learn: 0.5140378	total: 11s	remaining: 13.8s
# 443:	learn: 0.5139603	total: 11s	remaining: 13.8s
# 444:	learn: 0.5138955	total: 11s	remaining: 13.7s
# 445:	learn: 0.5138198	total: 11s	remaining: 13.7s
# 446:	learn: 0.5137714	total: 11.1s	remaining: 13.7s
# 447:	learn: 0.5136676	total: 11.1s	remaining: 13.6s
# 448:	learn: 0.5136191	total: 11.1s	remaining: 13.6s
# 449:	learn: 0.5135438	total: 11.1s	remaining: 13.6s
# 450:	learn: 0.5134670	total: 11.1s	remaining: 13.5s
# 451:	learn: 0.5133848	total: 11.1s	remaining: 13.5s
# 452:	learn: 0.5133242	total: 11.1s	remaining: 13.5s
# 453:	learn: 0.5132517	total: 11.2s	remaining: 13.4s
# 454:	learn: 0.5132054	total: 11.2s	remaining: 13.4s
# 455:	learn: 0.5131317	total: 11.2s	remaining: 13.3s
# 456:	learn: 0.5130872	total: 11.2s	remaining: 13.3s
# 457:	learn: 0.5130111	total: 11.2s	remaining: 13.3s
# 458:	learn: 0.5129248	total: 11.2s	remaining: 13.2s
# 459:	learn: 0.5128520	total: 11.2s	remaining: 13.2s
# 460:	learn: 0.5128076	total: 11.2s	remaining: 13.1s
# 461:	learn: 0.5127418	total: 11.2s	remaining: 13.1s
# 462:	learn: 0.5126574	total: 11.3s	remaining: 13.1s
# 463:	learn: 0.5125830	total: 11.3s	remaining: 13s
# 464:	learn: 0.5125188	total: 11.3s	remaining: 13s
# 465:	learn: 0.5124517	total: 11.3s	remaining: 12.9s
# 466:	learn: 0.5123714	total: 11.3s	remaining: 12.9s
# 467:	learn: 0.5123158	total: 11.3s	remaining: 12.9s
# 468:	learn: 0.5122407	total: 11.3s	remaining: 12.8s
# 469:	learn: 0.5121652	total: 11.3s	remaining: 12.8s
# 470:	learn: 0.5121340	total: 11.4s	remaining: 12.8s
# 471:	learn: 0.5120781	total: 11.4s	remaining: 12.7s
# 472:	learn: 0.5120010	total: 11.4s	remaining: 12.7s
# 473:	learn: 0.5119243	total: 11.4s	remaining: 12.6s
# 474:	learn: 0.5118684	total: 11.4s	remaining: 12.6s
# 475:	learn: 0.5118138	total: 11.4s	remaining: 12.6s
# 476:	learn: 0.5117465	total: 11.4s	remaining: 12.5s
# 477:	learn: 0.5117102	total: 11.4s	remaining: 12.5s
# 478:	learn: 0.5116306	total: 11.5s	remaining: 12.5s
# 479:	learn: 0.5115712	total: 11.5s	remaining: 12.4s
# 480:	learn: 0.5114819	total: 11.5s	remaining: 12.4s
# 481:	learn: 0.5114085	total: 11.5s	remaining: 12.4s
# 482:	learn: 0.5113396	total: 11.5s	remaining: 12.3s
# 483:	learn: 0.5112839	total: 11.5s	remaining: 12.3s
# 484:	learn: 0.5112192	total: 11.5s	remaining: 12.2s
# 485:	learn: 0.5111769	total: 11.5s	remaining: 12.2s
# 486:	learn: 0.5111102	total: 11.6s	remaining: 12.2s
# 487:	learn: 0.5110199	total: 11.6s	remaining: 12.1s
# 488:	learn: 0.5109511	total: 11.6s	remaining: 12.1s
# 489:	learn: 0.5108763	total: 11.6s	remaining: 12.1s
# 490:	learn: 0.5108178	total: 11.6s	remaining: 12s
# 491:	learn: 0.5107413	total: 11.6s	remaining: 12s
# 492:	learn: 0.5106440	total: 11.6s	remaining: 12s
# 493:	learn: 0.5105819	total: 11.6s	remaining: 11.9s
# 494:	learn: 0.5105079	total: 11.7s	remaining: 11.9s
# 495:	learn: 0.5104471	total: 11.7s	remaining: 11.9s
# 496:	learn: 0.5103772	total: 11.7s	remaining: 11.8s
# 497:	learn: 0.5103071	total: 11.7s	remaining: 11.8s
# 498:	learn: 0.5102324	total: 11.7s	remaining: 11.8s
# 499:	learn: 0.5101534	total: 11.7s	remaining: 11.7s
# 500:	learn: 0.5100969	total: 11.7s	remaining: 11.7s
# 501:	learn: 0.5100690	total: 11.7s	remaining: 11.6s
# 502:	learn: 0.5100061	total: 11.8s	remaining: 11.6s
# 503:	learn: 0.5099523	total: 11.8s	remaining: 11.6s
# 504:	learn: 0.5098886	total: 11.8s	remaining: 11.6s
# 505:	learn: 0.5098016	total: 11.8s	remaining: 11.5s
# 506:	learn: 0.5097369	total: 11.8s	remaining: 11.5s
# 507:	learn: 0.5096948	total: 11.8s	remaining: 11.5s
# 508:	learn: 0.5096368	total: 11.9s	remaining: 11.4s
# 509:	learn: 0.5095914	total: 11.9s	remaining: 11.4s
# 510:	learn: 0.5095204	total: 11.9s	remaining: 11.4s
# 511:	learn: 0.5094344	total: 11.9s	remaining: 11.3s
# 512:	learn: 0.5093781	total: 11.9s	remaining: 11.3s
# 513:	learn: 0.5093201	total: 11.9s	remaining: 11.3s
# 514:	learn: 0.5092320	total: 11.9s	remaining: 11.2s
# 515:	learn: 0.5091675	total: 12s	remaining: 11.2s
# 516:	learn: 0.5091195	total: 12s	remaining: 11.2s
# 517:	learn: 0.5090801	total: 12s	remaining: 11.1s
# 518:	learn: 0.5090315	total: 12s	remaining: 11.1s
# 519:	learn: 0.5089800	total: 12s	remaining: 11.1s
# 520:	learn: 0.5089081	total: 12s	remaining: 11s
# 521:	learn: 0.5088540	total: 12s	remaining: 11s
# 522:	learn: 0.5087904	total: 12s	remaining: 11s
# 523:	learn: 0.5087225	total: 12.1s	remaining: 10.9s
# 524:	learn: 0.5086595	total: 12.1s	remaining: 10.9s
# 525:	learn: 0.5086035	total: 12.1s	remaining: 10.9s
# 526:	learn: 0.5085671	total: 12.1s	remaining: 10.8s
# 527:	learn: 0.5084952	total: 12.1s	remaining: 10.8s
# 528:	learn: 0.5084260	total: 12.1s	remaining: 10.8s
# 529:	learn: 0.5083585	total: 12.1s	remaining: 10.8s
# 530:	learn: 0.5083033	total: 12.1s	remaining: 10.7s
# 531:	learn: 0.5082557	total: 12.2s	remaining: 10.7s
# 532:	learn: 0.5081859	total: 12.2s	remaining: 10.7s
# 533:	learn: 0.5081384	total: 12.2s	remaining: 10.6s
# 534:	learn: 0.5080863	total: 12.2s	remaining: 10.6s
# 535:	learn: 0.5080458	total: 12.2s	remaining: 10.6s
# 536:	learn: 0.5079938	total: 12.2s	remaining: 10.5s
# 537:	learn: 0.5079364	total: 12.2s	remaining: 10.5s
# 538:	learn: 0.5078685	total: 12.2s	remaining: 10.5s
# 539:	learn: 0.5077988	total: 12.3s	remaining: 10.4s
# 540:	learn: 0.5077198	total: 12.3s	remaining: 10.4s
# 541:	learn: 0.5076723	total: 12.3s	remaining: 10.4s
# 542:	learn: 0.5076068	total: 12.3s	remaining: 10.3s
# 543:	learn: 0.5075568	total: 12.3s	remaining: 10.3s
# 544:	learn: 0.5075149	total: 12.3s	remaining: 10.3s
# 545:	learn: 0.5074351	total: 12.3s	remaining: 10.3s
# 546:	learn: 0.5074007	total: 12.3s	remaining: 10.2s
# 547:	learn: 0.5073626	total: 12.4s	remaining: 10.2s
# 548:	learn: 0.5072832	total: 12.4s	remaining: 10.2s
# 549:	learn: 0.5072247	total: 12.4s	remaining: 10.1s
# 550:	learn: 0.5071689	total: 12.4s	remaining: 10.1s
# 551:	learn: 0.5071289	total: 12.4s	remaining: 10.1s
# 552:	learn: 0.5070808	total: 12.4s	remaining: 10s
# 553:	learn: 0.5070074	total: 12.4s	remaining: 10s
# 554:	learn: 0.5069288	total: 12.4s	remaining: 9.97s
# 555:	learn: 0.5068609	total: 12.4s	remaining: 9.94s
# 556:	learn: 0.5068002	total: 12.5s	remaining: 9.91s
# 557:	learn: 0.5067718	total: 12.5s	remaining: 9.88s
# 558:	learn: 0.5067047	total: 12.5s	remaining: 9.85s
# 559:	learn: 0.5066433	total: 12.5s	remaining: 9.82s
# 560:	learn: 0.5065861	total: 12.5s	remaining: 9.79s
# 561:	learn: 0.5065320	total: 12.5s	remaining: 9.76s
# 562:	learn: 0.5064727	total: 12.5s	remaining: 9.72s
# 563:	learn: 0.5064216	total: 12.5s	remaining: 9.7s
# 564:	learn: 0.5063768	total: 12.6s	remaining: 9.67s
# 565:	learn: 0.5063227	total: 12.6s	remaining: 9.64s
# 566:	learn: 0.5062642	total: 12.6s	remaining: 9.61s
# 567:	learn: 0.5062131	total: 12.6s	remaining: 9.58s
# 568:	learn: 0.5061618	total: 12.6s	remaining: 9.55s
# 569:	learn: 0.5061155	total: 12.6s	remaining: 9.52s
# 570:	learn: 0.5060741	total: 12.6s	remaining: 9.49s
# 571:	learn: 0.5060201	total: 12.6s	remaining: 9.46s
# 572:	learn: 0.5059422	total: 12.7s	remaining: 9.43s
# 573:	learn: 0.5059054	total: 12.7s	remaining: 9.4s
# 574:	learn: 0.5058548	total: 12.7s	remaining: 9.38s
# 575:	learn: 0.5057975	total: 12.7s	remaining: 9.35s
# 576:	learn: 0.5057474	total: 12.7s	remaining: 9.33s
# 577:	learn: 0.5056753	total: 12.7s	remaining: 9.3s
# 578:	learn: 0.5056198	total: 12.8s	remaining: 9.28s
# 579:	learn: 0.5055640	total: 12.8s	remaining: 9.25s
# 580:	learn: 0.5054968	total: 12.8s	remaining: 9.22s
# 581:	learn: 0.5054335	total: 12.8s	remaining: 9.2s
# 582:	learn: 0.5053857	total: 12.8s	remaining: 9.17s
# 583:	learn: 0.5053372	total: 12.8s	remaining: 9.14s
# 584:	learn: 0.5053015	total: 12.8s	remaining: 9.11s
# 585:	learn: 0.5052602	total: 12.9s	remaining: 9.08s
# 586:	learn: 0.5052081	total: 12.9s	remaining: 9.05s
# 587:	learn: 0.5051423	total: 12.9s	remaining: 9.03s
# 588:	learn: 0.5051090	total: 12.9s	remaining: 9s
# 589:	learn: 0.5050387	total: 12.9s	remaining: 8.97s
# 590:	learn: 0.5049982	total: 12.9s	remaining: 8.94s
# 591:	learn: 0.5049369	total: 12.9s	remaining: 8.91s
# 592:	learn: 0.5048828	total: 12.9s	remaining: 8.88s
# 593:	learn: 0.5048280	total: 13s	remaining: 8.85s
# 594:	learn: 0.5047487	total: 13s	remaining: 8.82s
# 595:	learn: 0.5047087	total: 13s	remaining: 8.8s
# 596:	learn: 0.5046566	total: 13s	remaining: 8.77s
# 597:	learn: 0.5045782	total: 13s	remaining: 8.74s
# 598:	learn: 0.5045103	total: 13s	remaining: 8.71s
# 599:	learn: 0.5044540	total: 13s	remaining: 8.69s
# 600:	learn: 0.5044185	total: 13s	remaining: 8.66s
# 601:	learn: 0.5043758	total: 13.1s	remaining: 8.63s
# 602:	learn: 0.5043283	total: 13.1s	remaining: 8.6s
# 603:	learn: 0.5042539	total: 13.1s	remaining: 8.57s
# 604:	learn: 0.5042052	total: 13.1s	remaining: 8.55s
# 605:	learn: 0.5041418	total: 13.1s	remaining: 8.52s
# 606:	learn: 0.5040774	total: 13.1s	remaining: 8.49s
# 607:	learn: 0.5040214	total: 13.1s	remaining: 8.46s
# 608:	learn: 0.5039514	total: 13.1s	remaining: 8.44s
# 609:	learn: 0.5039183	total: 13.2s	remaining: 8.41s
# 610:	learn: 0.5038703	total: 13.2s	remaining: 8.39s
# 611:	learn: 0.5038341	total: 13.2s	remaining: 8.37s
# 612:	learn: 0.5037679	total: 13.2s	remaining: 8.35s
# 613:	learn: 0.5036891	total: 13.2s	remaining: 8.32s
# 614:	learn: 0.5036476	total: 13.3s	remaining: 8.3s
# 615:	learn: 0.5036323	total: 13.3s	remaining: 8.27s
# 616:	learn: 0.5035870	total: 13.3s	remaining: 8.25s
# 617:	learn: 0.5035258	total: 13.3s	remaining: 8.22s
# 618:	learn: 0.5034855	total: 13.3s	remaining: 8.19s
# 619:	learn: 0.5034420	total: 13.3s	remaining: 8.17s
# 620:	learn: 0.5034099	total: 13.3s	remaining: 8.14s
# 621:	learn: 0.5033646	total: 13.3s	remaining: 8.11s
# 622:	learn: 0.5033265	total: 13.4s	remaining: 8.08s
# 623:	learn: 0.5032743	total: 13.4s	remaining: 8.06s
# 624:	learn: 0.5032303	total: 13.4s	remaining: 8.03s
# 625:	learn: 0.5032086	total: 13.4s	remaining: 8s
# 626:	learn: 0.5031450	total: 13.4s	remaining: 7.97s
# 627:	learn: 0.5031114	total: 13.4s	remaining: 7.95s
# 628:	learn: 0.5030805	total: 13.4s	remaining: 7.92s
# 629:	learn: 0.5030481	total: 13.4s	remaining: 7.89s
# 630:	learn: 0.5029932	total: 13.5s	remaining: 7.87s
# 631:	learn: 0.5029532	total: 13.5s	remaining: 7.84s
# 632:	learn: 0.5028790	total: 13.5s	remaining: 7.81s
# 633:	learn: 0.5028220	total: 13.5s	remaining: 7.79s
# 634:	learn: 0.5027629	total: 13.5s	remaining: 7.76s
# 635:	learn: 0.5027073	total: 13.5s	remaining: 7.73s
# 636:	learn: 0.5026598	total: 13.5s	remaining: 7.7s
# 637:	learn: 0.5025978	total: 13.5s	remaining: 7.68s
# 638:	learn: 0.5025396	total: 13.5s	remaining: 7.65s
# 639:	learn: 0.5024950	total: 13.6s	remaining: 7.62s
# 640:	learn: 0.5024460	total: 13.6s	remaining: 7.6s
# 641:	learn: 0.5023875	total: 13.6s	remaining: 7.57s
# 642:	learn: 0.5023320	total: 13.6s	remaining: 7.54s
# 643:	learn: 0.5022758	total: 13.6s	remaining: 7.52s
# 644:	learn: 0.5022495	total: 13.6s	remaining: 7.49s
# 645:	learn: 0.5022008	total: 13.6s	remaining: 7.46s
# 646:	learn: 0.5021690	total: 13.6s	remaining: 7.44s
# 647:	learn: 0.5021245	total: 13.6s	remaining: 7.41s
# 648:	learn: 0.5021033	total: 13.7s	remaining: 7.39s
# 649:	learn: 0.5020545	total: 13.7s	remaining: 7.36s
# 650:	learn: 0.5019729	total: 13.7s	remaining: 7.33s
# 651:	learn: 0.5019039	total: 13.7s	remaining: 7.31s
# 652:	learn: 0.5018616	total: 13.7s	remaining: 7.28s
# 653:	learn: 0.5018032	total: 13.7s	remaining: 7.26s
# 654:	learn: 0.5017964	total: 13.7s	remaining: 7.23s
# 655:	learn: 0.5017238	total: 13.7s	remaining: 7.21s
# 656:	learn: 0.5016754	total: 13.8s	remaining: 7.18s
# 657:	learn: 0.5015963	total: 13.8s	remaining: 7.16s
# 658:	learn: 0.5015540	total: 13.8s	remaining: 7.13s
# 659:	learn: 0.5014989	total: 13.8s	remaining: 7.1s
# 660:	learn: 0.5014540	total: 13.8s	remaining: 7.08s
# 661:	learn: 0.5013956	total: 13.8s	remaining: 7.05s
# 662:	learn: 0.5013654	total: 13.8s	remaining: 7.03s
# 663:	learn: 0.5013227	total: 13.8s	remaining: 7s
# 664:	learn: 0.5012657	total: 13.8s	remaining: 6.98s
# 665:	learn: 0.5012243	total: 13.9s	remaining: 6.95s
# 666:	learn: 0.5011928	total: 13.9s	remaining: 6.95s
# 667:	learn: 0.5011671	total: 13.9s	remaining: 6.93s
# 668:	learn: 0.5011288	total: 14s	remaining: 6.91s
# 669:	learn: 0.5010838	total: 14s	remaining: 6.9s
# 670:	learn: 0.5010568	total: 14s	remaining: 6.87s
# 671:	learn: 0.5009860	total: 14s	remaining: 6.85s
# 672:	learn: 0.5009378	total: 14s	remaining: 6.83s
# 673:	learn: 0.5008992	total: 14.1s	remaining: 6.8s
# 674:	learn: 0.5008579	total: 14.1s	remaining: 6.78s
# 675:	learn: 0.5007898	total: 14.1s	remaining: 6.75s
# 676:	learn: 0.5007330	total: 14.1s	remaining: 6.73s
# 677:	learn: 0.5006750	total: 14.1s	remaining: 6.7s
# 678:	learn: 0.5006438	total: 14.1s	remaining: 6.68s
# 679:	learn: 0.5005944	total: 14.1s	remaining: 6.65s
# 680:	learn: 0.5005520	total: 14.1s	remaining: 6.63s
# 681:	learn: 0.5005094	total: 14.2s	remaining: 6.6s
# 682:	learn: 0.5004683	total: 14.2s	remaining: 6.58s
# 683:	learn: 0.5004001	total: 14.2s	remaining: 6.55s
# 684:	learn: 0.5003626	total: 14.2s	remaining: 6.52s
# 685:	learn: 0.5003336	total: 14.2s	remaining: 6.5s
# 686:	learn: 0.5002749	total: 14.2s	remaining: 6.47s
# 687:	learn: 0.5002593	total: 14.2s	remaining: 6.45s
# 688:	learn: 0.5002094	total: 14.2s	remaining: 6.42s
# 689:	learn: 0.5001584	total: 14.2s	remaining: 6.4s
# 690:	learn: 0.5001179	total: 14.3s	remaining: 6.37s
# 691:	learn: 0.5000692	total: 14.3s	remaining: 6.35s
# 692:	learn: 0.5000013	total: 14.3s	remaining: 6.33s
# 693:	learn: 0.4999640	total: 14.3s	remaining: 6.3s
# 694:	learn: 0.4999489	total: 14.3s	remaining: 6.28s
# 695:	learn: 0.4998913	total: 14.3s	remaining: 6.25s
# 696:	learn: 0.4998337	total: 14.3s	remaining: 6.23s
# 697:	learn: 0.4998050	total: 14.3s	remaining: 6.21s
# 698:	learn: 0.4997443	total: 14.4s	remaining: 6.18s
# 699:	learn: 0.4997034	total: 14.4s	remaining: 6.16s
# 700:	learn: 0.4996845	total: 14.4s	remaining: 6.14s
# 701:	learn: 0.4996256	total: 14.4s	remaining: 6.11s
# 702:	learn: 0.4995765	total: 14.4s	remaining: 6.09s
# 703:	learn: 0.4995219	total: 14.4s	remaining: 6.06s
# 704:	learn: 0.4994785	total: 14.4s	remaining: 6.04s
# 705:	learn: 0.4994339	total: 14.4s	remaining: 6.02s
# 706:	learn: 0.4993916	total: 14.5s	remaining: 5.99s
# 707:	learn: 0.4993423	total: 14.5s	remaining: 5.97s
# 708:	learn: 0.4993022	total: 14.5s	remaining: 5.95s
# 709:	learn: 0.4992258	total: 14.5s	remaining: 5.92s
# 710:	learn: 0.4992008	total: 14.5s	remaining: 5.9s
# 711:	learn: 0.4991482	total: 14.5s	remaining: 5.88s
# 712:	learn: 0.4990945	total: 14.5s	remaining: 5.85s
# 713:	learn: 0.4990452	total: 14.6s	remaining: 5.83s
# 714:	learn: 0.4989923	total: 14.6s	remaining: 5.81s
# 715:	learn: 0.4989551	total: 14.6s	remaining: 5.78s
# 716:	learn: 0.4989209	total: 14.6s	remaining: 5.76s
# 717:	learn: 0.4988622	total: 14.6s	remaining: 5.74s
# 718:	learn: 0.4988152	total: 14.6s	remaining: 5.71s
# 719:	learn: 0.4987650	total: 14.6s	remaining: 5.69s
# 720:	learn: 0.4987079	total: 14.6s	remaining: 5.67s
# 721:	learn: 0.4986636	total: 14.7s	remaining: 5.64s
# 722:	learn: 0.4986206	total: 14.7s	remaining: 5.62s
# 723:	learn: 0.4985641	total: 14.7s	remaining: 5.6s
# 724:	learn: 0.4985101	total: 14.7s	remaining: 5.58s
# 725:	learn: 0.4984615	total: 14.7s	remaining: 5.56s
# 726:	learn: 0.4984111	total: 14.8s	remaining: 5.54s
# 727:	learn: 0.4983777	total: 14.8s	remaining: 5.52s
# 728:	learn: 0.4983043	total: 14.8s	remaining: 5.5s
# 729:	learn: 0.4982700	total: 14.8s	remaining: 5.48s
# 730:	learn: 0.4982250	total: 14.8s	remaining: 5.46s
# 731:	learn: 0.4981810	total: 14.8s	remaining: 5.43s
# 732:	learn: 0.4981491	total: 14.9s	remaining: 5.41s
# 733:	learn: 0.4981012	total: 14.9s	remaining: 5.39s
# 734:	learn: 0.4980711	total: 14.9s	remaining: 5.36s
# 735:	learn: 0.4980372	total: 14.9s	remaining: 5.34s
# 736:	learn: 0.4980066	total: 14.9s	remaining: 5.32s
# 737:	learn: 0.4979681	total: 14.9s	remaining: 5.29s
# 738:	learn: 0.4979202	total: 14.9s	remaining: 5.27s
# 739:	learn: 0.4978659	total: 14.9s	remaining: 5.25s
# 740:	learn: 0.4978149	total: 15s	remaining: 5.23s
# 741:	learn: 0.4977504	total: 15s	remaining: 5.2s
# 742:	learn: 0.4977196	total: 15s	remaining: 5.18s
# 743:	learn: 0.4976841	total: 15s	remaining: 5.16s
# 744:	learn: 0.4976403	total: 15s	remaining: 5.14s
# 745:	learn: 0.4975915	total: 15s	remaining: 5.12s
# 746:	learn: 0.4975214	total: 15.1s	remaining: 5.1s
# 747:	learn: 0.4974520	total: 15.1s	remaining: 5.08s
# 748:	learn: 0.4974010	total: 15.1s	remaining: 5.06s
# 749:	learn: 0.4973449	total: 15.1s	remaining: 5.04s
# 750:	learn: 0.4973024	total: 15.1s	remaining: 5.02s
# 751:	learn: 0.4972351	total: 15.1s	remaining: 5s
# 752:	learn: 0.4971977	total: 15.2s	remaining: 4.97s
# 753:	learn: 0.4971539	total: 15.2s	remaining: 4.96s
# 754:	learn: 0.4971048	total: 15.2s	remaining: 4.93s
# 755:	learn: 0.4970797	total: 15.2s	remaining: 4.91s
# 756:	learn: 0.4970273	total: 15.2s	remaining: 4.89s
# 757:	learn: 0.4969712	total: 15.2s	remaining: 4.87s
# 758:	learn: 0.4969112	total: 15.3s	remaining: 4.85s
# 759:	learn: 0.4968774	total: 15.3s	remaining: 4.82s
# 760:	learn: 0.4968140	total: 15.3s	remaining: 4.8s
# 761:	learn: 0.4967683	total: 15.3s	remaining: 4.78s
# 762:	learn: 0.4967394	total: 15.3s	remaining: 4.76s
# 763:	learn: 0.4966864	total: 15.3s	remaining: 4.74s
# 764:	learn: 0.4966263	total: 15.4s	remaining: 4.72s
# 765:	learn: 0.4966013	total: 15.4s	remaining: 4.7s
# 766:	learn: 0.4965255	total: 15.4s	remaining: 4.68s
# 767:	learn: 0.4964900	total: 15.4s	remaining: 4.66s
# 768:	learn: 0.4964515	total: 15.4s	remaining: 4.63s
# 769:	learn: 0.4964294	total: 15.4s	remaining: 4.61s
# 770:	learn: 0.4963750	total: 15.5s	remaining: 4.59s
# 771:	learn: 0.4963495	total: 15.5s	remaining: 4.57s
# 772:	learn: 0.4963083	total: 15.5s	remaining: 4.55s
# 773:	learn: 0.4962396	total: 15.5s	remaining: 4.53s
# 774:	learn: 0.4961969	total: 15.5s	remaining: 4.51s
# 775:	learn: 0.4961625	total: 15.5s	remaining: 4.49s
# 776:	learn: 0.4961208	total: 15.6s	remaining: 4.47s
# 777:	learn: 0.4960648	total: 15.6s	remaining: 4.45s
# 778:	learn: 0.4960143	total: 15.6s	remaining: 4.43s
# 779:	learn: 0.4959754	total: 15.6s	remaining: 4.41s
# 780:	learn: 0.4959063	total: 15.6s	remaining: 4.39s
# 781:	learn: 0.4958648	total: 15.7s	remaining: 4.37s
# 782:	learn: 0.4958299	total: 15.7s	remaining: 4.34s
# 783:	learn: 0.4957858	total: 15.7s	remaining: 4.32s
# 784:	learn: 0.4957329	total: 15.7s	remaining: 4.3s
# 785:	learn: 0.4957021	total: 15.7s	remaining: 4.28s
# 786:	learn: 0.4956511	total: 15.7s	remaining: 4.26s
# 787:	learn: 0.4956095	total: 15.7s	remaining: 4.24s
# 788:	learn: 0.4955569	total: 15.8s	remaining: 4.21s
# 789:	learn: 0.4955094	total: 15.8s	remaining: 4.19s
# 790:	learn: 0.4954772	total: 15.8s	remaining: 4.17s
# 791:	learn: 0.4954289	total: 15.8s	remaining: 4.15s
# 792:	learn: 0.4953831	total: 15.8s	remaining: 4.13s
# 793:	learn: 0.4953389	total: 15.8s	remaining: 4.11s
# 794:	learn: 0.4952902	total: 15.8s	remaining: 4.08s
# 795:	learn: 0.4952342	total: 15.9s	remaining: 4.07s
# 796:	learn: 0.4952141	total: 15.9s	remaining: 4.04s
# 797:	learn: 0.4951665	total: 15.9s	remaining: 4.02s
# 798:	learn: 0.4951068	total: 15.9s	remaining: 4s
# 799:	learn: 0.4950571	total: 15.9s	remaining: 3.98s
# 800:	learn: 0.4950197	total: 16s	remaining: 3.96s
# 801:	learn: 0.4949958	total: 16s	remaining: 3.94s
# 802:	learn: 0.4949626	total: 16s	remaining: 3.92s
# 803:	learn: 0.4949146	total: 16s	remaining: 3.9s
# 804:	learn: 0.4948779	total: 16.1s	remaining: 3.89s
# 805:	learn: 0.4948374	total: 16.1s	remaining: 3.87s
# 806:	learn: 0.4948067	total: 16.1s	remaining: 3.85s
# 807:	learn: 0.4947676	total: 16.1s	remaining: 3.83s
# 808:	learn: 0.4947294	total: 16.2s	remaining: 3.81s
# 809:	learn: 0.4946913	total: 16.2s	remaining: 3.79s
# 810:	learn: 0.4946676	total: 16.2s	remaining: 3.77s
# 811:	learn: 0.4946358	total: 16.2s	remaining: 3.75s
# 812:	learn: 0.4945860	total: 16.2s	remaining: 3.73s
# 813:	learn: 0.4945301	total: 16.3s	remaining: 3.71s
# 814:	learn: 0.4944810	total: 16.3s	remaining: 3.69s
# 815:	learn: 0.4944589	total: 16.3s	remaining: 3.69s
# 816:	learn: 0.4944114	total: 16.4s	remaining: 3.68s
# 817:	learn: 0.4943771	total: 16.5s	remaining: 3.67s
# 818:	learn: 0.4943419	total: 16.5s	remaining: 3.65s
# 819:	learn: 0.4942896	total: 16.5s	remaining: 3.63s
# 820:	learn: 0.4942550	total: 16.5s	remaining: 3.61s
# 821:	learn: 0.4941933	total: 16.6s	remaining: 3.59s
# 822:	learn: 0.4941305	total: 16.6s	remaining: 3.57s
# 823:	learn: 0.4940943	total: 16.6s	remaining: 3.54s
# 824:	learn: 0.4940687	total: 16.6s	remaining: 3.52s
# 825:	learn: 0.4939953	total: 16.6s	remaining: 3.5s
# 826:	learn: 0.4939373	total: 16.6s	remaining: 3.48s
# 827:	learn: 0.4938940	total: 16.6s	remaining: 3.46s
# 828:	learn: 0.4938473	total: 16.7s	remaining: 3.44s
# 829:	learn: 0.4938249	total: 16.7s	remaining: 3.42s
# 830:	learn: 0.4937871	total: 16.7s	remaining: 3.4s
# 831:	learn: 0.4937401	total: 16.7s	remaining: 3.37s
# 832:	learn: 0.4936911	total: 16.7s	remaining: 3.35s
# 833:	learn: 0.4936375	total: 16.7s	remaining: 3.33s
# 834:	learn: 0.4936023	total: 16.8s	remaining: 3.31s
# 835:	learn: 0.4935437	total: 16.8s	remaining: 3.29s
# 836:	learn: 0.4935037	total: 16.8s	remaining: 3.27s
# 837:	learn: 0.4934494	total: 16.8s	remaining: 3.25s
# 838:	learn: 0.4934193	total: 16.8s	remaining: 3.23s
# 839:	learn: 0.4933974	total: 16.9s	remaining: 3.21s
# 840:	learn: 0.4933592	total: 16.9s	remaining: 3.19s
# 841:	learn: 0.4933164	total: 16.9s	remaining: 3.17s
# 842:	learn: 0.4933002	total: 16.9s	remaining: 3.15s
# 843:	learn: 0.4932822	total: 16.9s	remaining: 3.13s
# 844:	learn: 0.4932170	total: 16.9s	remaining: 3.1s
# 845:	learn: 0.4931786	total: 16.9s	remaining: 3.08s
# 846:	learn: 0.4931312	total: 17s	remaining: 3.06s
# 847:	learn: 0.4930953	total: 17s	remaining: 3.04s
# 848:	learn: 0.4930734	total: 17s	remaining: 3.02s
# 849:	learn: 0.4930141	total: 17s	remaining: 3s
# 850:	learn: 0.4929623	total: 17s	remaining: 2.98s
# 851:	learn: 0.4928991	total: 17s	remaining: 2.96s
# 852:	learn: 0.4928595	total: 17s	remaining: 2.94s
# 853:	learn: 0.4928061	total: 17.1s	remaining: 2.91s
# 854:	learn: 0.4927622	total: 17.1s	remaining: 2.89s
# 855:	learn: 0.4927261	total: 17.1s	remaining: 2.87s
# 856:	learn: 0.4926885	total: 17.1s	remaining: 2.85s
# 857:	learn: 0.4926634	total: 17.1s	remaining: 2.83s
# 858:	learn: 0.4926350	total: 17.1s	remaining: 2.81s
# 859:	learn: 0.4925742	total: 17.1s	remaining: 2.79s
# 860:	learn: 0.4925428	total: 17.1s	remaining: 2.77s
# 861:	learn: 0.4925043	total: 17.1s	remaining: 2.75s
# 862:	learn: 0.4924728	total: 17.2s	remaining: 2.73s
# 863:	learn: 0.4924352	total: 17.2s	remaining: 2.7s
# 864:	learn: 0.4924062	total: 17.2s	remaining: 2.68s
# 865:	learn: 0.4923524	total: 17.2s	remaining: 2.66s
# 866:	learn: 0.4923342	total: 17.2s	remaining: 2.64s
# 867:	learn: 0.4922885	total: 17.2s	remaining: 2.62s
# 868:	learn: 0.4922605	total: 17.3s	remaining: 2.6s
# 869:	learn: 0.4922162	total: 17.3s	remaining: 2.58s
# 870:	learn: 0.4922041	total: 17.3s	remaining: 2.56s
# 871:	learn: 0.4921679	total: 17.3s	remaining: 2.54s
# 872:	learn: 0.4921017	total: 17.3s	remaining: 2.52s
# 873:	learn: 0.4920446	total: 17.3s	remaining: 2.5s
# 874:	learn: 0.4919961	total: 17.3s	remaining: 2.48s
# 875:	learn: 0.4919548	total: 17.4s	remaining: 2.46s
# 876:	learn: 0.4919398	total: 17.4s	remaining: 2.44s
# 877:	learn: 0.4918822	total: 17.4s	remaining: 2.42s
# 878:	learn: 0.4918495	total: 17.4s	remaining: 2.4s
# 879:	learn: 0.4917882	total: 17.4s	remaining: 2.38s
# 880:	learn: 0.4917280	total: 17.4s	remaining: 2.36s
# 881:	learn: 0.4916993	total: 17.5s	remaining: 2.34s
# 882:	learn: 0.4916621	total: 17.5s	remaining: 2.31s
# 883:	learn: 0.4916341	total: 17.5s	remaining: 2.29s
# 884:	learn: 0.4916069	total: 17.5s	remaining: 2.27s
# 885:	learn: 0.4915428	total: 17.5s	remaining: 2.25s
# 886:	learn: 0.4915003	total: 17.5s	remaining: 2.23s
# 887:	learn: 0.4914780	total: 17.5s	remaining: 2.21s
# 888:	learn: 0.4914343	total: 17.6s	remaining: 2.19s
# 889:	learn: 0.4913876	total: 17.6s	remaining: 2.17s
# 890:	learn: 0.4913424	total: 17.6s	remaining: 2.15s
# 891:	learn: 0.4912982	total: 17.6s	remaining: 2.13s
# 892:	learn: 0.4912517	total: 17.6s	remaining: 2.11s
# 893:	learn: 0.4912088	total: 17.6s	remaining: 2.09s
# 894:	learn: 0.4911540	total: 17.7s	remaining: 2.07s
# 895:	learn: 0.4911315	total: 17.7s	remaining: 2.05s
# 896:	learn: 0.4910934	total: 17.7s	remaining: 2.03s
# 897:	learn: 0.4910547	total: 17.7s	remaining: 2.01s
# 898:	learn: 0.4910130	total: 17.7s	remaining: 1.99s
# 899:	learn: 0.4909927	total: 17.7s	remaining: 1.97s
# 900:	learn: 0.4909481	total: 17.8s	remaining: 1.95s
# 901:	learn: 0.4908919	total: 17.8s	remaining: 1.93s
# 902:	learn: 0.4908474	total: 17.8s	remaining: 1.91s
# 903:	learn: 0.4907950	total: 17.8s	remaining: 1.89s
# 904:	learn: 0.4907582	total: 17.8s	remaining: 1.87s
# 905:	learn: 0.4907197	total: 17.9s	remaining: 1.85s
# 906:	learn: 0.4906919	total: 17.9s	remaining: 1.83s
# 907:	learn: 0.4906552	total: 17.9s	remaining: 1.81s
# 908:	learn: 0.4906243	total: 17.9s	remaining: 1.79s
# 909:	learn: 0.4905861	total: 18s	remaining: 1.77s
# 910:	learn: 0.4905447	total: 18s	remaining: 1.75s
# 911:	learn: 0.4904918	total: 18s	remaining: 1.74s
# 912:	learn: 0.4904597	total: 18s	remaining: 1.71s
# 913:	learn: 0.4903906	total: 18s	remaining: 1.69s
# 914:	learn: 0.4903661	total: 18s	remaining: 1.67s
# 915:	learn: 0.4903132	total: 18s	remaining: 1.65s
# 916:	learn: 0.4902791	total: 18.1s	remaining: 1.63s
# 917:	learn: 0.4902426	total: 18.1s	remaining: 1.61s
# 918:	learn: 0.4902118	total: 18.1s	remaining: 1.59s
# 919:	learn: 0.4901884	total: 18.1s	remaining: 1.57s
# 920:	learn: 0.4901519	total: 18.1s	remaining: 1.55s
# 921:	learn: 0.4901028	total: 18.1s	remaining: 1.53s
# 922:	learn: 0.4900693	total: 18.1s	remaining: 1.51s
# 923:	learn: 0.4900548	total: 18.2s	remaining: 1.49s
# 924:	learn: 0.4900223	total: 18.2s	remaining: 1.47s
# 925:	learn: 0.4899868	total: 18.2s	remaining: 1.45s
# 926:	learn: 0.4899414	total: 18.2s	remaining: 1.43s
# 927:	learn: 0.4899013	total: 18.2s	remaining: 1.41s
# 928:	learn: 0.4898487	total: 18.2s	remaining: 1.39s
# 929:	learn: 0.4897962	total: 18.3s	remaining: 1.37s
# 930:	learn: 0.4897437	total: 18.3s	remaining: 1.35s
# 931:	learn: 0.4897201	total: 18.3s	remaining: 1.33s
# 932:	learn: 0.4896822	total: 18.3s	remaining: 1.31s
# 933:	learn: 0.4896210	total: 18.3s	remaining: 1.3s
# 934:	learn: 0.4895897	total: 18.4s	remaining: 1.28s
# 935:	learn: 0.4895567	total: 18.4s	remaining: 1.26s
# 936:	learn: 0.4895094	total: 18.4s	remaining: 1.24s
# 937:	learn: 0.4894560	total: 18.4s	remaining: 1.22s
# 938:	learn: 0.4894068	total: 18.4s	remaining: 1.2s
# 939:	learn: 0.4893748	total: 18.5s	remaining: 1.18s
# 940:	learn: 0.4893295	total: 18.5s	remaining: 1.16s
# 941:	learn: 0.4892919	total: 18.5s	remaining: 1.14s
# 942:	learn: 0.4892487	total: 18.6s	remaining: 1.12s
# 943:	learn: 0.4892183	total: 18.7s	remaining: 1.11s
# 944:	learn: 0.4891726	total: 18.7s	remaining: 1.09s
# 945:	learn: 0.4891413	total: 18.7s	remaining: 1.07s
# 946:	learn: 0.4891006	total: 18.7s	remaining: 1.05s
# 947:	learn: 0.4890905	total: 18.7s	remaining: 1.03s
# 948:	learn: 0.4890590	total: 18.7s	remaining: 1.01s
# 949:	learn: 0.4889977	total: 18.8s	remaining: 987ms
# 950:	learn: 0.4889673	total: 18.8s	remaining: 967ms
# 951:	learn: 0.4889351	total: 18.8s	remaining: 947ms
# 952:	learn: 0.4889049	total: 18.8s	remaining: 927ms
# 953:	learn: 0.4888549	total: 18.8s	remaining: 907ms
# 954:	learn: 0.4888154	total: 18.8s	remaining: 888ms
# 955:	learn: 0.4887826	total: 18.9s	remaining: 868ms
# 956:	learn: 0.4887407	total: 18.9s	remaining: 848ms
# 957:	learn: 0.4886907	total: 18.9s	remaining: 828ms
# 958:	learn: 0.4886738	total: 18.9s	remaining: 809ms
# 959:	learn: 0.4886294	total: 18.9s	remaining: 789ms
# 960:	learn: 0.4885963	total: 19s	remaining: 769ms
# 961:	learn: 0.4885759	total: 19s	remaining: 749ms
# 962:	learn: 0.4885375	total: 19s	remaining: 730ms
# 963:	learn: 0.4884885	total: 19s	remaining: 710ms
# 964:	learn: 0.4884397	total: 19s	remaining: 690ms
# 965:	learn: 0.4883979	total: 19s	remaining: 670ms
# 966:	learn: 0.4883642	total: 19.1s	remaining: 651ms
# 967:	learn: 0.4883241	total: 19.1s	remaining: 631ms
# 968:	learn: 0.4882880	total: 19.1s	remaining: 612ms
# 969:	learn: 0.4882532	total: 19.1s	remaining: 592ms
# 970:	learn: 0.4882220	total: 19.2s	remaining: 572ms
# 971:	learn: 0.4881826	total: 19.2s	remaining: 553ms
# 972:	learn: 0.4881428	total: 19.2s	remaining: 533ms
# 973:	learn: 0.4881033	total: 19.2s	remaining: 513ms
# 974:	learn: 0.4880678	total: 19.2s	remaining: 493ms
# 975:	learn: 0.4880295	total: 19.3s	remaining: 474ms
# 976:	learn: 0.4879736	total: 19.3s	remaining: 454ms
# 977:	learn: 0.4879245	total: 19.3s	remaining: 434ms
# 978:	learn: 0.4878893	total: 19.3s	remaining: 414ms
# 979:	learn: 0.4878672	total: 19.3s	remaining: 394ms
# 980:	learn: 0.4878338	total: 19.3s	remaining: 375ms
# 981:	learn: 0.4878054	total: 19.4s	remaining: 355ms
# 982:	learn: 0.4877740	total: 19.4s	remaining: 335ms
# 983:	learn: 0.4877352	total: 19.4s	remaining: 315ms
# 984:	learn: 0.4876830	total: 19.4s	remaining: 296ms
# 985:	learn: 0.4876405	total: 19.4s	remaining: 276ms
# 986:	learn: 0.4876159	total: 19.5s	remaining: 256ms
# 987:	learn: 0.4875874	total: 19.6s	remaining: 238ms
# 988:	learn: 0.4875567	total: 19.7s	remaining: 219ms
# 989:	learn: 0.4875227	total: 19.7s	remaining: 199ms
# 990:	learn: 0.4874822	total: 19.8s	remaining: 180ms
# 991:	learn: 0.4874362	total: 19.9s	remaining: 160ms
# 992:	learn: 0.4873933	total: 19.9s	remaining: 140ms
# 993:	learn: 0.4873682	total: 20s	remaining: 121ms
# 994:	learn: 0.4873578	total: 20s	remaining: 101ms
# 995:	learn: 0.4873035	total: 20s	remaining: 80.5ms
# 996:	learn: 0.4872579	total: 20.1s	remaining: 60.5ms
# 997:	learn: 0.4872427	total: 20.1s	remaining: 40.3ms
# 998:	learn: 0.4871952	total: 20.2s	remaining: 20.2ms
# 999:	learn: 0.4871697	total: 20.2s	remaining: 0us
# Classification report for CatBoostClassifier:
#               precision    recall  f1-score   support
#
#            0       0.69      0.82      0.75     13451
#            1       0.78      0.63      0.70     13450
#
#     accuracy                           0.72     26901
#    macro avg       0.73      0.72      0.72     26901
# weighted avg       0.73      0.72      0.72     26901
#
# Confusion matrix for CatBoostClassifier:
# [[11023  2428]
#  [ 4988  8462]]
# Accuracy score for CatBoost: 0.72
# Precision score for CatBoostClassifier: 0.78
# Recall score for CatBoostClassifier: 0.63
# F1 score for CatBoostClassifier: 0.70
# Sensitivity score for CatBoostClassifier: 0.63
# Specificity score for CatBoostClassifier: 0.82
# AUC score for CatBoostClassifier: 0.78

# %%
import time
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create the FNN model
fnn_model = Sequential()
fnn_model.add(Dense(100, activation='relu', input_dim=X_train_resampled_std.shape[1]))
fnn_model.add(Dense(50, activation='relu'))
fnn_model.add(Dense(1, activation='sigmoid'))

# Compile the model
fnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
start = time.time()
fnn_model.fit(X_train_resampled_std, y_train_resampled, epochs=10, batch_size=32)
end = time.time()
print("Finished training within {:.2f} seconds".format(end - start))

# Predicting the test set results
y_ffn_prob = fnn_model.predict(X_test_resampled_std)
y_ffn = np.round(y_ffn_prob).astype(int)
# Out:
# Epoch 1/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6781 - loss: 0.5938
# Epoch 2/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7033 - loss: 0.5608
# Epoch 3/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7145 - loss: 0.5488
# Epoch 4/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7148 - loss: 0.5437
# Epoch 5/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7226 - loss: 0.5356
# Epoch 6/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7252 - loss: 0.5344
# Epoch 7/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7249 - loss: 0.5284
# Epoch 8/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7341 - loss: 0.5213
# Epoch 9/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7330 - loss: 0.5217
# Epoch 10/10
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7357 - loss: 0.5163
# Finished training within 26.90 seconds
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score

# Predicting the test set results
y_ffn_prob = fnn_model.predict(X_test_resampled_std)
y_ffn = np.round(y_ffn_prob).astype(int)

# Classification report
print("Classification report for FNN:\n{}".format(classification_report(y_test_resampled, y_ffn)))

# Confusion matrix
print("Confusion matrix for FNN:\n{}".format(confusion_matrix(y_test_resampled, y_ffn)))

# Calculate and print accuracy score
accuracy_score_ffn = accuracy_score(y_test_resampled, y_ffn)
print("Accuracy score for FNN: {:.2f}".format(accuracy_score_ffn))

# Precision, recall, and F1 scores
prec_ffn = precision_score(y_test_resampled, y_ffn)
rec_ffn = recall_score(y_test_resampled, y_ffn)
f1_ffn = f1_score(y_test_resampled, y_ffn)
print("Precision score for FNN: {:.2f}".format(prec_ffn))
print("Recall score for FNN: {:.2f}".format(rec_ffn))
print("F1 score for FNN: {:.2f}".format(f1_ffn))

# Calculate sensitivity, specificity, and AUC
def calc_sens_spec(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sens_ffn, spec_ffn = calc_sens_spec(y_test_resampled, y_ffn)
print("Sensitivity score for FNN: {:.2f}".format(sens_ffn))
print("Specificity score for FNN: {:.2f}".format(spec_ffn))

# Calculate the false positive rate, true positive rate, and AUC
fpr, tpr, _ = roc_curve(y_test_resampled, y_ffn_prob)
auc_ffn = roc_auc_score(y_test_resampled, y_ffn_prob)
print("AUC score for FNN: {:.2f}".format(auc_ffn))

# Plot the ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_ffn)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (FNN)')
ax.legend(loc="lower right")
ax.set_facecolor("white")
plt.show()
# Out:
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Classification report for FNN:
#               precision    recall  f1-score   support
#
#            0       0.67      0.85      0.75     13451
#            1       0.79      0.58      0.67     13450
#
#     accuracy                           0.71     26901
#    macro avg       0.73      0.71      0.71     26901
# weighted avg       0.73      0.71      0.71     26901
#
# Confusion matrix for FNN:
# [[11395  2056]
#  [ 5697  7753]]
# Accuracy score for FNN: 0.71
# Precision score for FNN: 0.79
# Recall score for FNN: 0.58
# F1 score for FNN: 0.67
# Sensitivity score for FNN: 0.58
# Specificity score for FNN: 0.85
# AUC score for FNN: 0.77

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

ml_names = ['SVM', 'Logistic_regression', 'GNB', 'Decision_tree', 'RF', 'eXGBoost', 'KNN', 'AdaBoost', 'FFNN', 'CatBoost']
recall_all = [rec_svm, rec_lr, rec_gnb, rec_dtree, rec_ranfor, rec_xgb, rec_knn, rec_adaboost, rec_ffn, rec_catboost]
spec_all = [spec_svm, spec_lr, spec_gnb, spec_dtree, spec_ranfor, spec_xgb, spec_knn, spec_adaboost, spec_ffn, spec_catboost]
prec_all = [prec_svm, prec_lr, prec_gnb, prec_dtree, prec_ranfor, prec_xgb, prec_knn, prec_adaboost, prec_ffn, prec_catboost]
f1_all = [f1_svm, f1_lr, f1_gnb, f1_dtree, f1_ranfor, f1_xgb, f1_knn, f1_adaboost, f1_ffn, f1_catboost]
accuracy_all = [accuracy_score_svm, accuracy_score_lr, accuracy_score_gnb, accuracy_score_dtree, accuracy_score_ranfor, accuracy_score_xgb, accuracy_score_knn, accuracy_score_adaboost, accuracy_score_ffn, accuracy_score_catboost]

def autolabel(ax, bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{:.2f}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 5),  # 3 points vertical offset
                    textcoords="offset points",
                    fontsize=12,
                    rotation=90,
                    ha='center', va='bottom')

width = 0.15  # the width of the bars
r = np.arange(len(ml_names))  # the label locations

# Plot recall, specificity, accuracy, precision, and F1 score
fig, ax = plt.subplots(figsize=(12, 8))

bar1 = ax.bar(r - 2 * width, recall_all, width, label='Recall')
bar2 = ax.bar(r - width, spec_all, width, label='Specificity')
bar3 = ax.bar(r, accuracy_all, width, label='Accuracy')
bar4 = ax.bar(r + width, prec_all, width, label='Precision')
bar5 = ax.bar(r + 2 * width, f1_all, width, label='F1')

ax.set_ylim([0, 1.15])
ax.set_ylabel('Scores', fontsize=14)
ax.set_xticks(r)
ax.set_xticklabels(ml_names)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xlabel("Machine Learning Model", fontsize=14)
ax.legend(loc='lower left', ncol=3, bbox_to_anchor=(0.25, 1), fontsize=12)

autolabel(ax, bar1)
autolabel(ax, bar2)
autolabel(ax, bar3)
autolabel(ax, bar4)
autolabel(ax, bar5)

fig.tight_layout()
fig.savefig("ml_benchmark_scores.pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
from catboost import CatBoostClassifier

def roc_auc_plot(ax, y_true, y_proba, label=' ', l='-', lw=2.0):
    if y_proba.ndim == 1:
        fpr, tpr, _ = roc_curve(y_true, y_proba)  # Use y_proba directly as it's a 1D array
    else:
        if y_proba.shape[1] > 1:
            fpr, tpr, _ = roc_curve(y_true, y_proba[:, 1])
        else:
            fpr, tpr, _ = roc_curve(y_true, y_proba)
    ax.plot(fpr, tpr, linestyle=l, linewidth=lw,
            label="%s (AUC = %.3f)" % (label, roc_auc_score(y_true, y_proba)))

f, ax = plt.subplots(figsize=(12, 8))

# Calculate and plot ROC-AUC for SVM
svm_proba = svm_model.decision_function(X_test_resampled.values)
roc_auc_plot(ax, y_test_resampled, svm_proba, label='SVM', l='-', lw=2.0)

# Calculate and plot ROC-AUC for LR
lr_proba = logit_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, lr_proba, label='Logistic regression', l='-', lw=2.0)

# Calculate and plot ROC-AUC for DT
dtree_proba = dtree_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, dtree_proba, label='Decision tree', l='-', lw=2.0)

# Calculate and plot ROC-AUC for RF
ranfor_proba = ranfor_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, ranfor_proba, label='Random forest', l='-', lw=2.0)

# Calculate and plot ROC-AUC for XGB
xgb_proba = xgb_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, xgb_proba, label='eXGBoost', l='-', lw=2.0)

# Calculate and plot ROC-AUC for KNN
knn_proba = knn_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, knn_proba, label='KNN', l='-', lw=2.0)

# Calculate and plot ROC-AUC for AdaBoost
adaboost_proba = adaboost_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, adaboost_proba, label='AdaBoost', l='-', lw=2.0)

# Calculate and plot ROC-AUC for FNN
fnn_proba = fnn_model.predict(X_test_resampled.values)
roc_auc_plot(ax, y_test_resampled, fnn_proba, label='FFNN', l='-', lw=2.0)

# Calculate and plot ROC-AUC for CatBoost
catboost_model = CatBoostClassifier()
catboost_model.fit(X_train_resampled, y_train_resampled)
catboost_proba = catboost_model.predict_proba(X_test_resampled)[:, 1]
roc_auc_plot(ax, y_test_resampled, catboost_proba, label='CatBoost', l='-', lw=2.0)

plt.plot([0, 1], [0, 1], color='k', linewidth=0.5, linestyle='--')
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operator Characteristic curves')
plt.xlim([0, 1])
plt.ylim([0, 1])

plt.show()
# Out:
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Learning rate set to 0.04751
# 0:	learn: 0.6847305	total: 38.7ms	remaining: 38.7s
# 1:	learn: 0.6763450	total: 55.7ms	remaining: 27.8s
# 2:	learn: 0.6699798	total: 72.6ms	remaining: 24.1s
# 3:	learn: 0.6638259	total: 89.4ms	remaining: 22.3s
# 4:	learn: 0.6575886	total: 106ms	remaining: 21.2s
# 5:	learn: 0.6527655	total: 124ms	remaining: 20.5s
# 6:	learn: 0.6482579	total: 140ms	remaining: 19.9s
# 7:	learn: 0.6441821	total: 173ms	remaining: 21.5s
# 8:	learn: 0.6399156	total: 218ms	remaining: 23.9s
# 9:	learn: 0.6365045	total: 236ms	remaining: 23.4s
# 10:	learn: 0.6332041	total: 252ms	remaining: 22.7s
# 11:	learn: 0.6303566	total: 264ms	remaining: 21.7s
# 12:	learn: 0.6276494	total: 277ms	remaining: 21s
# 13:	learn: 0.6253615	total: 289ms	remaining: 20.3s
# 14:	learn: 0.6229822	total: 300ms	remaining: 19.7s
# 15:	learn: 0.6210654	total: 312ms	remaining: 19.2s
# 16:	learn: 0.6191956	total: 323ms	remaining: 18.7s
# 17:	learn: 0.6171681	total: 337ms	remaining: 18.4s
# 18:	learn: 0.6153660	total: 351ms	remaining: 18.1s
# 19:	learn: 0.6136451	total: 363ms	remaining: 17.8s
# 20:	learn: 0.6121125	total: 375ms	remaining: 17.5s
# 21:	learn: 0.6105342	total: 388ms	remaining: 17.2s
# 22:	learn: 0.6091674	total: 401ms	remaining: 17s
# 23:	learn: 0.6077820	total: 414ms	remaining: 16.8s
# 24:	learn: 0.6065942	total: 428ms	remaining: 16.7s
# 25:	learn: 0.6053343	total: 488ms	remaining: 18.3s
# 26:	learn: 0.6036906	total: 520ms	remaining: 18.7s
# 27:	learn: 0.6026532	total: 546ms	remaining: 19s
# 28:	learn: 0.6016622	total: 590ms	remaining: 19.7s
# 29:	learn: 0.6006647	total: 608ms	remaining: 19.7s
# 30:	learn: 0.5990437	total: 621ms	remaining: 19.4s
# 31:	learn: 0.5978975	total: 633ms	remaining: 19.1s
# 32:	learn: 0.5966650	total: 647ms	remaining: 19s
# 33:	learn: 0.5956576	total: 660ms	remaining: 18.8s
# 34:	learn: 0.5947037	total: 682ms	remaining: 18.8s
# 35:	learn: 0.5938559	total: 698ms	remaining: 18.7s
# 36:	learn: 0.5930827	total: 710ms	remaining: 18.5s
# 37:	learn: 0.5921721	total: 723ms	remaining: 18.3s
# 38:	learn: 0.5913978	total: 736ms	remaining: 18.1s
# 39:	learn: 0.5907565	total: 748ms	remaining: 18s
# 40:	learn: 0.5896882	total: 763ms	remaining: 17.8s
# 41:	learn: 0.5886285	total: 778ms	remaining: 17.7s
# 42:	learn: 0.5879774	total: 789ms	remaining: 17.6s
# 43:	learn: 0.5873387	total: 801ms	remaining: 17.4s
# 44:	learn: 0.5864341	total: 814ms	remaining: 17.3s
# 45:	learn: 0.5857848	total: 825ms	remaining: 17.1s
# 46:	learn: 0.5847583	total: 837ms	remaining: 17s
# 47:	learn: 0.5842903	total: 849ms	remaining: 16.8s
# 48:	learn: 0.5835571	total: 862ms	remaining: 16.7s
# 49:	learn: 0.5828114	total: 879ms	remaining: 16.7s
# 50:	learn: 0.5821134	total: 897ms	remaining: 16.7s
# 51:	learn: 0.5812805	total: 909ms	remaining: 16.6s
# 52:	learn: 0.5808078	total: 921ms	remaining: 16.5s
# 53:	learn: 0.5801444	total: 933ms	remaining: 16.3s
# 54:	learn: 0.5796479	total: 945ms	remaining: 16.2s
# 55:	learn: 0.5788087	total: 957ms	remaining: 16.1s
# 56:	learn: 0.5782631	total: 970ms	remaining: 16s
# 57:	learn: 0.5777390	total: 982ms	remaining: 15.9s
# 58:	learn: 0.5772992	total: 993ms	remaining: 15.8s
# 59:	learn: 0.5766116	total: 1s	remaining: 15.7s
# 60:	learn: 0.5760999	total: 1.02s	remaining: 15.7s
# 61:	learn: 0.5757247	total: 1.03s	remaining: 15.6s
# 62:	learn: 0.5749336	total: 1.04s	remaining: 15.5s
# 63:	learn: 0.5745572	total: 1.05s	remaining: 15.4s
# 64:	learn: 0.5738973	total: 1.06s	remaining: 15.3s
# 65:	learn: 0.5733389	total: 1.08s	remaining: 15.3s
# 66:	learn: 0.5727280	total: 1.09s	remaining: 15.3s
# 67:	learn: 0.5723319	total: 1.11s	remaining: 15.2s
# 68:	learn: 0.5717083	total: 1.12s	remaining: 15.1s
# 69:	learn: 0.5712535	total: 1.13s	remaining: 15.1s
# 70:	learn: 0.5708951	total: 1.15s	remaining: 15s
# 71:	learn: 0.5704591	total: 1.16s	remaining: 14.9s
# 72:	learn: 0.5699620	total: 1.17s	remaining: 14.9s
# 73:	learn: 0.5694843	total: 1.18s	remaining: 14.8s
# 74:	learn: 0.5691030	total: 1.19s	remaining: 14.7s
# 75:	learn: 0.5684988	total: 1.21s	remaining: 14.7s
# 76:	learn: 0.5681297	total: 1.22s	remaining: 14.7s
# 77:	learn: 0.5677537	total: 1.24s	remaining: 14.6s
# 78:	learn: 0.5673111	total: 1.25s	remaining: 14.6s
# 79:	learn: 0.5669321	total: 1.26s	remaining: 14.5s
# 80:	learn: 0.5664620	total: 1.27s	remaining: 14.5s
# 81:	learn: 0.5659953	total: 1.29s	remaining: 14.5s
# 82:	learn: 0.5656898	total: 1.31s	remaining: 14.4s
# 83:	learn: 0.5653604	total: 1.32s	remaining: 14.4s
# 84:	learn: 0.5649771	total: 1.33s	remaining: 14.4s
# 85:	learn: 0.5646812	total: 1.34s	remaining: 14.3s
# 86:	learn: 0.5642520	total: 1.36s	remaining: 14.2s
# 87:	learn: 0.5638607	total: 1.37s	remaining: 14.2s
# 88:	learn: 0.5635410	total: 1.39s	remaining: 14.2s
# 89:	learn: 0.5632921	total: 1.41s	remaining: 14.2s
# 90:	learn: 0.5627801	total: 1.43s	remaining: 14.2s
# 91:	learn: 0.5623064	total: 1.44s	remaining: 14.2s
# 92:	learn: 0.5619928	total: 1.46s	remaining: 14.2s
# 93:	learn: 0.5616720	total: 1.47s	remaining: 14.2s
# 94:	learn: 0.5614269	total: 1.49s	remaining: 14.2s
# 95:	learn: 0.5611468	total: 1.51s	remaining: 14.2s
# 96:	learn: 0.5608404	total: 1.53s	remaining: 14.3s
# 97:	learn: 0.5605434	total: 1.55s	remaining: 14.3s
# 98:	learn: 0.5602624	total: 1.56s	remaining: 14.2s
# 99:	learn: 0.5598742	total: 1.58s	remaining: 14.2s
# 100:	learn: 0.5594568	total: 1.59s	remaining: 14.2s
# 101:	learn: 0.5591421	total: 1.6s	remaining: 14.1s
# 102:	learn: 0.5586742	total: 1.62s	remaining: 14.1s
# 103:	learn: 0.5585001	total: 1.63s	remaining: 14.1s
# 104:	learn: 0.5582118	total: 1.65s	remaining: 14.1s
# 105:	learn: 0.5579067	total: 1.66s	remaining: 14s
# 106:	learn: 0.5575773	total: 1.68s	remaining: 14s
# 107:	learn: 0.5571713	total: 1.69s	remaining: 14s
# 108:	learn: 0.5568545	total: 1.71s	remaining: 14s
# 109:	learn: 0.5565107	total: 1.73s	remaining: 14s
# 110:	learn: 0.5562374	total: 1.75s	remaining: 14s
# 111:	learn: 0.5558857	total: 1.77s	remaining: 14s
# 112:	learn: 0.5556333	total: 1.79s	remaining: 14s
# 113:	learn: 0.5553774	total: 1.8s	remaining: 14s
# 114:	learn: 0.5551276	total: 1.83s	remaining: 14.1s
# 115:	learn: 0.5547814	total: 1.86s	remaining: 14.2s
# 116:	learn: 0.5545317	total: 1.89s	remaining: 14.2s
# 117:	learn: 0.5541864	total: 1.91s	remaining: 14.3s
# 118:	learn: 0.5539763	total: 1.93s	remaining: 14.3s
# 119:	learn: 0.5537990	total: 1.96s	remaining: 14.4s
# 120:	learn: 0.5534920	total: 1.98s	remaining: 14.4s
# 121:	learn: 0.5531306	total: 2s	remaining: 14.4s
# 122:	learn: 0.5528480	total: 2.02s	remaining: 14.4s
# 123:	learn: 0.5525897	total: 2.06s	remaining: 14.6s
# 124:	learn: 0.5524428	total: 2.09s	remaining: 14.6s
# 125:	learn: 0.5522020	total: 2.12s	remaining: 14.7s
# 126:	learn: 0.5520735	total: 2.15s	remaining: 14.8s
# 127:	learn: 0.5517146	total: 2.19s	remaining: 14.9s
# 128:	learn: 0.5515388	total: 2.25s	remaining: 15.2s
# 129:	learn: 0.5513065	total: 2.29s	remaining: 15.3s
# 130:	learn: 0.5510305	total: 2.32s	remaining: 15.4s
# 131:	learn: 0.5508003	total: 2.38s	remaining: 15.7s
# 132:	learn: 0.5505385	total: 2.42s	remaining: 15.8s
# 133:	learn: 0.5502717	total: 2.46s	remaining: 15.9s
# 134:	learn: 0.5501770	total: 2.48s	remaining: 15.9s
# 135:	learn: 0.5499518	total: 2.5s	remaining: 15.9s
# 136:	learn: 0.5498069	total: 2.53s	remaining: 15.9s
# 137:	learn: 0.5495392	total: 2.56s	remaining: 16s
# 138:	learn: 0.5493562	total: 2.58s	remaining: 16s
# 139:	learn: 0.5490901	total: 2.6s	remaining: 16s
# 140:	learn: 0.5488913	total: 2.62s	remaining: 16s
# 141:	learn: 0.5486311	total: 2.65s	remaining: 16s
# 142:	learn: 0.5483396	total: 2.67s	remaining: 16s
# 143:	learn: 0.5481172	total: 2.69s	remaining: 16s
# 144:	learn: 0.5478054	total: 2.71s	remaining: 16s
# 145:	learn: 0.5476093	total: 2.73s	remaining: 16s
# 146:	learn: 0.5473703	total: 2.75s	remaining: 16s
# 147:	learn: 0.5472145	total: 2.77s	remaining: 15.9s
# 148:	learn: 0.5469658	total: 2.78s	remaining: 15.9s
# 149:	learn: 0.5467826	total: 2.8s	remaining: 15.9s
# 150:	learn: 0.5465910	total: 2.83s	remaining: 15.9s
# 151:	learn: 0.5463895	total: 2.85s	remaining: 15.9s
# 152:	learn: 0.5462015	total: 2.87s	remaining: 15.9s
# 153:	learn: 0.5459556	total: 2.89s	remaining: 15.9s
# 154:	learn: 0.5457883	total: 2.91s	remaining: 15.9s
# 155:	learn: 0.5455924	total: 2.93s	remaining: 15.9s
# 156:	learn: 0.5454210	total: 2.95s	remaining: 15.9s
# 157:	learn: 0.5452099	total: 2.97s	remaining: 15.8s
# 158:	learn: 0.5450314	total: 2.99s	remaining: 15.8s
# 159:	learn: 0.5449081	total: 3.01s	remaining: 15.8s
# 160:	learn: 0.5446679	total: 3.04s	remaining: 15.8s
# 161:	learn: 0.5445458	total: 3.06s	remaining: 15.8s
# 162:	learn: 0.5443987	total: 3.09s	remaining: 15.9s
# 163:	learn: 0.5442065	total: 3.13s	remaining: 16s
# 164:	learn: 0.5439812	total: 3.15s	remaining: 16s
# 165:	learn: 0.5438190	total: 3.19s	remaining: 16s
# 166:	learn: 0.5436474	total: 3.21s	remaining: 16s
# 167:	learn: 0.5435451	total: 3.23s	remaining: 16s
# 168:	learn: 0.5433403	total: 3.26s	remaining: 16s
# 169:	learn: 0.5431907	total: 3.28s	remaining: 16s
# 170:	learn: 0.5431804	total: 3.3s	remaining: 16s
# 171:	learn: 0.5429917	total: 3.32s	remaining: 16s
# 172:	learn: 0.5428033	total: 3.35s	remaining: 16s
# 173:	learn: 0.5425474	total: 3.37s	remaining: 16s
# 174:	learn: 0.5423199	total: 3.39s	remaining: 16s
# 175:	learn: 0.5421360	total: 3.41s	remaining: 16s
# 176:	learn: 0.5419794	total: 3.43s	remaining: 16s
# 177:	learn: 0.5418049	total: 3.45s	remaining: 16s
# 178:	learn: 0.5416361	total: 3.52s	remaining: 16.1s
# 179:	learn: 0.5415033	total: 3.6s	remaining: 16.4s
# 180:	learn: 0.5413460	total: 3.64s	remaining: 16.5s
# 181:	learn: 0.5412038	total: 3.69s	remaining: 16.6s
# 182:	learn: 0.5410363	total: 3.71s	remaining: 16.6s
# 183:	learn: 0.5409289	total: 3.73s	remaining: 16.6s
# 184:	learn: 0.5408123	total: 3.75s	remaining: 16.5s
# 185:	learn: 0.5405940	total: 3.78s	remaining: 16.5s
# 186:	learn: 0.5404309	total: 3.8s	remaining: 16.5s
# 187:	learn: 0.5402275	total: 3.82s	remaining: 16.5s
# 188:	learn: 0.5401467	total: 3.84s	remaining: 16.5s
# 189:	learn: 0.5399281	total: 3.86s	remaining: 16.5s
# 190:	learn: 0.5397916	total: 3.89s	remaining: 16.5s
# 191:	learn: 0.5395968	total: 3.92s	remaining: 16.5s
# 192:	learn: 0.5394745	total: 3.94s	remaining: 16.5s
# 193:	learn: 0.5392936	total: 3.96s	remaining: 16.4s
# 194:	learn: 0.5391173	total: 3.97s	remaining: 16.4s
# 195:	learn: 0.5389066	total: 3.99s	remaining: 16.4s
# 196:	learn: 0.5387841	total: 4.01s	remaining: 16.4s
# 197:	learn: 0.5386585	total: 4.04s	remaining: 16.4s
# 198:	learn: 0.5384660	total: 4.06s	remaining: 16.4s
# 199:	learn: 0.5383189	total: 4.08s	remaining: 16.3s
# 200:	learn: 0.5381249	total: 4.1s	remaining: 16.3s
# 201:	learn: 0.5379982	total: 4.12s	remaining: 16.3s
# 202:	learn: 0.5378862	total: 4.14s	remaining: 16.3s
# 203:	learn: 0.5377700	total: 4.16s	remaining: 16.2s
# 204:	learn: 0.5375928	total: 4.17s	remaining: 16.2s
# 205:	learn: 0.5374440	total: 4.19s	remaining: 16.1s
# 206:	learn: 0.5373791	total: 4.21s	remaining: 16.1s
# 207:	learn: 0.5372485	total: 4.22s	remaining: 16.1s
# 208:	learn: 0.5371297	total: 4.24s	remaining: 16s
# 209:	learn: 0.5369830	total: 4.25s	remaining: 16s
# 210:	learn: 0.5368594	total: 4.27s	remaining: 16s
# 211:	learn: 0.5367194	total: 4.29s	remaining: 16s
# 212:	learn: 0.5365634	total: 4.31s	remaining: 15.9s
# 213:	learn: 0.5363905	total: 4.34s	remaining: 15.9s
# 214:	learn: 0.5362596	total: 4.36s	remaining: 15.9s
# 215:	learn: 0.5360282	total: 4.38s	remaining: 15.9s
# 216:	learn: 0.5359501	total: 4.4s	remaining: 15.9s
# 217:	learn: 0.5358227	total: 4.42s	remaining: 15.9s
# 218:	learn: 0.5356930	total: 4.44s	remaining: 15.8s
# 219:	learn: 0.5356367	total: 4.47s	remaining: 15.8s
# 220:	learn: 0.5354811	total: 4.49s	remaining: 15.8s
# 221:	learn: 0.5353320	total: 4.52s	remaining: 15.8s
# 222:	learn: 0.5351918	total: 4.54s	remaining: 15.8s
# 223:	learn: 0.5350844	total: 4.57s	remaining: 15.8s
# 224:	learn: 0.5349581	total: 4.58s	remaining: 15.8s
# 225:	learn: 0.5348335	total: 4.61s	remaining: 15.8s
# 226:	learn: 0.5347350	total: 4.63s	remaining: 15.8s
# 227:	learn: 0.5346060	total: 4.67s	remaining: 15.8s
# 228:	learn: 0.5344856	total: 4.69s	remaining: 15.8s
# 229:	learn: 0.5343663	total: 4.73s	remaining: 15.8s
# 230:	learn: 0.5342260	total: 4.77s	remaining: 15.9s
# 231:	learn: 0.5340659	total: 4.79s	remaining: 15.9s
# 232:	learn: 0.5339854	total: 4.83s	remaining: 15.9s
# 233:	learn: 0.5339135	total: 4.86s	remaining: 15.9s
# 234:	learn: 0.5337548	total: 4.88s	remaining: 15.9s
# 235:	learn: 0.5336536	total: 4.91s	remaining: 15.9s
# 236:	learn: 0.5335609	total: 4.93s	remaining: 15.9s
# 237:	learn: 0.5334418	total: 4.95s	remaining: 15.9s
# 238:	learn: 0.5333385	total: 4.98s	remaining: 15.8s
# 239:	learn: 0.5332560	total: 5.01s	remaining: 15.9s
# 240:	learn: 0.5331366	total: 5.03s	remaining: 15.8s
# 241:	learn: 0.5329455	total: 5.05s	remaining: 15.8s
# 242:	learn: 0.5327878	total: 5.07s	remaining: 15.8s
# 243:	learn: 0.5326899	total: 5.08s	remaining: 15.7s
# 244:	learn: 0.5325786	total: 5.1s	remaining: 15.7s
# 245:	learn: 0.5324822	total: 5.11s	remaining: 15.7s
# 246:	learn: 0.5323331	total: 5.13s	remaining: 15.6s
# 247:	learn: 0.5321977	total: 5.14s	remaining: 15.6s
# 248:	learn: 0.5321212	total: 5.16s	remaining: 15.6s
# 249:	learn: 0.5319891	total: 5.18s	remaining: 15.5s
# 250:	learn: 0.5318470	total: 5.2s	remaining: 15.5s
# 251:	learn: 0.5316477	total: 5.22s	remaining: 15.5s
# 252:	learn: 0.5315510	total: 5.24s	remaining: 15.5s
# 253:	learn: 0.5314817	total: 5.26s	remaining: 15.5s
# 254:	learn: 0.5314011	total: 5.28s	remaining: 15.4s
# 255:	learn: 0.5312835	total: 5.29s	remaining: 15.4s
# 256:	learn: 0.5312057	total: 5.31s	remaining: 15.3s
# 257:	learn: 0.5310941	total: 5.32s	remaining: 15.3s
# 258:	learn: 0.5309921	total: 5.34s	remaining: 15.3s
# 259:	learn: 0.5308831	total: 5.36s	remaining: 15.3s
# 260:	learn: 0.5307779	total: 5.38s	remaining: 15.2s
# 261:	learn: 0.5307169	total: 5.39s	remaining: 15.2s
# 262:	learn: 0.5306337	total: 5.41s	remaining: 15.2s
# 263:	learn: 0.5304842	total: 5.43s	remaining: 15.1s
# 264:	learn: 0.5303802	total: 5.45s	remaining: 15.1s
# 265:	learn: 0.5302858	total: 5.48s	remaining: 15.1s
# 266:	learn: 0.5301672	total: 5.5s	remaining: 15.1s
# 267:	learn: 0.5300465	total: 5.52s	remaining: 15.1s
# 268:	learn: 0.5299452	total: 5.54s	remaining: 15.1s
# 269:	learn: 0.5298334	total: 5.56s	remaining: 15s
# 270:	learn: 0.5296568	total: 5.57s	remaining: 15s
# 271:	learn: 0.5295270	total: 5.59s	remaining: 15s
# 272:	learn: 0.5294295	total: 5.6s	remaining: 14.9s
# 273:	learn: 0.5292947	total: 5.62s	remaining: 14.9s
# 274:	learn: 0.5291898	total: 5.63s	remaining: 14.9s
# 275:	learn: 0.5290472	total: 5.65s	remaining: 14.8s
# 276:	learn: 0.5289574	total: 5.67s	remaining: 14.8s
# 277:	learn: 0.5288466	total: 5.69s	remaining: 14.8s
# 278:	learn: 0.5286551	total: 5.71s	remaining: 14.8s
# 279:	learn: 0.5285139	total: 5.75s	remaining: 14.8s
# 280:	learn: 0.5284236	total: 5.77s	remaining: 14.8s
# 281:	learn: 0.5283150	total: 5.79s	remaining: 14.7s
# 282:	learn: 0.5281676	total: 5.8s	remaining: 14.7s
# 283:	learn: 0.5280184	total: 5.82s	remaining: 14.7s
# 284:	learn: 0.5279002	total: 5.84s	remaining: 14.7s
# 285:	learn: 0.5277868	total: 5.86s	remaining: 14.6s
# 286:	learn: 0.5276254	total: 5.88s	remaining: 14.6s
# 287:	learn: 0.5275386	total: 5.89s	remaining: 14.6s
# 288:	learn: 0.5273591	total: 5.93s	remaining: 14.6s
# 289:	learn: 0.5272620	total: 5.94s	remaining: 14.6s
# 290:	learn: 0.5271652	total: 5.96s	remaining: 14.5s
# 291:	learn: 0.5270797	total: 5.98s	remaining: 14.5s
# 292:	learn: 0.5269919	total: 6.02s	remaining: 14.5s
# 293:	learn: 0.5268948	total: 6.07s	remaining: 14.6s
# 294:	learn: 0.5267823	total: 6.09s	remaining: 14.5s
# 295:	learn: 0.5266535	total: 6.1s	remaining: 14.5s
# 296:	learn: 0.5265266	total: 6.12s	remaining: 14.5s
# 297:	learn: 0.5263995	total: 6.14s	remaining: 14.5s
# 298:	learn: 0.5262882	total: 6.15s	remaining: 14.4s
# 299:	learn: 0.5261918	total: 6.17s	remaining: 14.4s
# 300:	learn: 0.5261041	total: 6.18s	remaining: 14.4s
# 301:	learn: 0.5259900	total: 6.19s	remaining: 14.3s
# 302:	learn: 0.5258824	total: 6.21s	remaining: 14.3s
# 303:	learn: 0.5257974	total: 6.22s	remaining: 14.2s
# 304:	learn: 0.5257206	total: 6.23s	remaining: 14.2s
# 305:	learn: 0.5256369	total: 6.24s	remaining: 14.2s
# 306:	learn: 0.5255194	total: 6.26s	remaining: 14.1s
# 307:	learn: 0.5254211	total: 6.27s	remaining: 14.1s
# 308:	learn: 0.5253117	total: 6.28s	remaining: 14s
# 309:	learn: 0.5252343	total: 6.29s	remaining: 14s
# 310:	learn: 0.5251337	total: 6.31s	remaining: 14s
# 311:	learn: 0.5250362	total: 6.33s	remaining: 13.9s
# 312:	learn: 0.5249366	total: 6.38s	remaining: 14s
# 313:	learn: 0.5248530	total: 6.43s	remaining: 14.1s
# 314:	learn: 0.5247403	total: 6.48s	remaining: 14.1s
# 315:	learn: 0.5246317	total: 6.5s	remaining: 14.1s
# 316:	learn: 0.5245653	total: 6.51s	remaining: 14s
# 317:	learn: 0.5244238	total: 6.53s	remaining: 14s
# 318:	learn: 0.5242983	total: 6.55s	remaining: 14s
# 319:	learn: 0.5242197	total: 6.57s	remaining: 14s
# 320:	learn: 0.5241502	total: 6.59s	remaining: 13.9s
# 321:	learn: 0.5240245	total: 6.6s	remaining: 13.9s
# 322:	learn: 0.5239126	total: 6.62s	remaining: 13.9s
# 323:	learn: 0.5238560	total: 6.63s	remaining: 13.8s
# 324:	learn: 0.5237762	total: 6.65s	remaining: 13.8s
# 325:	learn: 0.5236855	total: 6.67s	remaining: 13.8s
# 326:	learn: 0.5235738	total: 6.68s	remaining: 13.8s
# 327:	learn: 0.5234450	total: 6.7s	remaining: 13.7s
# 328:	learn: 0.5233557	total: 6.72s	remaining: 13.7s
# 329:	learn: 0.5232601	total: 6.75s	remaining: 13.7s
# 330:	learn: 0.5231621	total: 6.77s	remaining: 13.7s
# 331:	learn: 0.5230728	total: 6.79s	remaining: 13.7s
# 332:	learn: 0.5230209	total: 6.81s	remaining: 13.6s
# 333:	learn: 0.5229283	total: 6.83s	remaining: 13.6s
# 334:	learn: 0.5228109	total: 6.84s	remaining: 13.6s
# 335:	learn: 0.5226660	total: 6.86s	remaining: 13.6s
# 336:	learn: 0.5225724	total: 6.88s	remaining: 13.5s
# 337:	learn: 0.5224645	total: 6.9s	remaining: 13.5s
# 338:	learn: 0.5223560	total: 6.94s	remaining: 13.5s
# 339:	learn: 0.5222651	total: 6.97s	remaining: 13.5s
# 340:	learn: 0.5222022	total: 7.01s	remaining: 13.5s
# 341:	learn: 0.5221392	total: 7.03s	remaining: 13.5s
# 342:	learn: 0.5220521	total: 7.05s	remaining: 13.5s
# 343:	learn: 0.5219426	total: 7.08s	remaining: 13.5s
# 344:	learn: 0.5218341	total: 7.11s	remaining: 13.5s
# 345:	learn: 0.5217279	total: 7.14s	remaining: 13.5s
# 346:	learn: 0.5216269	total: 7.17s	remaining: 13.5s
# 347:	learn: 0.5215354	total: 7.19s	remaining: 13.5s
# 348:	learn: 0.5214604	total: 7.21s	remaining: 13.5s
# 349:	learn: 0.5213952	total: 7.23s	remaining: 13.4s
# 350:	learn: 0.5213414	total: 7.25s	remaining: 13.4s
# 351:	learn: 0.5212381	total: 7.28s	remaining: 13.4s
# 352:	learn: 0.5211481	total: 7.31s	remaining: 13.4s
# 353:	learn: 0.5210670	total: 7.33s	remaining: 13.4s
# 354:	learn: 0.5209659	total: 7.36s	remaining: 13.4s
# 355:	learn: 0.5208732	total: 7.39s	remaining: 13.4s
# 356:	learn: 0.5208021	total: 7.42s	remaining: 13.4s
# 357:	learn: 0.5207023	total: 7.44s	remaining: 13.3s
# 358:	learn: 0.5206146	total: 7.46s	remaining: 13.3s
# 359:	learn: 0.5204995	total: 7.48s	remaining: 13.3s
# 360:	learn: 0.5203971	total: 7.51s	remaining: 13.3s
# 361:	learn: 0.5203232	total: 7.54s	remaining: 13.3s
# 362:	learn: 0.5202085	total: 7.57s	remaining: 13.3s
# 363:	learn: 0.5201423	total: 7.59s	remaining: 13.3s
# 364:	learn: 0.5200583	total: 7.61s	remaining: 13.2s
# 365:	learn: 0.5199750	total: 7.63s	remaining: 13.2s
# 366:	learn: 0.5198972	total: 7.65s	remaining: 13.2s
# 367:	learn: 0.5197954	total: 7.67s	remaining: 13.2s
# 368:	learn: 0.5196952	total: 7.68s	remaining: 13.1s
# 369:	learn: 0.5196098	total: 7.69s	remaining: 13.1s
# 370:	learn: 0.5195178	total: 7.7s	remaining: 13.1s
# 371:	learn: 0.5194360	total: 7.72s	remaining: 13s
# 372:	learn: 0.5193344	total: 7.73s	remaining: 13s
# 373:	learn: 0.5192262	total: 7.74s	remaining: 13s
# 374:	learn: 0.5191393	total: 7.75s	remaining: 12.9s
# 375:	learn: 0.5190628	total: 7.76s	remaining: 12.9s
# 376:	learn: 0.5189946	total: 7.78s	remaining: 12.8s
# 377:	learn: 0.5189242	total: 7.79s	remaining: 12.8s
# 378:	learn: 0.5188305	total: 7.8s	remaining: 12.8s
# 379:	learn: 0.5187457	total: 7.81s	remaining: 12.7s
# 380:	learn: 0.5186404	total: 7.82s	remaining: 12.7s
# 381:	learn: 0.5185884	total: 7.84s	remaining: 12.7s
# 382:	learn: 0.5184930	total: 7.86s	remaining: 12.7s
# 383:	learn: 0.5184170	total: 7.88s	remaining: 12.6s
# 384:	learn: 0.5183340	total: 7.89s	remaining: 12.6s
# 385:	learn: 0.5182426	total: 7.91s	remaining: 12.6s
# 386:	learn: 0.5181680	total: 7.92s	remaining: 12.6s
# 387:	learn: 0.5180811	total: 7.94s	remaining: 12.5s
# 388:	learn: 0.5179910	total: 7.96s	remaining: 12.5s
# 389:	learn: 0.5179181	total: 7.97s	remaining: 12.5s
# 390:	learn: 0.5178122	total: 7.99s	remaining: 12.4s
# 391:	learn: 0.5177161	total: 8s	remaining: 12.4s
# 392:	learn: 0.5176404	total: 8.02s	remaining: 12.4s
# 393:	learn: 0.5175695	total: 8.04s	remaining: 12.4s
# 394:	learn: 0.5174948	total: 8.05s	remaining: 12.3s
# 395:	learn: 0.5174006	total: 8.08s	remaining: 12.3s
# 396:	learn: 0.5173232	total: 8.1s	remaining: 12.3s
# 397:	learn: 0.5172300	total: 8.11s	remaining: 12.3s
# 398:	learn: 0.5171413	total: 8.12s	remaining: 12.2s
# 399:	learn: 0.5170726	total: 8.13s	remaining: 12.2s
# 400:	learn: 0.5170079	total: 8.15s	remaining: 12.2s
# 401:	learn: 0.5169231	total: 8.16s	remaining: 12.1s
# 402:	learn: 0.5168813	total: 8.17s	remaining: 12.1s
# 403:	learn: 0.5167964	total: 8.18s	remaining: 12.1s
# 404:	learn: 0.5167140	total: 8.19s	remaining: 12s
# 405:	learn: 0.5166575	total: 8.21s	remaining: 12s
# 406:	learn: 0.5166042	total: 8.22s	remaining: 12s
# 407:	learn: 0.5165436	total: 8.23s	remaining: 11.9s
# 408:	learn: 0.5164796	total: 8.24s	remaining: 11.9s
# 409:	learn: 0.5164102	total: 8.25s	remaining: 11.9s
# 410:	learn: 0.5163520	total: 8.26s	remaining: 11.8s
# 411:	learn: 0.5162678	total: 8.28s	remaining: 11.8s
# 412:	learn: 0.5161877	total: 8.29s	remaining: 11.8s
# 413:	learn: 0.5161291	total: 8.3s	remaining: 11.8s
# 414:	learn: 0.5160890	total: 8.32s	remaining: 11.7s
# 415:	learn: 0.5160052	total: 8.33s	remaining: 11.7s
# 416:	learn: 0.5159318	total: 8.34s	remaining: 11.7s
# 417:	learn: 0.5158569	total: 8.35s	remaining: 11.6s
# 418:	learn: 0.5157971	total: 8.37s	remaining: 11.6s
# 419:	learn: 0.5157189	total: 8.38s	remaining: 11.6s
# 420:	learn: 0.5156505	total: 8.39s	remaining: 11.5s
# 421:	learn: 0.5155930	total: 8.4s	remaining: 11.5s
# 422:	learn: 0.5155067	total: 8.41s	remaining: 11.5s
# 423:	learn: 0.5154431	total: 8.43s	remaining: 11.4s
# 424:	learn: 0.5153389	total: 8.44s	remaining: 11.4s
# 425:	learn: 0.5152436	total: 8.45s	remaining: 11.4s
# 426:	learn: 0.5151761	total: 8.46s	remaining: 11.4s
# 427:	learn: 0.5150892	total: 8.47s	remaining: 11.3s
# 428:	learn: 0.5150174	total: 8.49s	remaining: 11.3s
# 429:	learn: 0.5149666	total: 8.5s	remaining: 11.3s
# 430:	learn: 0.5148931	total: 8.52s	remaining: 11.2s
# 431:	learn: 0.5148078	total: 8.53s	remaining: 11.2s
# 432:	learn: 0.5147256	total: 8.54s	remaining: 11.2s
# 433:	learn: 0.5146501	total: 8.56s	remaining: 11.2s
# 434:	learn: 0.5145803	total: 8.58s	remaining: 11.1s
# 435:	learn: 0.5145226	total: 8.6s	remaining: 11.1s
# 436:	learn: 0.5144546	total: 8.61s	remaining: 11.1s
# 437:	learn: 0.5143861	total: 8.63s	remaining: 11.1s
# 438:	learn: 0.5143372	total: 8.64s	remaining: 11s
# 439:	learn: 0.5142594	total: 8.66s	remaining: 11s
# 440:	learn: 0.5141849	total: 8.67s	remaining: 11s
# 441:	learn: 0.5141207	total: 8.69s	remaining: 11s
# 442:	learn: 0.5140378	total: 8.71s	remaining: 10.9s
# 443:	learn: 0.5139603	total: 8.73s	remaining: 10.9s
# 444:	learn: 0.5138955	total: 8.79s	remaining: 11s
# 445:	learn: 0.5138198	total: 8.81s	remaining: 10.9s
# 446:	learn: 0.5137714	total: 8.84s	remaining: 10.9s
# 447:	learn: 0.5136676	total: 8.88s	remaining: 10.9s
# 448:	learn: 0.5136191	total: 8.96s	remaining: 11s
# 449:	learn: 0.5135438	total: 8.97s	remaining: 11s
# 450:	learn: 0.5134670	total: 9s	remaining: 11s
# 451:	learn: 0.5133848	total: 9.03s	remaining: 10.9s
# 452:	learn: 0.5133242	total: 9.05s	remaining: 10.9s
# 453:	learn: 0.5132517	total: 9.07s	remaining: 10.9s
# 454:	learn: 0.5132054	total: 9.08s	remaining: 10.9s
# 455:	learn: 0.5131317	total: 9.1s	remaining: 10.9s
# 456:	learn: 0.5130872	total: 9.11s	remaining: 10.8s
# 457:	learn: 0.5130111	total: 9.12s	remaining: 10.8s
# 458:	learn: 0.5129248	total: 9.14s	remaining: 10.8s
# 459:	learn: 0.5128520	total: 9.15s	remaining: 10.7s
# 460:	learn: 0.5128076	total: 9.16s	remaining: 10.7s
# 461:	learn: 0.5127418	total: 9.18s	remaining: 10.7s
# 462:	learn: 0.5126574	total: 9.2s	remaining: 10.7s
# 463:	learn: 0.5125830	total: 9.21s	remaining: 10.6s
# 464:	learn: 0.5125188	total: 9.22s	remaining: 10.6s
# 465:	learn: 0.5124517	total: 9.23s	remaining: 10.6s
# 466:	learn: 0.5123714	total: 9.25s	remaining: 10.6s
# 467:	learn: 0.5123158	total: 9.26s	remaining: 10.5s
# 468:	learn: 0.5122407	total: 9.27s	remaining: 10.5s
# 469:	learn: 0.5121652	total: 9.29s	remaining: 10.5s
# 470:	learn: 0.5121340	total: 9.3s	remaining: 10.4s
# 471:	learn: 0.5120781	total: 9.31s	remaining: 10.4s
# 472:	learn: 0.5120010	total: 9.32s	remaining: 10.4s
# 473:	learn: 0.5119243	total: 9.34s	remaining: 10.4s
# 474:	learn: 0.5118684	total: 9.35s	remaining: 10.3s
# 475:	learn: 0.5118138	total: 9.36s	remaining: 10.3s
# 476:	learn: 0.5117465	total: 9.37s	remaining: 10.3s
# 477:	learn: 0.5117102	total: 9.39s	remaining: 10.3s
# 478:	learn: 0.5116306	total: 9.41s	remaining: 10.2s
# 479:	learn: 0.5115712	total: 9.42s	remaining: 10.2s
# 480:	learn: 0.5114819	total: 9.43s	remaining: 10.2s
# 481:	learn: 0.5114085	total: 9.45s	remaining: 10.2s
# 482:	learn: 0.5113396	total: 9.46s	remaining: 10.1s
# 483:	learn: 0.5112839	total: 9.47s	remaining: 10.1s
# 484:	learn: 0.5112192	total: 9.49s	remaining: 10.1s
# 485:	learn: 0.5111769	total: 9.5s	remaining: 10s
# 486:	learn: 0.5111102	total: 9.51s	remaining: 10s
# 487:	learn: 0.5110199	total: 9.52s	remaining: 9.99s
# 488:	learn: 0.5109511	total: 9.54s	remaining: 9.96s
# 489:	learn: 0.5108763	total: 9.55s	remaining: 9.94s
# 490:	learn: 0.5108178	total: 9.56s	remaining: 9.91s
# 491:	learn: 0.5107413	total: 9.57s	remaining: 9.89s
# 492:	learn: 0.5106440	total: 9.59s	remaining: 9.86s
# 493:	learn: 0.5105819	total: 9.6s	remaining: 9.83s
# 494:	learn: 0.5105079	total: 9.62s	remaining: 9.81s
# 495:	learn: 0.5104471	total: 9.63s	remaining: 9.79s
# 496:	learn: 0.5103772	total: 9.64s	remaining: 9.76s
# 497:	learn: 0.5103071	total: 9.66s	remaining: 9.74s
# 498:	learn: 0.5102324	total: 9.67s	remaining: 9.71s
# 499:	learn: 0.5101534	total: 9.68s	remaining: 9.68s
# 500:	learn: 0.5100969	total: 9.7s	remaining: 9.66s
# 501:	learn: 0.5100690	total: 9.71s	remaining: 9.63s
# 502:	learn: 0.5100061	total: 9.72s	remaining: 9.61s
# 503:	learn: 0.5099523	total: 9.73s	remaining: 9.58s
# 504:	learn: 0.5098886	total: 9.75s	remaining: 9.55s
# 505:	learn: 0.5098016	total: 9.76s	remaining: 9.53s
# 506:	learn: 0.5097369	total: 9.77s	remaining: 9.5s
# 507:	learn: 0.5096948	total: 9.79s	remaining: 9.48s
# 508:	learn: 0.5096368	total: 9.81s	remaining: 9.46s
# 509:	learn: 0.5095914	total: 9.83s	remaining: 9.44s
# 510:	learn: 0.5095204	total: 9.86s	remaining: 9.43s
# 511:	learn: 0.5094344	total: 9.88s	remaining: 9.41s
# 512:	learn: 0.5093781	total: 9.89s	remaining: 9.39s
# 513:	learn: 0.5093201	total: 9.91s	remaining: 9.37s
# 514:	learn: 0.5092320	total: 9.93s	remaining: 9.35s
# 515:	learn: 0.5091675	total: 9.95s	remaining: 9.33s
# 516:	learn: 0.5091195	total: 9.96s	remaining: 9.3s
# 517:	learn: 0.5090801	total: 9.97s	remaining: 9.28s
# 518:	learn: 0.5090315	total: 9.98s	remaining: 9.25s
# 519:	learn: 0.5089800	total: 10s	remaining: 9.24s
# 520:	learn: 0.5089081	total: 10s	remaining: 9.21s
# 521:	learn: 0.5088540	total: 10s	remaining: 9.19s
# 522:	learn: 0.5087904	total: 10.1s	remaining: 9.18s
# 523:	learn: 0.5087225	total: 10.1s	remaining: 9.16s
# 524:	learn: 0.5086595	total: 10.1s	remaining: 9.14s
# 525:	learn: 0.5086035	total: 10.1s	remaining: 9.12s
# 526:	learn: 0.5085671	total: 10.1s	remaining: 9.1s
# 527:	learn: 0.5084952	total: 10.2s	remaining: 9.07s
# 528:	learn: 0.5084260	total: 10.2s	remaining: 9.05s
# 529:	learn: 0.5083585	total: 10.2s	remaining: 9.03s
# 530:	learn: 0.5083033	total: 10.2s	remaining: 9.01s
# 531:	learn: 0.5082557	total: 10.2s	remaining: 8.99s
# 532:	learn: 0.5081859	total: 10.2s	remaining: 8.97s
# 533:	learn: 0.5081384	total: 10.3s	remaining: 8.96s
# 534:	learn: 0.5080863	total: 10.3s	remaining: 8.94s
# 535:	learn: 0.5080458	total: 10.3s	remaining: 8.92s
# 536:	learn: 0.5079938	total: 10.3s	remaining: 8.9s
# 537:	learn: 0.5079364	total: 10.3s	remaining: 8.88s
# 538:	learn: 0.5078685	total: 10.4s	remaining: 8.87s
# 539:	learn: 0.5077988	total: 10.4s	remaining: 8.84s
# 540:	learn: 0.5077198	total: 10.4s	remaining: 8.82s
# 541:	learn: 0.5076723	total: 10.4s	remaining: 8.8s
# 542:	learn: 0.5076068	total: 10.4s	remaining: 8.77s
# 543:	learn: 0.5075568	total: 10.4s	remaining: 8.75s
# 544:	learn: 0.5075149	total: 10.4s	remaining: 8.72s
# 545:	learn: 0.5074351	total: 10.5s	remaining: 8.7s
# 546:	learn: 0.5074007	total: 10.5s	remaining: 8.67s
# 547:	learn: 0.5073626	total: 10.5s	remaining: 8.65s
# 548:	learn: 0.5072832	total: 10.5s	remaining: 8.63s
# 549:	learn: 0.5072247	total: 10.5s	remaining: 8.61s
# 550:	learn: 0.5071689	total: 10.5s	remaining: 8.59s
# 551:	learn: 0.5071289	total: 10.6s	remaining: 8.56s
# 552:	learn: 0.5070808	total: 10.6s	remaining: 8.54s
# 553:	learn: 0.5070074	total: 10.6s	remaining: 8.52s
# 554:	learn: 0.5069288	total: 10.6s	remaining: 8.5s
# 555:	learn: 0.5068609	total: 10.6s	remaining: 8.48s
# 556:	learn: 0.5068002	total: 10.6s	remaining: 8.46s
# 557:	learn: 0.5067718	total: 10.7s	remaining: 8.44s
# 558:	learn: 0.5067047	total: 10.7s	remaining: 8.42s
# 559:	learn: 0.5066433	total: 10.7s	remaining: 8.4s
# 560:	learn: 0.5065861	total: 10.7s	remaining: 8.38s
# 561:	learn: 0.5065320	total: 10.7s	remaining: 8.36s
# 562:	learn: 0.5064727	total: 10.8s	remaining: 8.34s
# 563:	learn: 0.5064216	total: 10.8s	remaining: 8.32s
# 564:	learn: 0.5063768	total: 10.8s	remaining: 8.3s
# 565:	learn: 0.5063227	total: 10.8s	remaining: 8.28s
# 566:	learn: 0.5062642	total: 10.8s	remaining: 8.26s
# 567:	learn: 0.5062131	total: 10.8s	remaining: 8.24s
# 568:	learn: 0.5061618	total: 10.9s	remaining: 8.22s
# 569:	learn: 0.5061155	total: 10.9s	remaining: 8.2s
# 570:	learn: 0.5060741	total: 10.9s	remaining: 8.18s
# 571:	learn: 0.5060201	total: 10.9s	remaining: 8.16s
# 572:	learn: 0.5059422	total: 10.9s	remaining: 8.14s
# 573:	learn: 0.5059054	total: 10.9s	remaining: 8.12s
# 574:	learn: 0.5058548	total: 11s	remaining: 8.1s
# 575:	learn: 0.5057975	total: 11s	remaining: 8.08s
# 576:	learn: 0.5057474	total: 11s	remaining: 8.06s
# 577:	learn: 0.5056753	total: 11s	remaining: 8.04s
# 578:	learn: 0.5056198	total: 11s	remaining: 8.02s
# 579:	learn: 0.5055640	total: 11s	remaining: 8s
# 580:	learn: 0.5054968	total: 11.1s	remaining: 7.97s
# 581:	learn: 0.5054335	total: 11.1s	remaining: 7.95s
# 582:	learn: 0.5053857	total: 11.1s	remaining: 7.93s
# 583:	learn: 0.5053372	total: 11.1s	remaining: 7.91s
# 584:	learn: 0.5053015	total: 11.1s	remaining: 7.88s
# 585:	learn: 0.5052602	total: 11.1s	remaining: 7.86s
# 586:	learn: 0.5052081	total: 11.1s	remaining: 7.84s
# 587:	learn: 0.5051423	total: 11.2s	remaining: 7.82s
# 588:	learn: 0.5051090	total: 11.2s	remaining: 7.8s
# 589:	learn: 0.5050387	total: 11.2s	remaining: 7.78s
# 590:	learn: 0.5049982	total: 11.2s	remaining: 7.75s
# 591:	learn: 0.5049369	total: 11.2s	remaining: 7.73s
# 592:	learn: 0.5048828	total: 11.2s	remaining: 7.71s
# 593:	learn: 0.5048280	total: 11.2s	remaining: 7.68s
# 594:	learn: 0.5047487	total: 11.3s	remaining: 7.66s
# 595:	learn: 0.5047087	total: 11.3s	remaining: 7.64s
# 596:	learn: 0.5046566	total: 11.3s	remaining: 7.62s
# 597:	learn: 0.5045782	total: 11.3s	remaining: 7.59s
# 598:	learn: 0.5045103	total: 11.3s	remaining: 7.57s
# 599:	learn: 0.5044540	total: 11.3s	remaining: 7.55s
# 600:	learn: 0.5044185	total: 11.3s	remaining: 7.53s
# 601:	learn: 0.5043758	total: 11.4s	remaining: 7.51s
# 602:	learn: 0.5043283	total: 11.4s	remaining: 7.49s
# 603:	learn: 0.5042539	total: 11.4s	remaining: 7.47s
# 604:	learn: 0.5042052	total: 11.4s	remaining: 7.45s
# 605:	learn: 0.5041418	total: 11.4s	remaining: 7.43s
# 606:	learn: 0.5040774	total: 11.5s	remaining: 7.41s
# 607:	learn: 0.5040214	total: 11.5s	remaining: 7.39s
# 608:	learn: 0.5039514	total: 11.5s	remaining: 7.37s
# 609:	learn: 0.5039183	total: 11.5s	remaining: 7.35s
# 610:	learn: 0.5038703	total: 11.5s	remaining: 7.33s
# 611:	learn: 0.5038341	total: 11.5s	remaining: 7.31s
# 612:	learn: 0.5037679	total: 11.5s	remaining: 7.29s
# 613:	learn: 0.5036891	total: 11.6s	remaining: 7.27s
# 614:	learn: 0.5036476	total: 11.6s	remaining: 7.25s
# 615:	learn: 0.5036323	total: 11.6s	remaining: 7.23s
# 616:	learn: 0.5035870	total: 11.6s	remaining: 7.21s
# 617:	learn: 0.5035258	total: 11.6s	remaining: 7.19s
# 618:	learn: 0.5034855	total: 11.6s	remaining: 7.17s
# 619:	learn: 0.5034420	total: 11.7s	remaining: 7.14s
# 620:	learn: 0.5034099	total: 11.7s	remaining: 7.12s
# 621:	learn: 0.5033646	total: 11.7s	remaining: 7.1s
# 622:	learn: 0.5033265	total: 11.7s	remaining: 7.08s
# 623:	learn: 0.5032743	total: 11.7s	remaining: 7.06s
# 624:	learn: 0.5032303	total: 11.7s	remaining: 7.04s
# 625:	learn: 0.5032086	total: 11.8s	remaining: 7.02s
# 626:	learn: 0.5031450	total: 11.8s	remaining: 7s
# 627:	learn: 0.5031114	total: 11.8s	remaining: 6.98s
# 628:	learn: 0.5030805	total: 11.8s	remaining: 6.96s
# 629:	learn: 0.5030481	total: 11.8s	remaining: 6.95s
# 630:	learn: 0.5029932	total: 11.8s	remaining: 6.92s
# 631:	learn: 0.5029532	total: 11.9s	remaining: 6.91s
# 632:	learn: 0.5028790	total: 11.9s	remaining: 6.88s
# 633:	learn: 0.5028220	total: 11.9s	remaining: 6.86s
# 634:	learn: 0.5027629	total: 11.9s	remaining: 6.84s
# 635:	learn: 0.5027073	total: 11.9s	remaining: 6.82s
# 636:	learn: 0.5026598	total: 11.9s	remaining: 6.8s
# 637:	learn: 0.5025978	total: 11.9s	remaining: 6.78s
# 638:	learn: 0.5025396	total: 12s	remaining: 6.75s
# 639:	learn: 0.5024950	total: 12s	remaining: 6.73s
# 640:	learn: 0.5024460	total: 12s	remaining: 6.71s
# 641:	learn: 0.5023875	total: 12s	remaining: 6.69s
# 642:	learn: 0.5023320	total: 12s	remaining: 6.67s
# 643:	learn: 0.5022758	total: 12s	remaining: 6.65s
# 644:	learn: 0.5022495	total: 12s	remaining: 6.63s
# 645:	learn: 0.5022008	total: 12.1s	remaining: 6.64s
# 646:	learn: 0.5021690	total: 12.2s	remaining: 6.67s
# 647:	learn: 0.5021245	total: 12.3s	remaining: 6.67s
# 648:	learn: 0.5021033	total: 12.3s	remaining: 6.66s
# 649:	learn: 0.5020545	total: 12.4s	remaining: 6.66s
# 650:	learn: 0.5019729	total: 12.4s	remaining: 6.67s
# 651:	learn: 0.5019039	total: 12.5s	remaining: 6.66s
# 652:	learn: 0.5018616	total: 12.5s	remaining: 6.66s
# 653:	learn: 0.5018032	total: 12.6s	remaining: 6.67s
# 654:	learn: 0.5017964	total: 12.7s	remaining: 6.66s
# 655:	learn: 0.5017238	total: 12.7s	remaining: 6.67s
# 656:	learn: 0.5016754	total: 12.8s	remaining: 6.69s
# 657:	learn: 0.5015963	total: 12.8s	remaining: 6.68s
# 658:	learn: 0.5015540	total: 12.9s	remaining: 6.66s
# 659:	learn: 0.5014989	total: 12.9s	remaining: 6.66s
# 660:	learn: 0.5014540	total: 12.9s	remaining: 6.64s
# 661:	learn: 0.5013956	total: 13s	remaining: 6.62s
# 662:	learn: 0.5013654	total: 13s	remaining: 6.6s
# 663:	learn: 0.5013227	total: 13s	remaining: 6.58s
# 664:	learn: 0.5012657	total: 13s	remaining: 6.56s
# 665:	learn: 0.5012243	total: 13s	remaining: 6.54s
# 666:	learn: 0.5011928	total: 13.1s	remaining: 6.52s
# 667:	learn: 0.5011671	total: 13.1s	remaining: 6.5s
# 668:	learn: 0.5011288	total: 13.1s	remaining: 6.48s
# 669:	learn: 0.5010838	total: 13.1s	remaining: 6.46s
# 670:	learn: 0.5010568	total: 13.1s	remaining: 6.44s
# 671:	learn: 0.5009860	total: 13.2s	remaining: 6.43s
# 672:	learn: 0.5009378	total: 13.2s	remaining: 6.41s
# 673:	learn: 0.5008992	total: 13.2s	remaining: 6.39s
# 674:	learn: 0.5008579	total: 13.2s	remaining: 6.37s
# 675:	learn: 0.5007898	total: 13.2s	remaining: 6.35s
# 676:	learn: 0.5007330	total: 13.3s	remaining: 6.33s
# 677:	learn: 0.5006750	total: 13.3s	remaining: 6.31s
# 678:	learn: 0.5006438	total: 13.3s	remaining: 6.29s
# 679:	learn: 0.5005944	total: 13.3s	remaining: 6.27s
# 680:	learn: 0.5005520	total: 13.3s	remaining: 6.25s
# 681:	learn: 0.5005094	total: 13.3s	remaining: 6.22s
# 682:	learn: 0.5004683	total: 13.4s	remaining: 6.2s
# 683:	learn: 0.5004001	total: 13.4s	remaining: 6.18s
# 684:	learn: 0.5003626	total: 13.4s	remaining: 6.16s
# 685:	learn: 0.5003336	total: 13.4s	remaining: 6.13s
# 686:	learn: 0.5002749	total: 13.4s	remaining: 6.11s
# 687:	learn: 0.5002593	total: 13.4s	remaining: 6.09s
# 688:	learn: 0.5002094	total: 13.4s	remaining: 6.07s
# 689:	learn: 0.5001584	total: 13.5s	remaining: 6.04s
# 690:	learn: 0.5001179	total: 13.5s	remaining: 6.02s
# 691:	learn: 0.5000692	total: 13.5s	remaining: 6s
# 692:	learn: 0.5000013	total: 13.5s	remaining: 5.98s
# 693:	learn: 0.4999640	total: 13.5s	remaining: 5.96s
# 694:	learn: 0.4999489	total: 13.5s	remaining: 5.93s
# 695:	learn: 0.4998913	total: 13.5s	remaining: 5.91s
# 696:	learn: 0.4998337	total: 13.5s	remaining: 5.89s
# 697:	learn: 0.4998050	total: 13.6s	remaining: 5.87s
# 698:	learn: 0.4997443	total: 13.6s	remaining: 5.84s
# 699:	learn: 0.4997034	total: 13.6s	remaining: 5.82s
# 700:	learn: 0.4996845	total: 13.6s	remaining: 5.8s
# 701:	learn: 0.4996256	total: 13.6s	remaining: 5.78s
# 702:	learn: 0.4995765	total: 13.6s	remaining: 5.76s
# 703:	learn: 0.4995219	total: 13.7s	remaining: 5.74s
# 704:	learn: 0.4994785	total: 13.7s	remaining: 5.72s
# 705:	learn: 0.4994339	total: 13.7s	remaining: 5.7s
# 706:	learn: 0.4993916	total: 13.7s	remaining: 5.68s
# 707:	learn: 0.4993423	total: 13.7s	remaining: 5.66s
# 708:	learn: 0.4993022	total: 13.7s	remaining: 5.64s
# 709:	learn: 0.4992258	total: 13.8s	remaining: 5.62s
# 710:	learn: 0.4992008	total: 13.8s	remaining: 5.6s
# 711:	learn: 0.4991482	total: 13.8s	remaining: 5.58s
# 712:	learn: 0.4990945	total: 13.8s	remaining: 5.55s
# 713:	learn: 0.4990452	total: 13.8s	remaining: 5.53s
# 714:	learn: 0.4989923	total: 13.8s	remaining: 5.51s
# 715:	learn: 0.4989551	total: 13.8s	remaining: 5.49s
# 716:	learn: 0.4989209	total: 13.9s	remaining: 5.47s
# 717:	learn: 0.4988622	total: 13.9s	remaining: 5.45s
# 718:	learn: 0.4988152	total: 13.9s	remaining: 5.43s
# 719:	learn: 0.4987650	total: 13.9s	remaining: 5.41s
# 720:	learn: 0.4987079	total: 13.9s	remaining: 5.39s
# 721:	learn: 0.4986636	total: 14s	remaining: 5.37s
# 722:	learn: 0.4986206	total: 14s	remaining: 5.35s
# 723:	learn: 0.4985641	total: 14s	remaining: 5.33s
# 724:	learn: 0.4985101	total: 14s	remaining: 5.31s
# 725:	learn: 0.4984615	total: 14s	remaining: 5.29s
# 726:	learn: 0.4984111	total: 14.1s	remaining: 5.28s
# 727:	learn: 0.4983777	total: 14.1s	remaining: 5.26s
# 728:	learn: 0.4983043	total: 14.1s	remaining: 5.24s
# 729:	learn: 0.4982700	total: 14.1s	remaining: 5.22s
# 730:	learn: 0.4982250	total: 14.1s	remaining: 5.2s
# 731:	learn: 0.4981810	total: 14.1s	remaining: 5.18s
# 732:	learn: 0.4981491	total: 14.2s	remaining: 5.16s
# 733:	learn: 0.4981012	total: 14.2s	remaining: 5.14s
# 734:	learn: 0.4980711	total: 14.2s	remaining: 5.12s
# 735:	learn: 0.4980372	total: 14.2s	remaining: 5.1s
# 736:	learn: 0.4980066	total: 14.2s	remaining: 5.08s
# 737:	learn: 0.4979681	total: 14.2s	remaining: 5.05s
# 738:	learn: 0.4979202	total: 14.3s	remaining: 5.03s
# 739:	learn: 0.4978659	total: 14.3s	remaining: 5.01s
# 740:	learn: 0.4978149	total: 14.3s	remaining: 4.99s
# 741:	learn: 0.4977504	total: 14.3s	remaining: 4.97s
# 742:	learn: 0.4977196	total: 14.3s	remaining: 4.95s
# 743:	learn: 0.4976841	total: 14.3s	remaining: 4.93s
# 744:	learn: 0.4976403	total: 14.4s	remaining: 4.91s
# 745:	learn: 0.4975915	total: 14.4s	remaining: 4.89s
# 746:	learn: 0.4975214	total: 14.4s	remaining: 4.87s
# 747:	learn: 0.4974520	total: 14.4s	remaining: 4.85s
# 748:	learn: 0.4974010	total: 14.4s	remaining: 4.83s
# 749:	learn: 0.4973449	total: 14.4s	remaining: 4.81s
# 750:	learn: 0.4973024	total: 14.5s	remaining: 4.79s
# 751:	learn: 0.4972351	total: 14.5s	remaining: 4.77s
# 752:	learn: 0.4971977	total: 14.5s	remaining: 4.75s
# 753:	learn: 0.4971539	total: 14.5s	remaining: 4.73s
# 754:	learn: 0.4971048	total: 14.5s	remaining: 4.71s
# 755:	learn: 0.4970797	total: 14.5s	remaining: 4.69s
# 756:	learn: 0.4970273	total: 14.5s	remaining: 4.67s
# 757:	learn: 0.4969712	total: 14.6s	remaining: 4.65s
# 758:	learn: 0.4969112	total: 14.6s	remaining: 4.63s
# 759:	learn: 0.4968774	total: 14.6s	remaining: 4.61s
# 760:	learn: 0.4968140	total: 14.6s	remaining: 4.59s
# 761:	learn: 0.4967683	total: 14.6s	remaining: 4.57s
# 762:	learn: 0.4967394	total: 14.6s	remaining: 4.54s
# 763:	learn: 0.4966864	total: 14.6s	remaining: 4.52s
# 764:	learn: 0.4966263	total: 14.7s	remaining: 4.5s
# 765:	learn: 0.4966013	total: 14.7s	remaining: 4.48s
# 766:	learn: 0.4965255	total: 14.7s	remaining: 4.46s
# 767:	learn: 0.4964900	total: 14.7s	remaining: 4.44s
# 768:	learn: 0.4964515	total: 14.7s	remaining: 4.42s
# 769:	learn: 0.4964294	total: 14.7s	remaining: 4.4s
# 770:	learn: 0.4963750	total: 14.7s	remaining: 4.38s
# 771:	learn: 0.4963495	total: 14.8s	remaining: 4.36s
# 772:	learn: 0.4963083	total: 14.8s	remaining: 4.34s
# 773:	learn: 0.4962396	total: 14.8s	remaining: 4.32s
# 774:	learn: 0.4961969	total: 14.8s	remaining: 4.3s
# 775:	learn: 0.4961625	total: 14.8s	remaining: 4.28s
# 776:	learn: 0.4961208	total: 14.8s	remaining: 4.26s
# 777:	learn: 0.4960648	total: 14.9s	remaining: 4.24s
# 778:	learn: 0.4960143	total: 14.9s	remaining: 4.22s
# 779:	learn: 0.4959754	total: 15s	remaining: 4.23s
# 780:	learn: 0.4959063	total: 15.1s	remaining: 4.22s
# 781:	learn: 0.4958648	total: 15.1s	remaining: 4.21s
# 782:	learn: 0.4958299	total: 15.1s	remaining: 4.19s
# 783:	learn: 0.4957858	total: 15.2s	remaining: 4.17s
# 784:	learn: 0.4957329	total: 15.2s	remaining: 4.16s
# 785:	learn: 0.4957021	total: 15.2s	remaining: 4.14s
# 786:	learn: 0.4956511	total: 15.2s	remaining: 4.12s
# 787:	learn: 0.4956095	total: 15.2s	remaining: 4.1s
# 788:	learn: 0.4955569	total: 15.3s	remaining: 4.08s
# 789:	learn: 0.4955094	total: 15.3s	remaining: 4.06s
# 790:	learn: 0.4954772	total: 15.3s	remaining: 4.04s
# 791:	learn: 0.4954289	total: 15.3s	remaining: 4.02s
# 792:	learn: 0.4953831	total: 15.3s	remaining: 4s
# 793:	learn: 0.4953389	total: 15.3s	remaining: 3.98s
# 794:	learn: 0.4952902	total: 15.3s	remaining: 3.96s
# 795:	learn: 0.4952342	total: 15.4s	remaining: 3.94s
# 796:	learn: 0.4952141	total: 15.4s	remaining: 3.92s
# 797:	learn: 0.4951665	total: 15.4s	remaining: 3.9s
# 798:	learn: 0.4951068	total: 15.4s	remaining: 3.88s
# 799:	learn: 0.4950571	total: 15.5s	remaining: 3.86s
# 800:	learn: 0.4950197	total: 15.5s	remaining: 3.84s
# 801:	learn: 0.4949958	total: 15.5s	remaining: 3.82s
# 802:	learn: 0.4949626	total: 15.5s	remaining: 3.8s
# 803:	learn: 0.4949146	total: 15.5s	remaining: 3.78s
# 804:	learn: 0.4948779	total: 15.5s	remaining: 3.76s
# 805:	learn: 0.4948374	total: 15.5s	remaining: 3.74s
# 806:	learn: 0.4948067	total: 15.6s	remaining: 3.72s
# 807:	learn: 0.4947676	total: 15.6s	remaining: 3.7s
# 808:	learn: 0.4947294	total: 15.6s	remaining: 3.68s
# 809:	learn: 0.4946913	total: 15.6s	remaining: 3.66s
# 810:	learn: 0.4946676	total: 15.6s	remaining: 3.64s
# 811:	learn: 0.4946358	total: 15.6s	remaining: 3.62s
# 812:	learn: 0.4945860	total: 15.7s	remaining: 3.6s
# 813:	learn: 0.4945301	total: 15.7s	remaining: 3.58s
# 814:	learn: 0.4944810	total: 15.7s	remaining: 3.56s
# 815:	learn: 0.4944589	total: 15.7s	remaining: 3.54s
# 816:	learn: 0.4944114	total: 15.7s	remaining: 3.52s
# 817:	learn: 0.4943771	total: 15.8s	remaining: 3.5s
# 818:	learn: 0.4943419	total: 15.8s	remaining: 3.48s
# 819:	learn: 0.4942896	total: 15.8s	remaining: 3.47s
# 820:	learn: 0.4942550	total: 15.8s	remaining: 3.45s
# 821:	learn: 0.4941933	total: 15.8s	remaining: 3.43s
# 822:	learn: 0.4941305	total: 15.8s	remaining: 3.41s
# 823:	learn: 0.4940943	total: 15.9s	remaining: 3.39s
# 824:	learn: 0.4940687	total: 15.9s	remaining: 3.37s
# 825:	learn: 0.4939953	total: 15.9s	remaining: 3.35s
# 826:	learn: 0.4939373	total: 15.9s	remaining: 3.33s
# 827:	learn: 0.4938940	total: 15.9s	remaining: 3.31s
# 828:	learn: 0.4938473	total: 15.9s	remaining: 3.29s
# 829:	learn: 0.4938249	total: 16s	remaining: 3.27s
# 830:	learn: 0.4937871	total: 16s	remaining: 3.25s
# 831:	learn: 0.4937401	total: 16s	remaining: 3.23s
# 832:	learn: 0.4936911	total: 16s	remaining: 3.21s
# 833:	learn: 0.4936375	total: 16s	remaining: 3.19s
# 834:	learn: 0.4936023	total: 16.1s	remaining: 3.17s
# 835:	learn: 0.4935437	total: 16.1s	remaining: 3.15s
# 836:	learn: 0.4935037	total: 16.1s	remaining: 3.14s
# 837:	learn: 0.4934494	total: 16.2s	remaining: 3.12s
# 838:	learn: 0.4934193	total: 16.2s	remaining: 3.1s
# 839:	learn: 0.4933974	total: 16.2s	remaining: 3.09s
# 840:	learn: 0.4933592	total: 16.2s	remaining: 3.07s
# 841:	learn: 0.4933164	total: 16.3s	remaining: 3.05s
# 842:	learn: 0.4933002	total: 16.3s	remaining: 3.03s
# 843:	learn: 0.4932822	total: 16.3s	remaining: 3.01s
# 844:	learn: 0.4932170	total: 16.3s	remaining: 3s
# 845:	learn: 0.4931786	total: 16.4s	remaining: 2.98s
# 846:	learn: 0.4931312	total: 16.4s	remaining: 2.96s
# 847:	learn: 0.4930953	total: 16.4s	remaining: 2.94s
# 848:	learn: 0.4930734	total: 16.4s	remaining: 2.92s
# 849:	learn: 0.4930141	total: 16.4s	remaining: 2.9s
# 850:	learn: 0.4929623	total: 16.4s	remaining: 2.88s
# 851:	learn: 0.4928991	total: 16.5s	remaining: 2.86s
# 852:	learn: 0.4928595	total: 16.5s	remaining: 2.84s
# 853:	learn: 0.4928061	total: 16.5s	remaining: 2.82s
# 854:	learn: 0.4927622	total: 16.5s	remaining: 2.8s
# 855:	learn: 0.4927261	total: 16.6s	remaining: 2.78s
# 856:	learn: 0.4926885	total: 16.6s	remaining: 2.77s
# 857:	learn: 0.4926634	total: 16.6s	remaining: 2.75s
# 858:	learn: 0.4926350	total: 16.6s	remaining: 2.73s
# 859:	learn: 0.4925742	total: 16.6s	remaining: 2.71s
# 860:	learn: 0.4925428	total: 16.7s	remaining: 2.69s
# 861:	learn: 0.4925043	total: 16.7s	remaining: 2.67s
# 862:	learn: 0.4924728	total: 16.7s	remaining: 2.65s
# 863:	learn: 0.4924352	total: 16.7s	remaining: 2.63s
# 864:	learn: 0.4924062	total: 16.7s	remaining: 2.61s
# 865:	learn: 0.4923524	total: 16.8s	remaining: 2.59s
# 866:	learn: 0.4923342	total: 16.8s	remaining: 2.57s
# 867:	learn: 0.4922885	total: 16.8s	remaining: 2.56s
# 868:	learn: 0.4922605	total: 16.8s	remaining: 2.54s
# 869:	learn: 0.4922162	total: 16.9s	remaining: 2.52s
# 870:	learn: 0.4922041	total: 16.9s	remaining: 2.5s
# 871:	learn: 0.4921679	total: 16.9s	remaining: 2.48s
# 872:	learn: 0.4921017	total: 16.9s	remaining: 2.46s
# 873:	learn: 0.4920446	total: 16.9s	remaining: 2.44s
# 874:	learn: 0.4919961	total: 16.9s	remaining: 2.42s
# 875:	learn: 0.4919548	total: 17s	remaining: 2.4s
# 876:	learn: 0.4919398	total: 17s	remaining: 2.38s
# 877:	learn: 0.4918822	total: 17s	remaining: 2.37s
# 878:	learn: 0.4918495	total: 17.1s	remaining: 2.35s
# 879:	learn: 0.4917882	total: 17.1s	remaining: 2.33s
# 880:	learn: 0.4917280	total: 17.1s	remaining: 2.31s
# 881:	learn: 0.4916993	total: 17.1s	remaining: 2.29s
# 882:	learn: 0.4916621	total: 17.1s	remaining: 2.27s
# 883:	learn: 0.4916341	total: 17.2s	remaining: 2.25s
# 884:	learn: 0.4916069	total: 17.3s	remaining: 2.25s
# 885:	learn: 0.4915428	total: 17.3s	remaining: 2.23s
# 886:	learn: 0.4915003	total: 17.4s	remaining: 2.21s
# 887:	learn: 0.4914780	total: 17.4s	remaining: 2.2s
# 888:	learn: 0.4914343	total: 17.5s	remaining: 2.18s
# 889:	learn: 0.4913876	total: 17.5s	remaining: 2.17s
# 890:	learn: 0.4913424	total: 17.6s	remaining: 2.15s
# 891:	learn: 0.4912982	total: 17.6s	remaining: 2.13s
# 892:	learn: 0.4912517	total: 17.7s	remaining: 2.12s
# 893:	learn: 0.4912088	total: 17.7s	remaining: 2.1s
# 894:	learn: 0.4911540	total: 17.7s	remaining: 2.08s
# 895:	learn: 0.4911315	total: 17.8s	remaining: 2.06s
# 896:	learn: 0.4910934	total: 17.8s	remaining: 2.04s
# 897:	learn: 0.4910547	total: 17.8s	remaining: 2.02s
# 898:	learn: 0.4910130	total: 17.8s	remaining: 2s
# 899:	learn: 0.4909927	total: 17.8s	remaining: 1.98s
# 900:	learn: 0.4909481	total: 17.9s	remaining: 1.96s
# 901:	learn: 0.4908919	total: 17.9s	remaining: 1.95s
# 902:	learn: 0.4908474	total: 17.9s	remaining: 1.93s
# 903:	learn: 0.4907950	total: 18s	remaining: 1.91s
# 904:	learn: 0.4907582	total: 18s	remaining: 1.89s
# 905:	learn: 0.4907197	total: 18.1s	remaining: 1.87s
# 906:	learn: 0.4906919	total: 18.1s	remaining: 1.86s
# 907:	learn: 0.4906552	total: 18.2s	remaining: 1.84s
# 908:	learn: 0.4906243	total: 18.2s	remaining: 1.82s
# 909:	learn: 0.4905861	total: 18.3s	remaining: 1.81s
# 910:	learn: 0.4905447	total: 18.3s	remaining: 1.79s
# 911:	learn: 0.4904918	total: 18.4s	remaining: 1.77s
# 912:	learn: 0.4904597	total: 18.4s	remaining: 1.76s
# 913:	learn: 0.4903906	total: 18.5s	remaining: 1.74s
# 914:	learn: 0.4903661	total: 18.5s	remaining: 1.72s
# 915:	learn: 0.4903132	total: 18.6s	remaining: 1.7s
# 916:	learn: 0.4902791	total: 18.6s	remaining: 1.68s
# 917:	learn: 0.4902426	total: 18.6s	remaining: 1.66s
# 918:	learn: 0.4902118	total: 18.7s	remaining: 1.65s
# 919:	learn: 0.4901884	total: 18.7s	remaining: 1.63s
# 920:	learn: 0.4901519	total: 18.8s	remaining: 1.61s
# 921:	learn: 0.4901028	total: 18.8s	remaining: 1.59s
# 922:	learn: 0.4900693	total: 18.8s	remaining: 1.57s
# 923:	learn: 0.4900548	total: 19s	remaining: 1.56s
# 924:	learn: 0.4900223	total: 19s	remaining: 1.54s
# 925:	learn: 0.4899868	total: 19.1s	remaining: 1.52s
# 926:	learn: 0.4899414	total: 19.1s	remaining: 1.5s
# 927:	learn: 0.4899013	total: 19.2s	remaining: 1.49s
# 928:	learn: 0.4898487	total: 19.2s	remaining: 1.47s
# 929:	learn: 0.4897962	total: 19.2s	remaining: 1.45s
# 930:	learn: 0.4897437	total: 19.3s	remaining: 1.43s
# 931:	learn: 0.4897201	total: 19.3s	remaining: 1.41s
# 932:	learn: 0.4896822	total: 19.3s	remaining: 1.39s
# 933:	learn: 0.4896210	total: 19.4s	remaining: 1.37s
# 934:	learn: 0.4895897	total: 19.4s	remaining: 1.35s
# 935:	learn: 0.4895567	total: 19.4s	remaining: 1.33s
# 936:	learn: 0.4895094	total: 19.4s	remaining: 1.3s
# 937:	learn: 0.4894560	total: 19.4s	remaining: 1.28s
# 938:	learn: 0.4894068	total: 19.5s	remaining: 1.26s
# 939:	learn: 0.4893748	total: 19.5s	remaining: 1.24s
# 940:	learn: 0.4893295	total: 19.6s	remaining: 1.23s
# 941:	learn: 0.4892919	total: 19.7s	remaining: 1.22s
# 942:	learn: 0.4892487	total: 19.8s	remaining: 1.2s
# 943:	learn: 0.4892183	total: 19.8s	remaining: 1.18s
# 944:	learn: 0.4891726	total: 19.8s	remaining: 1.16s
# 945:	learn: 0.4891413	total: 19.9s	remaining: 1.13s
# 946:	learn: 0.4891006	total: 19.9s	remaining: 1.11s
# 947:	learn: 0.4890905	total: 19.9s	remaining: 1.09s
# 948:	learn: 0.4890590	total: 20s	remaining: 1.07s
# 949:	learn: 0.4889977	total: 20s	remaining: 1.05s
# 950:	learn: 0.4889673	total: 20s	remaining: 1.03s
# 951:	learn: 0.4889351	total: 20.1s	remaining: 1.01s
# 952:	learn: 0.4889049	total: 20.1s	remaining: 991ms
# 953:	learn: 0.4888549	total: 20.1s	remaining: 970ms
# 954:	learn: 0.4888154	total: 20.2s	remaining: 950ms
# 955:	learn: 0.4887826	total: 20.2s	remaining: 930ms
# 956:	learn: 0.4887407	total: 20.2s	remaining: 910ms
# 957:	learn: 0.4886907	total: 20.3s	remaining: 890ms
# 958:	learn: 0.4886738	total: 20.3s	remaining: 870ms
# 959:	learn: 0.4886294	total: 20.4s	remaining: 850ms
# 960:	learn: 0.4885963	total: 20.4s	remaining: 829ms
# 961:	learn: 0.4885759	total: 20.5s	remaining: 809ms
# 962:	learn: 0.4885375	total: 20.5s	remaining: 788ms
# 963:	learn: 0.4884885	total: 20.5s	remaining: 766ms
# 964:	learn: 0.4884397	total: 20.5s	remaining: 745ms
# 965:	learn: 0.4883979	total: 20.5s	remaining: 723ms
# 966:	learn: 0.4883642	total: 20.6s	remaining: 702ms
# 967:	learn: 0.4883241	total: 20.6s	remaining: 681ms
# 968:	learn: 0.4882880	total: 20.6s	remaining: 659ms
# 969:	learn: 0.4882532	total: 20.6s	remaining: 638ms
# 970:	learn: 0.4882220	total: 20.7s	remaining: 617ms
# 971:	learn: 0.4881826	total: 20.7s	remaining: 596ms
# 972:	learn: 0.4881428	total: 20.7s	remaining: 575ms
# 973:	learn: 0.4881033	total: 20.7s	remaining: 554ms
# 974:	learn: 0.4880678	total: 20.8s	remaining: 532ms
# 975:	learn: 0.4880295	total: 20.8s	remaining: 511ms
# 976:	learn: 0.4879736	total: 20.8s	remaining: 490ms
# 977:	learn: 0.4879245	total: 20.8s	remaining: 469ms
# 978:	learn: 0.4878893	total: 20.9s	remaining: 447ms
# 979:	learn: 0.4878672	total: 20.9s	remaining: 426ms
# 980:	learn: 0.4878338	total: 20.9s	remaining: 405ms
# 981:	learn: 0.4878054	total: 20.9s	remaining: 383ms
# 982:	learn: 0.4877740	total: 20.9s	remaining: 362ms
# 983:	learn: 0.4877352	total: 20.9s	remaining: 341ms
# 984:	learn: 0.4876830	total: 21s	remaining: 319ms
# 985:	learn: 0.4876405	total: 21s	remaining: 298ms
# 986:	learn: 0.4876159	total: 21s	remaining: 276ms
# 987:	learn: 0.4875874	total: 21s	remaining: 255ms
# 988:	learn: 0.4875567	total: 21s	remaining: 234ms
# 989:	learn: 0.4875227	total: 21s	remaining: 213ms
# 990:	learn: 0.4874822	total: 21.1s	remaining: 191ms
# 991:	learn: 0.4874362	total: 21.1s	remaining: 170ms
# 992:	learn: 0.4873933	total: 21.1s	remaining: 149ms
# 993:	learn: 0.4873682	total: 21.1s	remaining: 127ms
# 994:	learn: 0.4873578	total: 21.1s	remaining: 106ms
# 995:	learn: 0.4873035	total: 21.1s	remaining: 84.9ms
# 996:	learn: 0.4872579	total: 21.2s	remaining: 63.7ms
# 997:	learn: 0.4872427	total: 21.2s	remaining: 42.4ms
# 998:	learn: 0.4871952	total: 21.2s	remaining: 21.2ms
# 999:	learn: 0.4871697	total: 21.2s	remaining: 0us

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

def roc_auc_plot(y_true, y_proba, label=' ', l='-', lw=1.0, auc=None):
    fpr, tpr, _ = roc_curve(y_true, y_proba)
    plt.plot(fpr, tpr, linestyle=l, linewidth=lw, label="%s (AUC = %.2f)" % (label, auc))

# Individual AUC values for each algorithm
auc_svm = 0.77
auc_lr = 0.72
auc_gnb = 0.72  # AUC for GNB
auc_dtree = 0.61
auc_ranfor = 0.72
auc_xgb = 0.78
auc_knn = 0.70
auc_adaboost = 0.75
auc_ffn = 0.77
auc_catboost = 0.78

# Plot ROC curve
plt.figure(figsize=(12, 8))

roc_auc_plot(y_test_resampled, svm_model.predict_proba(X_test_resampled.values)[:, 1], label='SVM', l='-', lw=2.0, auc=auc_svm)  # Bold line for SVM
roc_auc_plot(y_test_resampled, logit_model.predict_proba(X_test_resampled.values)[:, 1], label='Logistic regression', l='-', lw=2.0, auc=auc_lr)  # Bold line for LR
roc_auc_plot(y_test_resampled, gnb_model.predict_proba(X_test_resampled.values)[:, 1], label='GNB', l='-', lw=2.0, auc=auc_gnb)  # Bold line for GNB
roc_auc_plot(y_test_resampled, dtree_model.predict_proba(X_test_resampled.values)[:, 1], label='Decision tree ', l='-', lw=2.0, auc=auc_dtree)  # Bold line for DT
roc_auc_plot(y_test_resampled, ranfor_model.predict_proba(X_test_resampled.values)[:, 1], label='Random forest', l='-', lw=2.0, auc=auc_ranfor)  # Bold line for RF
roc_auc_plot(y_test_resampled, xgb_model.predict_proba(X_test_resampled.values)[:, 1], label='eXGBoost', l='-', lw=2.0, auc=auc_xgb)  # Bold line for XGB
roc_auc_plot(y_test_resampled, knn_model.predict_proba(X_test_resampled.values)[:, 1], label='KNN', l='-', lw=2.0, auc=auc_knn)  # Bold line for KNN
roc_auc_plot(y_test_resampled, adaboost_model.predict_proba(X_test_resampled.values)[:, 1], label='AdaBoost', l='-', lw=2.0, auc=auc_adaboost)  # Bold line for AdaBoost
roc_auc_plot(y_test_resampled, fnn_model.predict(X_test_resampled_std), label='FFNN', l='--', lw=2.0, auc=auc_ffn)  # Dotted line for FFNN
roc_auc_plot(y_test_resampled, catboost_model.predict_proba(X_test_resampled.values)[:, 1], label='CatBoost', l='-', lw=2.0, auc=auc_catboost)  # Bold line for CatBoost

plt.plot([0, 1], [0, 1], color='k', linewidth=0.5, linestyle='--')
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operator Characteristic curves')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.show()
# Out:
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
