# %%
import warnings
warnings.filterwarnings('ignore')
import os
import csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')
import os
import csv
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
from sklearn.metrics import auc,roc_auc_score,roc_curve,precision_score,recall_score,f1_score
import time as timer
from sklearn.inspection import permutation_importance
import itertools
import seaborn as sns
from sklearn.svm import LinearSVC,SVC
from sklearn.multiclass import OneVsRestClassifier
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LassoCV,LogisticRegression,SGDClassifier
from sklearn.naive_bayes import GaussianNB,BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,BaggingClassifier,AdaBoostClassifier,GradientBoostingClassifier,VotingClassifier,StackingClassifier
from sklearn.feature_selection import chi2,SelectKBest,SelectFromModel,RFE,VarianceThreshold
from sklearn.metrics import confusion_matrix,precision_recall_curve,average_precision_score,roc_curve,auc,f1_score,accuracy_score,\
classification_report,multilabel_confusion_matrix, roc_auc_score,precision_recall_fscore_support
from sklearn.model_selection import cross_val_score,train_test_split,StratifiedKFold,GridSearchCV
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler,LabelEncoder,LabelBinarizer
from scipy import interp
from itertools import cycle
plt.style.use('ggplot');
import sys
if ("/your/path/to/xelatex") not in sys.path:
    print('adding path') # I just add this to know if the path was present or not.
    sys.path.append("/your/path/to/xelatex")
# Out:
# adding path

# %%
from sklearn.metrics import precision_recall_curve
from imblearn.over_sampling import SMOTE

# %%
data = pd.read_csv('data_adverse_imputed.csv')
data
# Out:
#         Residence  Mother_education  Sex_of_HH  mobile_phone  deliver_by_CS  \
# 0               2                 0          1             0              1
# 1               1                 1          2             0              0
# 2               1                 0          2             0              0
# 3               1                 0          2             0              0
# 4               1                 1          2             0              0
# ...           ...               ...        ...           ...            ...
# 139654          2                 2          1             0              0
# 139655          2                 1          1             0              0
# 139656          2                 2          1             1              0
# 139657          2                 1          2             1              0
# 139658          2                 1          2             1              0
#
#         Smoke  Distance_to_HF  Working_status  sex_of_child  Age_of_mother  \
# 0           0               1               1             1              4
# 1           0               1               1             1              2
# 2           0               1               0             2              3
# 3           0               1               0             1              3
# 4           0               1               1             1              3
# ...       ...             ...             ...           ...            ...
# 139654      0               1               0             1              1
# 139655      0               1               0             2              3
# 139656      0               1               1             1              3
# 139657      0               1               1             2              2
# 139658      0               1               0             2              4
#
#         ...  Iron_supplementation  Type_of_pregnancy  ANC_visits  \
# 0       ...                     0                  0           0
# 1       ...                     0                  0           2
# 2       ...                     0                  0           2
# 3       ...                     0                  0           1
# 4       ...                     1                  0           0
# ...     ...                   ...                ...         ...
# 139654  ...                     1                  0           2
# 139655  ...                     1                  0           2
# 139656  ...                     1                  0           1
# 139657  ...                     1                  0           2
# 139658  ...                     0                  0           1
#
#         Birth_interval  Wanted_pregnancy  First_ANC_check  Place_of_delivery  \
# 0                    1                 1                0                  1
# 1                    1                 1                1                  1
# 2                    1                 1                1                  1
# 3                    0                 1                0                  0
# 4                    1                 1                0                  0
# ...                ...               ...              ...                ...
# 139654               1                 1                1                  1
# 139655               2                 1                0                  0
# 139656               2                 1                0                  1
# 139657               1                 1                1                  1
# 139658               1                 1                0                  1
#
#         Media_exposure  Regions  adverse_birth_outcome
# 0                    0        1                      0
# 1                    0        1                      1
# 2                    0        1                      1
# 3                    0        1                      1
# 4                    0        1                      0
# ...                ...      ...                    ...
# 139654               0        3                      0
# 139655               1        3                      0
# 139656               1        3                      0
# 139657               1        3                      0
# 139658               0        3                      0
#
# [139659 rows x 26 columns]

# %%
# "data" is the DataFrame
data.drop('Smoke', axis=1, inplace=True)
data.drop('Number_of_children', axis=1, inplace=True)

# %%
##Data Preprocessing/Feauture selection
X = data.drop('adverse_birth_outcome',axis=1)
y = data.adverse_birth_outcome
num_features_opt = 40   # the number of features that we need to choose as a result
num_features_max = 60   # the somewhat excessive number of features, which we will choose at each stage
features_best = []

# %%
from imblearn.over_sampling import RandomOverSampler

# Create a RandomOverSampler object
over_sampler = RandomOverSampler()

# Perform over-sampling
X_resampled, y_resampled = over_sampler.fit_resample(X, y)

# Print the shape of the resampled data
print("Shape of X_resampled:", X_resampled.shape)
print("Shape of y_resampled:", y_resampled.shape)
# Out:
# Shape of X_resampled: (189648, 23)
# Shape of y_resampled: (189648,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split
import numpy as np

def split_train_valid_test(X, y, test_size=0.2, random_state=None):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state, stratify=y)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=test_size/(1-test_size), random_state=random_state, stratify=y_train)
    return X_train, X_valid, X_test, y_train, y_valid, y_test

# Usage example
X_train_resampled, X_valid_resampled, X_test_resampled, y_train_resampled, y_valid_resampled, y_test_resampled = split_train_valid_test(X_resampled, y_resampled, test_size=0.3, random_state=42)
_, train_counts = np.unique(y_train_resampled, return_counts=True)
_, valid_counts = np.unique(y_valid_resampled, return_counts=True)
_, test_counts = np.unique(y_test_resampled, return_counts=True)
print("[train] # class 0: {} | # class 1: {}".format(train_counts[0], train_counts[1]))
print("[valid] # class 0: {} | # class 1: {}".format(valid_counts[0], valid_counts[1]))
print("[test]  # class 0: {} | # class 1: {}".format(test_counts[0], test_counts[1]))
# Out:
# [train] # class 0: 37929 | # class 1: 37929
# [valid] # class 0: 28447 | # class 1: 28448
# [test]  # class 0: 28448 | # class 1: 28447

# %%
# Scaling code
scaler = StandardScaler()
scaler = scaler.fit(X_train_resampled)

X_train_resampled_std = scaler.transform(X_train_resampled)
X_valid_resampled_std = scaler.transform(X_valid_resampled)
X_test_resampled_std = scaler.transform(X_test_resampled)

# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit

# %%
def calc_sens_spec(y_true,y_pred):
    conf_matrix = confusion_matrix(y_true,y_pred)
    TP = conf_matrix[1][1]
    TN = conf_matrix[0][0]
    FP = conf_matrix[0][1]
    FN = conf_matrix[1][0]
    # calculate the sensitivity
    sensitivity = TP / (TP + FN)    
    # calculate the specificity
    specificity = TN / (TN + FP)
    return sensitivity,specificity
from sklearn import metrics
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
import time as timer
## SVM
start = timer.time()
svm_model = SVC(kernel='rbf',probability=True)
svm_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_svm = svm_model.predict(X_test_resampled_std)
y_svm_prob = svm_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 5055.08 seconds

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
from sklearn.metrics import auc,roc_auc_score,roc_curve,precision_score,recall_score,f1_score

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for SVM:\n{}".format(classification_report(y_test_resampled, y_svm)))

# Print confusion matrix
print("Confusion matrix for SVM:\n{}".format(confusion_matrix(y_test_resampled, y_svm)))

# Calculate and print accuracy score
accuracy_score_svm = accuracy_score(y_test_resampled, y_svm)
print("Accuracy score for SVM: {:.2f}".format(accuracy_score_svm))

# Calculate precision, recall, and f1 scores
prec_svm = precision_score(y_test_resampled, y_svm)
rec_svm = recall_score(y_test_resampled, y_svm)
f1_svm = f1_score(y_test_resampled, y_svm)
print("Precision score for SVM: {:.2f}".format(prec_svm))
print("Recall score for SVM: {:.2f}".format(rec_svm))
print("F1 score for SVM: {:.2f}".format(f1_svm))

# Calculate sensitivity, specificity, and AUC
sens_svm, spec_svm = calc_sens_spec(y_test_resampled, y_svm)
fpr, tpr, _ = roc_curve(y_test_resampled, y_svm_prob[:, 1])
auc_svm = roc_auc_score(y_test_resampled, y_svm_prob[:, 1])
print("Sensitivity score for SVM: {:.2f}".format(sens_svm))
print("Specificity score for SVM: {:.2f}".format(spec_svm))
print("AUC score for SVM: {:.2f}".format(auc_svm))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_svm)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (SVM)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for SVM:
#               precision    recall  f1-score   support
#
#            0       0.58      0.72      0.64     28448
#            1       0.63      0.49      0.55     28447
#
#     accuracy                           0.60     56895
#    macro avg       0.61      0.60      0.60     56895
# weighted avg       0.61      0.60      0.60     56895
#
# Confusion matrix for SVM:
# [[20445  8003]
#  [14640 13807]]
# Accuracy score for SVM: 0.60
# Precision score for SVM: 0.63
# Recall score for SVM: 0.49
# F1 score for SVM: 0.55
# Sensitivity score for SVM: 0.49
# Specificity score for SVM: 0.72
# AUC score for SVM: 0.64

# %%
##Logistic Regression (LR)
start = timer.time()
logit_model = LogisticRegression(solver='lbfgs', random_state=42)
logit_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_logit = logit_model.predict(X_test_resampled_std)
y_logit_prob = logit_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 0.28 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for LR:\n{}".format(classification_report(y_test_resampled, y_logit)))

# Print confusion matrix
print("Confusion matrix for LR:\n{}".format(confusion_matrix(y_test_resampled, y_logit)))

# Calculate and print accuracy score
accuracy_score_lr = accuracy_score(y_test_resampled, y_logit)
print("Accuracy score for LR: {:.2f}".format(accuracy_score_lr))

# Calculate precision, recall, and f1 scores
prec_lr = precision_score(y_test_resampled, y_logit)
rec_lr = recall_score(y_test_resampled, y_logit)
f1_lr = f1_score(y_test_resampled, y_logit)
print("Precision score for LR: {:.2f}".format(prec_lr))
print("Recall score for LR: {:.2f}".format(rec_lr))
print("F1 score for LR: {:.2f}".format(f1_lr))

# Calculate sensitivity, specificity, and AUC
sens_lr, spec_lr = calc_sens_spec(y_test_resampled, y_logit)
fpr, tpr, _ = roc_curve(y_test_resampled, y_logit_prob[:, 1])
auc_lr = roc_auc_score(y_test_resampled, y_logit_prob[:, 1])
print("Sensitivity score for LR: {:.2f}".format(sens_lr))
print("Specificity score for LR: {:.2f}".format(spec_lr))
print("AUC score for LR: {:.2f}".format(auc_lr))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_lr)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (LR)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for LR:
#               precision    recall  f1-score   support
#
#            0       0.56      0.68      0.61     28448
#            1       0.59      0.46      0.52     28447
#
#     accuracy                           0.57     56895
#    macro avg       0.57      0.57      0.57     56895
# weighted avg       0.57      0.57      0.57     56895
#
# Confusion matrix for LR:
# [[19475  8973]
#  [15451 12996]]
# Accuracy score for LR: 0.57
# Precision score for LR: 0.59
# Recall score for LR: 0.46
# F1 score for LR: 0.52
# Sensitivity score for LR: 0.46
# Specificity score for LR: 0.68
# AUC score for LR: 0.60

# %%
## Gaussian Naive Bayes (GNB)
start = timer.time()
gnb_model = GaussianNB()
gnb_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_gnb = gnb_model.predict(X_test_resampled_std)
y_gnb_prob = gnb_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 0.11 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for GNB:\n{}".format(classification_report(y_test_resampled, y_gnb)))

# Print confusion matrix
print("Confusion matrix for GNB:\n{}".format(confusion_matrix(y_test_resampled, y_gnb)))

# Calculate and print accuracy score
accuracy_score_gnb = accuracy_score(y_test_resampled, y_gnb)
print("Accuracy score for GNB: {:.2f}".format(accuracy_score_gnb))

# Calculate precision, recall, and f1 scores
prec_gnb = precision_score(y_test_resampled, y_gnb)
rec_gnb = recall_score(y_test_resampled, y_gnb)
f1_gnb = f1_score(y_test_resampled, y_gnb)
print("Precision score for GNB: {:.2f}".format(prec_gnb))
print("Recall score for GNB: {:.2f}".format(rec_gnb))
print("F1 score for GNB: {:.2f}".format(f1_gnb))

# Calculate sensitivity, specificity, and AUC
sens_gnb, spec_gnb = calc_sens_spec(y_test_resampled, y_gnb)
fpr, tpr, _ = roc_curve(y_test_resampled, y_gnb_prob[:, 1])
auc_gnb = roc_auc_score(y_test_resampled, y_gnb_prob[:, 1])
print("Sensitivity score for GNB: {:.2f}".format(sens_gnb))
print("Specificity score for GNB: {:.2f}".format(spec_gnb))
print("AUC score for GNB: {:.2f}".format(auc_gnb))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_gnb)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (GNB)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for GNB:
#               precision    recall  f1-score   support
#
#            0       0.54      0.86      0.66     28448
#            1       0.64      0.25      0.36     28447
#
#     accuracy                           0.56     56895
#    macro avg       0.59      0.56      0.51     56895
# weighted avg       0.59      0.56      0.51     56895
#
# Confusion matrix for GNB:
# [[24490  3958]
#  [21257  7190]]
# Accuracy score for GNB: 0.56
# Precision score for GNB: 0.64
# Recall score for GNB: 0.25
# F1 score for GNB: 0.36
# Sensitivity score for GNB: 0.25
# Specificity score for GNB: 0.86
# AUC score for GNB: 0.60

# %%
from sklearn.tree import DecisionTreeClassifier
##  DT
start = timer.time()
dtree_model = DecisionTreeClassifier(random_state=42)
dtree_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_dtree = dtree_model.predict(X_test_resampled_std)
y_dtree_prob = dtree_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 1.15 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for DT:\n{}".format(classification_report(y_test_resampled, y_dtree)))

# Print confusion matrix
print("Confusion matrix for DT:\n{}".format(confusion_matrix(y_test_resampled, y_dtree)))

# Calculate and print accuracy score
accuracy_score_dtree = accuracy_score(y_test_resampled, y_dtree)
print("Accuracy score for DT: {:.2f}".format(accuracy_score_dtree))

# Calculate precision, recall, and f1 scores
prec_dtree = precision_score(y_test_resampled, y_dtree)
rec_dtree = recall_score(y_test_resampled, y_dtree)
f1_dtree = f1_score(y_test_resampled, y_dtree)
print("Precision score for DT: {:.2f}".format(prec_dtree))
print("Recall score for DT: {:.2f}".format(rec_dtree))
print("F1 score for DT: {:.2f}".format(f1_dtree))

# Calculate sensitivity, specificity, and AUC
sens_dtree, spec_dtree = calc_sens_spec(y_test_resampled, y_dtree)
fpr, tpr, _ = roc_curve(y_test_resampled, y_dtree_prob[:, 1])
auc_dtree = roc_auc_score(y_test_resampled, y_dtree_prob[:, 1])
print("Sensitivity score for DT: {:.2f}".format(sens_dtree))
print("Specificity score for DT: {:.2f}".format(spec_dtree))
print("AUC score for DT: {:.2f}".format(auc_dtree))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_dtree)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (DT)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for DT:
#               precision    recall  f1-score   support
#
#            0       0.67      0.62      0.64     28448
#            1       0.65      0.69      0.67     28447
#
#     accuracy                           0.66     56895
#    macro avg       0.66      0.66      0.66     56895
# weighted avg       0.66      0.66      0.66     56895
#
# Confusion matrix for DT:
# [[17681 10767]
#  [ 8721 19726]]
# Accuracy score for DT: 0.66
# Precision score for DT: 0.65
# Recall score for DT: 0.69
# F1 score for DT: 0.67
# Sensitivity score for DT: 0.69
# Specificity score for DT: 0.62
# AUC score for DT: 0.67

# %%
## RF
start = timer.time()
ranfor_model = RandomForestClassifier(n_estimators=100, random_state=42)
ranfor_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_ranfor = ranfor_model.predict(X_test_resampled_std)
y_ranfor_prob = ranfor_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 23.60 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have the necessary data and have imported the required libraries

# Print classification report
print("Classification report for RF:\n{}".format(classification_report(y_test_resampled, y_ranfor)))

# Print confusion matrix
print("Confusion matrix for RF:\n{}".format(confusion_matrix(y_test_resampled, y_ranfor)))

# Calculate and print accuracy score
accuracy_score_ranfor = accuracy_score(y_test_resampled, y_ranfor)
print("Accuracy score for RF: {:.2f}".format(accuracy_score_ranfor))

# Calculate precision, recall, and f1 scores
prec_ranfor = precision_score(y_test_resampled, y_ranfor)
rec_ranfor = recall_score(y_test_resampled, y_ranfor)
f1_ranfor = f1_score(y_test_resampled, y_ranfor)
print("Precision score for RF: {:.2f}".format(prec_ranfor))
print("Recall score for RF: {:.2f}".format(rec_ranfor))
print("F1 score for RF: {:.2f}".format(f1_ranfor))

# Calculate sensitivity, specificity, and AUC
sens_ranfor, spec_ranfor = calc_sens_spec(y_test_resampled, y_ranfor)
fpr, tpr, _ = roc_curve(y_test_resampled, y_ranfor_prob[:, 1])
auc_ranfor = roc_auc_score(y_test_resampled, y_ranfor_prob[:, 1])
print("Sensitivity score for RF: {:.2f}".format(sens_ranfor))
print("Specificity score for RF: {:.2f}".format(spec_ranfor))
print("AUC score for RF: {:.2f}".format(auc_ranfor))

# Plot ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_ranfor)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (RF)')
ax.legend(loc="lower right")
ax = plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for RF:
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70     28448
#            1       0.70      0.70      0.70     28447
#
#     accuracy                           0.70     56895
#    macro avg       0.70      0.70      0.70     56895
# weighted avg       0.70      0.70      0.70     56895
#
# Confusion matrix for RF:
# [[19881  8567]
#  [ 8664 19783]]
# Accuracy score for RF: 0.70
# Precision score for RF: 0.70
# Recall score for RF: 0.70
# F1 score for RF: 0.70
# Sensitivity score for RF: 0.70
# Specificity score for RF: 0.70
# AUC score for RF: 0.76

# %%
start = timer.time()
xgb_model = XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_xgb = xgb_model.predict(X_test_resampled_std)
y_xgb_prob = xgb_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 2.06 seconds

# %%
print("Classification report for XGB: \n{}".format(classification_report(y_test_resampled,y_xgb)))
print("Confusion matrix for XGB: \n{}".format(confusion_matrix(y_test_resampled,y_xgb)))
# Calculate and print accuracy score
accuracy_score_xgb = accuracy_score(y_test_resampled, y_xgb)
print("Accuracy score for xgb: {:.2f}".format(accuracy_score_xgb))
# calculate precision, recall, and f1 scores
prec_xgb = precision_score(y_test_resampled,y_xgb)
rec_xgb = recall_score(y_test_resampled,y_xgb)
f1_xgb = f1_score(y_test_resampled,y_xgb)
print("Precision score for XGB: {:.2f}".format(prec_xgb))
print("Recall score for XGB: {:.2f}".format(rec_xgb))
print("F1 score for XGB: {:.2f}".format(f1_xgb))
# calculate sensitivity, specificity, and auc
sens_xgb,spec_xgb = calc_sens_spec(y_test_resampled,y_xgb)
fpr, tpr, _ = roc_curve(y_test_resampled, y_xgb_prob[:,1])
auc_xgb = roc_auc_score(y_test_resampled, y_xgb_prob[:,1])
print("Sensitivity score for XGB: {:.2f}".format(sens_xgb))
print("Specitivity score for XGB: {:.2f}".format(spec_xgb))
print("AUC score for XGB: {:.2f}".format(auc_xgb))
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_xgb)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (XGB)')
ax.legend(loc="lower right")
ax= plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for XGB:
#               precision    recall  f1-score   support
#
#            0       0.60      0.69      0.64     28448
#            1       0.63      0.53      0.58     28447
#
#     accuracy                           0.61     56895
#    macro avg       0.61      0.61      0.61     56895
# weighted avg       0.61      0.61      0.61     56895
#
# Confusion matrix for XGB:
# [[19623  8825]
#  [13344 15103]]
# Accuracy score for xgb: 0.61
# Precision score for XGB: 0.63
# Recall score for XGB: 0.53
# F1 score for XGB: 0.58
# Sensitivity score for XGB: 0.53
# Specitivity score for XGB: 0.69
# AUC score for XGB: 0.66

# %%
from sklearn.neighbors import KNeighborsClassifier
## KNN
start = timer.time()
knn_model = KNeighborsClassifier(n_neighbors=15)
knn_model.fit(X_train_resampled_std, y_train_resampled)
end = timer.time()
print("Finished training within {:.2f} seconds".format(end-start))
# Predicting the test set results
y_knn = knn_model.predict(X_test_resampled_std)
y_knn_prob = knn_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 0.02 seconds

# %%
print("Classification report for knn: \n{}".format(classification_report(y_test_resampled,y_knn)))
print("Confusion matrix for knn: \n{}".format(confusion_matrix(y_test_resampled,y_knn)))
# Calculate and print accuracy score
accuracy_score_knn = accuracy_score(y_test_resampled, y_knn)
print("Accuracy score for knn: {:.2f}".format(accuracy_score_knn))
# calculate precision, recall, and f1 scores
prec_knn = precision_score(y_test_resampled,y_knn)
rec_knn = recall_score(y_test_resampled,y_knn)
f1_knn = f1_score(y_test_resampled,y_knn)
print("Precision score for knn: {:.2f}".format(prec_knn))
print("Recall score for knn: {:.2f}".format(rec_knn))
print("F1 score for knn: {:.2f}".format(f1_knn))
# calculate sensitivity, specificity, and auc
sens_knn,spec_knn = calc_sens_spec(y_test_resampled,y_knn)
fpr, tpr, _ = roc_curve(y_test_resampled,  y_knn_prob[:,1])
auc_knn = roc_auc_score(y_test_resampled, y_knn_prob[:,1])
print("Sensitivity score for knn: {:.2f}".format(sens_knn))
print("Specitivity score for knn: {:.2f}".format(spec_knn))
print("AUC score for knn: {:.2f}".format(auc_knn))
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_knn)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (knn)')
ax.legend(loc="lower right")
ax= plt.gca()
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for knn:
#               precision    recall  f1-score   support
#
#            0       0.58      0.62      0.60     28448
#            1       0.59      0.55      0.57     28447
#
#     accuracy                           0.58     56895
#    macro avg       0.58      0.58      0.58     56895
# weighted avg       0.58      0.58      0.58     56895
#
# Confusion matrix for knn:
# [[17544 10904]
#  [12836 15611]]
# Accuracy score for knn: 0.58
# Precision score for knn: 0.59
# Recall score for knn: 0.55
# F1 score for knn: 0.57
# Sensitivity score for knn: 0.55
# Specitivity score for knn: 0.62
# AUC score for knn: 0.62

# %%
from sklearn.ensemble import AdaBoostClassifier
import time

# Create an instance of the AdaBoostClassifier model
adaboost_model = AdaBoostClassifier(n_estimators=50, random_state=42)

# Start the timer to measure the training time
start = time.time()

# Fit the AdaBoost model to the training data
adaboost_model.fit(X_train_resampled_std, y_train_resampled)

# Stop the timer and calculate the training time
end = time.time()
print("Finished training within {:.2f} seconds".format(end - start))

# Predict the labels for the test set using the trained AdaBoost model
y_adaboost = adaboost_model.predict(X_test_resampled_std)

# Predict the class probabilities for the test set using the trained AdaBoost model
y_adaboost_prob = adaboost_model.predict_proba(X_test_resampled_std)
# Out:
# Finished training within 6.09 seconds

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Classification report
print("Classification report for AdaBoost:\n{}".format(classification_report(y_test_resampled, y_adaboost)))

# Confusion matrix
print("Confusion matrix for AdaBoost:\n{}".format(confusion_matrix(y_test_resampled, y_adaboost)))

# Calculate and print accuracy score
accuracy_score_adaboost = accuracy_score(y_test_resampled, y_adaboost)
print("Accuracy score for AdaBoost: {:.2f}".format(accuracy_score_adaboost))

# Precision, recall, and F1 scores
prec_adaboost = precision_score(y_test_resampled, y_adaboost)
rec_adaboost = recall_score(y_test_resampled, y_adaboost)
f1_adaboost = f1_score(y_test_resampled, y_adaboost)
print("Precision score for AdaBoost: {:.2f}".format(prec_adaboost))
print("Recall score for AdaBoost: {:.2f}".format(rec_adaboost))
print("F1 score for AdaBoost: {:.2f}".format(f1_adaboost))

# Calculate sensitivity, specificity, and AUC
def calc_sens_spec(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sens_adaboost, spec_adaboost = calc_sens_spec(y_test_resampled, y_adaboost)
print("Sensitivity score for AdaBoost: {:.2f}".format(sens_adaboost))
print("Specificity score for AdaBoost: {:.2f}".format(spec_adaboost))

# Calculate the false positive rate, true positive rate, and AUC
fpr, tpr, _ = roc_curve(y_test_resampled, y_adaboost_prob[:, 1])
auc_adaboost = roc_auc_score(y_test_resampled, y_adaboost_prob[:, 1])
print("AUC score for AdaBoost: {:.2f}".format(auc_adaboost))

# Plot the ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_adaboost)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (AdaBoost)')
ax.legend(loc="lower right")
ax.set_facecolor("white")
plt.show()
# Out:
# Classification report for AdaBoost:
#               precision    recall  f1-score   support
#
#            0       0.57      0.69      0.62     28448
#            1       0.61      0.47      0.53     28447
#
#     accuracy                           0.58     56895
#    macro avg       0.59      0.58      0.58     56895
# weighted avg       0.59      0.58      0.58     56895
#
# Confusion matrix for AdaBoost:
# [[19718  8730]
#  [15005 13442]]
# Accuracy score for AdaBoost: 0.58
# Precision score for AdaBoost: 0.61
# Recall score for AdaBoost: 0.47
# F1 score for AdaBoost: 0.53
# Sensitivity score for AdaBoost: 0.47
# Specificity score for AdaBoost: 0.69
# AUC score for AdaBoost: 0.62

# %%
from catboost import CatBoostClassifier
import time

# CatBoost
start = time.time()
catboost_model = CatBoostClassifier(iterations=100, random_state=42)
catboost_model.fit(X_train_resampled_std, y_train_resampled)
end = time.time()
print("Finished training within {:.2f} seconds".format(end - start))

# Predicting the test set results
y_catboost = catboost_model.predict(X_test_resampled_std)
y_catboost_prob = catboost_model.predict_proba(X_test_resampled_std)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.6685878	total: 130ms	remaining: 12.9s
# 1:	learn: 0.6619347	total: 164ms	remaining: 8.03s
# 2:	learn: 0.6584528	total: 213ms	remaining: 6.87s
# 3:	learn: 0.6562676	total: 266ms	remaining: 6.38s
# 4:	learn: 0.6550119	total: 303ms	remaining: 5.75s
# 5:	learn: 0.6538472	total: 334ms	remaining: 5.23s
# 6:	learn: 0.6529147	total: 383ms	remaining: 5.08s
# 7:	learn: 0.6523944	total: 428ms	remaining: 4.92s
# 8:	learn: 0.6508625	total: 472ms	remaining: 4.77s
# 9:	learn: 0.6488068	total: 511ms	remaining: 4.6s
# 10:	learn: 0.6481548	total: 553ms	remaining: 4.47s
# 11:	learn: 0.6475514	total: 610ms	remaining: 4.47s
# 12:	learn: 0.6469508	total: 687ms	remaining: 4.59s
assifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Create and train the CatBoostClassifier model
catboost_model = CatBoostClassifier()
catboost_model.fit(X_train_resampled, y_train_resampled)

# Make predictions on the test set
y_catboost = catboost_model.predict(X_test_resampled)

# Classification report
print("Classification report for CatBoostClassifier:\n{}".format(classification_report(y_test_resampled, y_catboost)))

# Confusion matrix
print("Confusion matrix for CatBoostClassifier:\n{}".format(confusion_matrix(y_test_resampled, y_catboost)))

# Calculate and print accuracy score
accuracy_score_catboost = accuracy_score(y_test_resampled, y_catboost)
print("Accuracy score for CatBoost: {:.2f}".format(accuracy_score_catboost))

# Precision, recall, and F1 scores
prec_catboost = precision_score(y_test_resampled, y_catboost)
rec_catboost = recall_score(y_test_resampled, y_catboost)
f1_catboost = f1_score(y_test_resampled, y_catboost)
print("Precision score for CatBoostClassifier: {:.2f}".format(prec_catboost))
print("Recall score for CatBoostClassifier: {:.2f}".format(rec_catboost))
print("F1 score for CatBoostClassifier: {:.2f}".format(f1_catboost))

# Calculate sensitivity, specificity, and AUC
def calc_sens_spec(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sens_catboost, spec_catboost = calc_sens_spec(y_test_resampled, y_catboost)
print("Sensitivity score for CatBoostClassifier: {:.2f}".format(sens_catboost))
print("Specificity score for CatBoostClassifier: {:.2f}".format(spec_catboost))

# Calculate the false positive rate, true positive rate, and AUC
y_catboost_prob = catboost_model.predict_proba(X_test_resampled)[:, 1]
fpr, tpr, _ = roc_curve(y_test_resampled, y_catboost_prob)
auc_catboost = roc_auc_score(y_test_resampled, y_catboost_prob)
print("AUC score for CatBoostClassifier: {:.2f}".format(auc_catboost))

# Plot the ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_catboost)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (CatBoostClassifier)')
ax.legend(loc="lower right")
ax.set_facecolor("white")
plt.show()
# Out:
# Learning rate set to 0.065418
# 0:	learn: 0.6886872	total: 88ms	remaining: 1m 27s
# 1:	learn: 0.6847727	total: 129ms	remaining: 1m 4s
# 2:	learn: 0.6815704	total: 165ms	remaining: 54.9s
# 3:	learn: 0.6785915	total: 256ms	remaining: 1m 3s
# 4:	learn: 0.6762764	total: 342ms	remaining: 1m 8s
# 5:	learn: 0.6746095	total: 394ms	remaining: 1m 5s
# 6:	learn: 0.6730187	total: 487ms	remaining: 1m 9s
# 7:	learn: 0.6713247	total: 548ms	remaining: 1m 7s
# 8:	learn: 0.6701769	total: 599ms	remaining: 1m 5s
# 9:	learn: 0.6693254	total: 649ms	remaining: 1m 4s
# 10:	learn: 0.6682991	total: 727ms	remaining: 1m 5s
# 11:	learn: 0.6673592	total: 793ms	remaining: 1m 5s
# 12:	learn: 0.6665279	total: 855ms	remaining: 1m 4s
# 13:	learn: 0.6656552	total: 896ms	remaining: 1m 3s
# 14:	learn: 0.6649935	total: 946ms	remaining: 1m 2s
# 15:	learn: 0.6641985	total: 998ms	remaining: 1m 1s
# 16:	learn: 0.6636308	total: 1.03s	remaining: 59.9s
# 17:	learn: 0.6629541	total: 1.08s	remaining: 58.7s
# 18:	learn: 0.6623725	total: 1.11s	remaining: 57.2s
# 19:	learn: 0.6618062	total: 1.15s	remaining: 56.3s
# 20:	learn: 0.6612378	total: 1.21s	remaining: 56.2s
# 396:	learn: 0.6252252	total: 14.3s	remaining: 21.7s
# 397:	learn: 0.6251826	total: 14.3s	remaining: 21.7s
# 398:	learn: 0.6251147	total: 14.4s	remaining: 21.6s
# 399:	learn: 0.6250648	total: 14.4s	remaining: 21.6s
# 400:	learn: 0.6250065	total: 14.4s	remaining: 21.6s
# 401:	learn: 0.6249424	total: 14.5s	remaining: 21.5s
# 402:	learn: 0.6248857	total: 14.5s	remaining: 21.5s
# 403:	learn: 0.6248360	total: 14.5s	remaining: 21.4s
# 404:	learn: 0.6247740	total: 14.5s	remaining: 21.4s
# 405:	learn: 0.6247020	total: 14.6s	remaining: 21.3s
# 406:	learn: 0.6246368	total: 14.6s	remaining: 21.3s
# 407:	learn: 0.6245626	total: 14.6s	remaining: 21.2s
# 408:	learn: 0.6245053	total: 14.7s	remaining: 21.2s
# 409:	learn: 0.6244682	total: 14.7s	remaining: 21.2s
# 410:	learn: 0.6244064	total: 14.7s	remaining: 21.1s
# 411:	learn: 0.6243593	total: 14.8s	remaining: 21.1s
# 412:	learn: 0.6243014	total: 14.8s	remaining: 21s
# 413:	learn: 0.6242240	total: 14.8s	remaining: 21s
# 414:	learn: 0.6241612	total: 14.9s	remaining: 21s
# 415:	learn: 0.6240700	total: 14.9s	remaining: 20.9s
# 416:	learn: 0.6240142	total: 14.9s	remaining: 20.9s
# 417:	learn: 0.6239396	total: 15s	remaining: 20.8s
# 418:	learn: 0.6238818	total: 15s	remaining: 20.8s
# 419:	learn: 0.6238139	total: 15s	remaining: 20.7s
# 420:	learn: 0.6237691	total: 15.1s	remaining: 20.7s
# 421:	learn: 0.6237136	total: 15.1s	remaining: 20.7s
# 422:	learn: 0.6236797	total: 15.1s	remaining: 20.6s
# 423:	learn: 0.6236077	total: 15.1s	remaining: 20.6s
# 424:	learn: 0.6235542	total: 15.2s	remaining: 20.5s
# 425:	learn: 0.6234948	total: 15.2s	remaining: 20.5s
# 426:	learn: 0.6234483	total: 15.2s	remaining: 20.5s
# 427:	learn: 0.6233849	total: 15.3s	remaining: 20.4s
# 428:	learn: 0.6233410	total: 15.3s	remaining: 20.4s
# 429:	learn: 0.6232842	total: 15.4s	remaining: 20.4s
# 430:	learn: 0.6232338	total: 15.4s	remaining: 20.3s
# 431:	learn: 0.6231871	total: 15.4s	remaining: 20.3s
# 432:	learn: 0.6231446	total: 15.4s	remaining: 20.2s
# 433:	learn: 0.6230862	total: 15.5s	remaining: 20.2s
# 434:	learn: 0.6230396	total: 15.5s	remaining: 20.2s
# 435:	learn: 0.6230183	total: 15.6s	remaining: 20.2s
# 436:	learn: 0.6229594	total: 15.7s	remaining: 20.2s
# 437:	learn: 0.6229255	total: 15.8s	remaining: 20.2s
# 438:	learn: 0.6228881	total: 15.8s	remaining: 20.2s
# 439:	learn: 0.6228398	total: 15.8s	remaining: 20.2s
# 440:	learn: 0.6227853	total: 15.9s	remaining: 20.1s
# 441:	learn: 0.6227433	total: 15.9s	remaining: 20.1s
# 442:	learn: 0.6226890	total: 15.9s	remaining: 20s
# 678:	learn: 0.6110831	total: 23.6s	remaining: 11.2s
# 679:	learn: 0.6110243	total: 23.6s	remaining: 11.1s
# 680:	learn: 0.6109916	total: 23.7s	remaining: 11.1s
# 681:	learn: 0.6109554	total: 23.7s	remaining: 11s
# 682:	learn: 0.6109066	total: 23.7s	remaining: 11s
# 683:	learn: 0.6108618	total: 23.7s	remaining: 11s
# 684:	learn: 0.6108244	total: 23.8s	remaining: 10.9s
# 685:	learn: 0.6107788	total: 23.8s	remaining: 10.9s
# 686:	learn: 0.6107220	total: 23.8s	remaining: 10.9s
# 687:	learn: 0.6106718	total: 23.9s	remaining: 10.8s
# 688:	learn: 0.6106269	total: 23.9s	remaining: 10.8s
# 689:	learn: 0.6105983	total: 23.9s	remaining: 10.7s
# 690:	learn: 0.6105622	total: 23.9s	remaining: 10.7s
# 691:	learn: 0.6105099	total: 24s	remaining: 10.7s
# 692:	learn: 0.6104654	total: 24s	remaining: 10.6s
# 693:	learn: 0.6104054	total: 24s	remaining: 10.6s
# 694:	learn: 0.6103787	total: 24.1s	remaining: 10.6s
# 695:	learn: 0.6103437	total: 24.1s	remaining: 10.5s
# 696:	learn: 0.6103159	total: 24.1s	remaining: 10.5s
# 697:	learn: 0.6102772	total: 24.2s	remaining: 10.5s
# 698:	learn: 0.6102224	total: 24.2s	remaining: 10.4s
# 699:	learn: 0.6101888	total: 24.2s	remaining: 10.4s
# 700:	learn: 0.6101480	total: 24.2s	remaining: 10.3s
# 701:	learn: 0.6101069	total: 24.3s	remaining: 10.3s
# 702:	learn: 0.6100502	total: 24.3s	remaining: 10.3s
# 703:	learn: 0.6100082	total: 24.3s	remaining: 10.2s
# 704:	learn: 0.6099694	total: 24.4s	remaining: 10.2s
# 705:	learn: 0.6099283	total: 24.4s	remaining: 10.2s
# 706:	learn: 0.6098792	total: 24.4s	remaining: 10.1s
# 707:	learn: 0.6098468	total: 24.5s	remaining: 10.1s
# 708:	learn: 0.6097999	total: 24.5s	remaining: 10s
# 709:	learn: 0.6097626	total: 24.5s	remaining: 10s
# 710:	learn: 0.6097147	total: 24.5s	remaining: 9.98s
# 711:	learn: 0.6096460	total: 24.6s	remaining: 9.94s
# 712:	learn: 0.6095961	total: 24.6s	remaining: 9.9s
# 713:	learn: 0.6095475	total: 24.6s	remaining: 9.86s
# 714:	learn: 0.6095207	total: 24.6s	remaining: 9.82s
# 715:	learn: 0.6094659	total: 24.7s	remaining: 9.79s
# 716:	learn: 0.6094249	total: 24.7s	remaining: 9.75s
# 717:	learn: 0.6093787	total: 24.7s	remaining: 9.72s
# 718:	learn: 0.6093384	total: 24.8s	remaining: 9.68s
# 719:	learn: 0.6093020	total: 24.8s	remaining: 9.64s
# 720:	learn: 0.6092476	total: 24.8s	remaining: 9.6s
# 721:	learn: 0.6092211	total: 24.8s	remaining: 9.56s
# 722:	learn: 0.6091705	total: 24.9s	remaining: 9.53s
# 723:	learn: 0.6091474	total: 24.9s	remaining: 9.49s
# 724:	learn: 0.6091017	total: 24.9s	remaining: 9.45s
# 725:	learn: 0.6090858	total: 24.9s	remaining: 9.42s
# 726:	learn: 0.6090251	total: 25s	remaining: 9.38s
# 727:	learn: 0.6089754	total: 25s	remaining: 9.35s
# 728:	learn: 0.6089226	total: 25s	remaining: 9.31s
# 729:	learn: 0.6088970	total: 25.1s	remaining: 9.27s
# 730:	learn: 0.6088436	total: 25.1s	remaining: 9.23s
# 731:	learn: 0.6087959	total: 25.1s	remaining: 9.19s
# 732:	learn: 0.6087459	total: 25.1s	remaining: 9.16s
# 733:	learn: 0.6086946	total: 25.2s	remaining: 9.12s
# 734:	learn: 0.6086556	total: 25.2s	remaining: 9.08s
# 735:	learn: 0.6086193	total: 25.2s	remaining: 9.05s
# 736:	learn: 0.6085814	total: 25.3s	remaining: 9.01s
# 737:	learn: 0.6085116	total: 25.3s	remaining: 8.97s
# 738:	learn: 0.6084610	total: 25.3s	remaining: 8.93s
# 739:	learn: 0.6084259	total: 25.3s	remaining: 8.9s
# 740:	learn: 0.6083840	total: 25.4s	remaining: 8.86s
# 741:	learn: 0.6083541	total: 25.4s	remaining: 8.83s
# 742:	learn: 0.6083304	total: 25.4s	remaining: 8.79s
# 743:	learn: 0.6082994	total: 25.5s	remaining: 8.76s
# 744:	learn: 0.6082695	total: 25.5s	remaining: 8.72s
# 745:	learn: 0.6082212	total: 25.5s	remaining: 8.69s
# 746:	learn: 0.6081841	total: 25.5s	remaining: 8.65s
# 747:	learn: 0.6081567	total: 25.6s	remaining: 8.62s
# 748:	learn: 0.6081097	total: 25.6s	remaining: 8.58s
# 749:	learn: 0.6080636	total: 25.6s	remaining: 8.54s
# 750:	learn: 0.6080075	total: 25.6s	remaining: 8.5s
# 751:	learn: 0.6079647	total: 25.7s	remaining: 8.46s
# 752:	learn: 0.6079164	total: 25.7s	remaining: 8.43s
# 753:	learn: 0.6078737	total: 25.7s	remaining: 8.39s
# 754:	learn: 0.6078234	total: 25.7s	remaining: 8.35s
# 755:	learn: 0.6077857	total: 25.8s	remaining: 8.32s
# 756:	learn: 0.6077494	total: 25.8s	remaining: 8.28s
# 757:	learn: 0.6077012	total: 25.8s	remaining: 8.25s
# 758:	learn: 0.6076504	total: 25.9s	remaining: 8.21s
# 759:	learn: 0.6076041	total: 25.9s	remaining: 8.17s
# 760:	learn: 0.6075672	total: 25.9s	remaining: 8.14s
# 761:	learn: 0.6075124	total: 26s	remaining: 8.11s
# 762:	learn: 0.6074572	total: 26s	remaining: 8.09s
# 763:	learn: 0.6074204	total: 26.1s	remaining: 8.07s
# 764:	learn: 0.6073777	total: 26.2s	remaining: 8.04s
# 765:	learn: 0.6073374	total: 26.2s	remaining: 8s
# 766:	learn: 0.6073101	total: 26.2s	remaining: 7.96s
# 767:	learn: 0.6072772	total: 26.2s	remaining: 7.93s
# 768:	learn: 0.6072365	total: 26.3s	remaining: 7.89s
# 769:	learn: 0.6071922	total: 26.3s	remaining: 7.85s
# 770:	learn: 0.6071477	total: 26.3s	remaining: 7.82s
# 771:	learn: 0.6071222	total: 26.3s	remaining: 7.78s
# 959:	learn: 0.6000116	total: 33.4s	remaining: 1.39s
# 960:	learn: 0.5999555	total: 33.4s	remaining: 1.35s
# 961:	learn: 0.5999052	total: 33.4s	remaining: 1.32s
# 962:	learn: 0.5998611	total: 33.5s	remaining: 1.29s
# 963:	learn: 0.5998234	total: 33.5s	remaining: 1.25s
# 964:	learn: 0.5997976	total: 33.6s	remaining: 1.22s
# 965:	learn: 0.5997495	total: 33.6s	remaining: 1.18s
# 966:	learn: 0.5997166	total: 33.7s	remaining: 1.15s
# 967:	learn: 0.5996938	total: 33.7s	remaining: 1.11s
# 968:	learn: 0.5996563	total: 33.8s	remaining: 1.08s
# 969:	learn: 0.5996157	total: 33.9s	remaining: 1.05s
# 970:	learn: 0.5995732	total: 33.9s	remaining: 1.01s
# 971:	learn: 0.5995322	total: 34s	remaining: 979ms
# 972:	learn: 0.5995197	total: 34s	remaining: 945ms
# 973:	learn: 0.5994794	total: 34.1s	remaining: 910ms
# 974:	learn: 0.5994428	total: 34.1s	remaining: 875ms
# 975:	learn: 0.5994084	total: 34.2s	remaining: 840ms
# 976:	learn: 0.5993855	total: 34.2s	remaining: 806ms
# 977:	learn: 0.5993538	total: 34.3s	remaining: 771ms
# 978:	learn: 0.5993263	total: 34.3s	remaining: 736ms
# 979:	learn: 0.5993043	total: 34.4s	remaining: 702ms
# 980:	learn: 0.5992667	total: 34.5s	remaining: 667ms
# 981:	learn: 0.5992414	total: 34.6s	remaining: 634ms
# 982:	learn: 0.5992007	total: 34.8s	remaining: 602ms
# 983:	learn: 0.5991559	total: 34.9s	remaining: 567ms
# 984:	learn: 0.5991013	total: 34.9s	remaining: 531ms
# 985:	learn: 0.5990546	total: 34.9s	remaining: 496ms
# 986:	learn: 0.5990257	total: 35s	remaining: 461ms
# 987:	learn: 0.5989848	total: 35s	remaining: 425ms
# 988:	learn: 0.5989327	total: 35s	remaining: 390ms
# 989:	learn: 0.5988877	total: 35.1s	remaining: 354ms
# 990:	learn: 0.5988613	total: 35.1s	remaining: 319ms
# 991:	learn: 0.5988158	total: 35.2s	remaining: 284ms
# 992:	learn: 0.5987670	total: 35.2s	remaining: 248ms
# 993:	learn: 0.5987308	total: 35.3s	remaining: 213ms
# 994:	learn: 0.5987008	total: 35.3s	remaining: 177ms
# 995:	learn: 0.5986742	total: 35.3s	remaining: 142ms
# 996:	learn: 0.5986297	total: 35.4s	remaining: 106ms
# 997:	learn: 0.5985915	total: 35.4s	remaining: 71ms
# 998:	learn: 0.5985684	total: 35.4s	remaining: 35.5ms
# 999:	learn: 0.5985318	total: 35.5s	remaining: 0us
# Classification report for CatBoostClassifier:
#               precision    recall  f1-score   support
#
#            0       0.60      0.70      0.65     28448
#            1       0.64      0.53      0.58     28447
#
#     accuracy                           0.62     56895
#    macro avg       0.62      0.62      0.61     56895
# weighted avg       0.62      0.62      0.61     56895
#
# Confusion matrix for CatBoostClassifier:
# [[19994  8454]
#  [13440 15007]]
# Accuracy score for CatBoost: 0.62
# Precision score for CatBoostClassifier: 0.64
# Recall score for CatBoostClassifier: 0.53
# F1 score for CatBoostClassifier: 0.58
# Sensitivity score for CatBoostClassifier: 0.53
# Specificity score for CatBoostClassifier: 0.70
# AUC score for CatBoostClassifier: 0.66

# %%
import time
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create the FNN model
fnn_model = Sequential()
fnn_model.add(Dense(100, activation='relu', input_dim=X_train_resampled_std.shape[1]))
fnn_model.add(Dense(50, activation='relu'))
fnn_model.add(Dense(1, activation='sigmoid'))

# Compile the model
fnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
start = time.time()
fnn_model.fit(X_train_resampled_std, y_train_resampled, epochs=10, batch_size=32)
end = time.time()
print("Finished training within {:.2f} seconds".format(end - start))

# Predicting the test set results
y_ffn_prob = fnn_model.predict(X_test_resampled_std)
y_ffn = np.round(y_ffn_prob).astype(int)
# Out:
# Epoch 1/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.5690 - loss: 0.6707
# Epoch 2/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5930 - loss: 0.6561
# Epoch 3/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6026 - loss: 0.6509
# Epoch 4/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6061 - loss: 0.6471
# Epoch 5/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6114 - loss: 0.6438
# Epoch 6/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6155 - loss: 0.6412
# Epoch 7/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6234 - loss: 0.6352
# Epoch 8/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6251 - loss: 0.6335
# Epoch 9/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6283 - loss: 0.6317
# Epoch 10/10
# 2371/2371 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6342 - loss: 0.6264
# Finished training within 74.00 seconds
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score

# Predicting the test set results
y_ffn_prob = fnn_model.predict(X_test_resampled_std)
y_ffn = np.round(y_ffn_prob).astype(int)

# Classification report
print("Classification report for FNN:\n{}".format(classification_report(y_test_resampled, y_ffn)))

# Confusion matrix
print("Confusion matrix for FNN:\n{}".format(confusion_matrix(y_test_resampled, y_ffn)))

# Calculate and print accuracy score
accuracy_score_ffn = accuracy_score(y_test_resampled, y_ffn)
print("Accuracy score for FNN: {:.2f}".format(accuracy_score_ffn))

# Precision, recall, and F1 scores
prec_ffn = precision_score(y_test_resampled, y_ffn)
rec_ffn = recall_score(y_test_resampled, y_ffn)
f1_ffn = f1_score(y_test_resampled, y_ffn)
print("Precision score for FNN: {:.2f}".format(prec_ffn))
print("Recall score for FNN: {:.2f}".format(rec_ffn))
print("F1 score for FNN: {:.2f}".format(f1_ffn))

# Calculate sensitivity, specificity, and AUC
def calc_sens_spec(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    return sensitivity, specificity

sens_ffn, spec_ffn = calc_sens_spec(y_test_resampled, y_ffn)
print("Sensitivity score for FNN: {:.2f}".format(sens_ffn))
print("Specificity score for FNN: {:.2f}".format(spec_ffn))

# Calculate the false positive rate, true positive rate, and AUC
fpr, tpr, _ = roc_curve(y_test_resampled, y_ffn_prob)
auc_ffn = roc_auc_score(y_test_resampled, y_ffn_prob)
print("AUC score for FNN: {:.2f}".format(auc_ffn))

# Plot the ROC curve
fig, ax = plt.subplots()
ax.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % auc_ffn)
ax.plot([0, 1], [0, 1], color='green', linestyle='--')
ax.set_xlim([-0.05, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('Receiver Operating Characteristic (FNN)')
ax.legend(loc="lower right")
ax.set_facecolor("white")
plt.show()
# Out:
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Classification report for FNN:
#               precision    recall  f1-score   support
#
#            0       0.58      0.67      0.62     28448
#            1       0.61      0.53      0.57     28447
#
#     accuracy                           0.60     56895
#    macro avg       0.60      0.60      0.59     56895
# weighted avg       0.60      0.60      0.59     56895
#
# Confusion matrix for FNN:
# [[18921  9527]
#  [13434 15013]]
# Accuracy score for FNN: 0.60
# Precision score for FNN: 0.61
# Recall score for FNN: 0.53
# F1 score for FNN: 0.57
# Sensitivity score for FNN: 0.53
# Specificity score for FNN: 0.67
# AUC score for FNN: 0.64

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

ml_names = ['SVM', 'Logistic_regression', 'GNB', 'Decision_tree', 'RF', 'eXGBoost', 'KNN', 'AdaBoost', 'FFNN', 'CatBoost']
recall_all = [rec_svm, rec_lr, rec_gnb, rec_dtree, rec_ranfor, rec_xgb, rec_knn, rec_adaboost, rec_ffn, rec_catboost]
spec_all = [spec_svm, spec_lr, spec_gnb, spec_dtree, spec_ranfor, spec_xgb, spec_knn, spec_adaboost, spec_ffn, spec_catboost]
prec_all = [prec_svm, prec_lr, prec_gnb, prec_dtree, prec_ranfor, prec_xgb, prec_knn, prec_adaboost, prec_ffn, prec_catboost]
f1_all = [f1_svm, f1_lr, f1_gnb, f1_dtree, f1_ranfor, f1_xgb, f1_knn, f1_adaboost, f1_ffn, f1_catboost]
accuracy_all = [accuracy_score_svm, accuracy_score_lr, accuracy_score_gnb, accuracy_score_dtree, accuracy_score_ranfor, accuracy_score_xgb, accuracy_score_knn, accuracy_score_adaboost, accuracy_score_ffn, accuracy_score_catboost]

def autolabel(ax, bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{:.2f}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 5),  # 3 points vertical offset
                    textcoords="offset points",
                    fontsize=12,
                    rotation=90,
                    ha='center', va='bottom')

width = 0.15  # the width of the bars
r = np.arange(len(ml_names))  # the label locations

# Plot recall, specificity, accuracy, precision, and F1 score
fig, ax = plt.subplots(figsize=(12, 8))

bar1 = ax.bar(r - 2 * width, recall_all, width, label='Recall')
bar2 = ax.bar(r - width, spec_all, width, label='Specificity')
bar3 = ax.bar(r, accuracy_all, width, label='Accuracy')
bar4 = ax.bar(r + width, prec_all, width, label='Precision')
bar5 = ax.bar(r + 2 * width, f1_all, width, label='F1')

ax.set_ylim([0, 1.15])
ax.set_ylabel('Scores', fontsize=14)
ax.set_xticks(r)
ax.set_xticklabels(ml_names)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xlabel("Machine Learning Model", fontsize=14)
ax.legend(loc='lower left', ncol=3, bbox_to_anchor=(0.25, 1), fontsize=12)

autolabel(ax, bar1)
autolabel(ax, bar2)
autolabel(ax, bar3)
autolabel(ax, bar4)
autolabel(ax, bar5)

fig.tight_layout()
fig.savefig("ml_benchmark_scores.pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
from catboost import CatBoostClassifier

def roc_auc_plot(ax, y_true, y_proba, label=' ', l='-', lw=2.0):
    if y_proba.ndim == 1:
        fpr, tpr, _ = roc_curve(y_true, y_proba)  # Use y_proba directly as it's a 1D array
    else:
        if y_proba.shape[1] > 1:
            fpr, tpr, _ = roc_curve(y_true, y_proba[:, 1])
        else:
            fpr, tpr, _ = roc_curve(y_true, y_proba)
    ax.plot(fpr, tpr, linestyle=l, linewidth=lw,
            label="%s (AUC = %.3f)" % (label, roc_auc_score(y_true, y_proba)))

f, ax = plt.subplots(figsize=(12, 8))

# Calculate and plot ROC-AUC for SVM
svm_proba = svm_model.decision_function(X_test_resampled.values)
roc_auc_plot(ax, y_test_resampled, svm_proba, label='SVM', l='-', lw=2.0)

# Calculate and plot ROC-AUC for LR
lr_proba = logit_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, lr_proba, label='Logistic regression', l='-', lw=2.0)

# Calculate and plot ROC-AUC for DT
dtree_proba = dtree_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, dtree_proba, label='Decision tree', l='-', lw=2.0)

# Calculate and plot ROC-AUC for RF
ranfor_proba = ranfor_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, ranfor_proba, label='Random forest', l='-', lw=2.0)

# Calculate and plot ROC-AUC for XGB
xgb_proba = xgb_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, xgb_proba, label='eXGBoost', l='-', lw=2.0)

# Calculate and plot ROC-AUC for KNN
knn_proba = knn_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, knn_proba, label='KNN', l='-', lw=2.0)

# Calculate and plot ROC-AUC for AdaBoost
adaboost_proba = adaboost_model.predict_proba(X_test_resampled.values)[:, 1]
roc_auc_plot(ax, y_test_resampled, adaboost_proba, label='AdaBoost', l='-', lw=2.0)

# Calculate and plot ROC-AUC for FNN
fnn_proba = fnn_model.predict(X_test_resampled.values)
roc_auc_plot(ax, y_test_resampled, fnn_proba, label='FFNN', l='-', lw=2.0)

# Calculate and plot ROC-AUC for CatBoost
catboost_model = CatBoostClassifier()
catboost_model.fit(X_train_resampled, y_train_resampled)
catboost_proba = catboost_model.predict_proba(X_test_resampled)[:, 1]
roc_auc_plot(ax, y_test_resampled, catboost_proba, label='CatBoost', l='-', lw=2.0)

plt.plot([0, 1], [0, 1], color='k', linewidth=0.5, linestyle='--')
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operator Characteristic curves')
plt.xlim([0, 1])
plt.ylim([0, 1])

plt.show()
# Out:
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/
# 286:	learn: 0.6321070	total: 10.6s	remaining: 26.4s
# 287:	learn: 0.6320196	total: 10.7s	remaining: 26.4s
# 288:	learn: 0.6319587	total: 10.7s	remaining: 26.4s
# 289:	learn: 0.6319010	total: 10.8s	remaining: 26.4s
# 290:	learn: 0.6318564	total: 10.8s	remaining: 26.3s
# 291:	learn: 0.6318003	total: 10.9s	remaining: 26.3s
# 292:	learn: 0.6317445	total: 10.9s	remaining: 26.3s
# 293:	learn: 0.6316528	total: 10.9s	remaining: 26.3s
# 294:	learn: 0.6315796	total: 11s	remaining: 26.3s
# 295:	learn: 0.6314968	total: 11s	remaining: 26.3s
# 296:	learn: 0.6314166	total: 11.1s	remaining: 26.2s
# 297:	learn: 0.6313489	total: 11.1s	remaining: 26.2s
# 298:	learn: 0.6312699	total: 11.2s	remaining: 26.2s
# 299:	learn: 0.6312153	total: 11.2s	remaining: 26.2s
# 300:	learn: 0.6311607	total: 11.3s	remaining: 26.1s
# 301:	learn: 0.6310796	total: 11.3s	remaining: 26.1s
# 302:	learn: 0.6310190	total: 11.3s	remaining: 26.1s
# 303:	learn: 0.6309456	total: 11.4s	remaining: 26.1s
# 304:	learn: 0.6308880	total: 11.4s	remaining: 26.1s
# 305:	learn: 0.6308431	total: 11.5s	remaining: 26s
# 306:	learn: 0.6307466	total: 11.5s	remaining: 26s
# 307:	learn: 0.6306796	total: 11.6s	remaining: 26s
# 308:	learn: 0.6305924	total: 11.6s	remaining: 26s
# 309:	learn: 0.6305045	total: 11.7s	remaining: 25.9s
# 310:	learn: 0.6304427	total: 11.7s	remaining: 25.9s
# 311:	learn: 0.6303787	total: 11.7s	remaining: 25.9s
# 312:	learn: 0.6303238	total: 11.8s	remaining: 25.9s
# 313:	learn: 0.6302576	total: 11.8s	remaining: 25.9s
# 314:	learn: 0.6301859	total: 11.9s	remaining: 25.9s
# 315:	learn: 0.6301270	total: 11.9s	remaining: 25.8s
# 316:	learn: 0.6300492	total: 12s	remaining: 25.8s
# 317:	learn: 0.6299883	total: 12s	remaining: 25.8s
# 318:	learn: 0.6299307	total: 12.1s	remaining: 25.8s
# 319:	learn: 0.6298690	total: 12.1s	remaining: 25.8s
# 320:	learn: 0.6298221	total: 12.2s	remaining: 25.7s
# 321:	learn: 0.6297673	total: 12.2s	remaining: 25.7s
# 322:	learn: 0.6297035	total: 12.2s	remaining: 25.6s
# 323:	learn: 0.6296511	total: 12.3s	remaining: 25.6s
# 324:	learn: 0.6295682	total: 12.3s	remaining: 25.5s
# 325:	learn: 0.6295189	total: 12.3s	remaining: 25.4s
# 326:	learn: 0.6294470	total: 12.3s	remaining: 25.4s
# 327:	learn: 0.6293915	total: 12.3s	remaining: 25.3s
# 328:	learn: 0.6293134	total: 12.4s	remaining: 25.2s
# 329:	learn: 0.6292432	total: 12.4s	remaining: 25.2s
# 330:	learn: 0.6291673	total: 12.4s	remaining: 25.1s
# 331:	learn: 0.6291059	total: 12.5s	remaining: 25.1s
# 332:	learn: 0.6290556	total: 12.5s	remaining: 25s
# 475:	learn: 0.6210017	total: 18.6s	remaining: 20.5s
# 476:	learn: 0.6209548	total: 18.7s	remaining: 20.5s
# 477:	learn: 0.6209018	total: 18.7s	remaining: 20.5s
# 478:	learn: 0.6208597	total: 18.8s	remaining: 20.4s
# 479:	learn: 0.6207938	total: 18.8s	remaining: 20.4s
# 480:	learn: 0.6207466	total: 18.9s	remaining: 20.3s
# 481:	learn: 0.6206891	total: 18.9s	remaining: 20.3s
# 482:	learn: 0.6206331	total: 18.9s	remaining: 20.3s
# 483:	learn: 0.6205813	total: 19s	remaining: 20.2s
# 484:	learn: 0.6205319	total: 19s	remaining: 20.2s
# 485:	learn: 0.6204713	total: 19.1s	remaining: 20.2s
# 486:	learn: 0.6204126	total: 19.1s	remaining: 20.1s
# 487:	learn: 0.6203877	total: 19.2s	remaining: 20.1s
# 488:	learn: 0.6203179	total: 19.2s	remaining: 20.1s
# 489:	learn: 0.6202609	total: 19.2s	remaining: 20s
# 490:	learn: 0.6202162	total: 19.3s	remaining: 20s
# 491:	learn: 0.6201532	total: 19.3s	remaining: 20s
# 492:	learn: 0.6200972	total: 19.4s	remaining: 19.9s
# 493:	learn: 0.6200394	total: 19.4s	remaining: 19.9s
# 494:	learn: 0.6199833	total: 19.5s	remaining: 19.9s
# 495:	learn: 0.6199343	total: 19.5s	remaining: 19.8s
# 496:	learn: 0.6198617	total: 19.5s	remaining: 19.8s
# 497:	learn: 0.6198213	total: 19.6s	remaining: 19.7s
# 498:	learn: 0.6197456	total: 19.6s	remaining: 19.7s
# 499:	learn: 0.6196960	total: 19.6s	remaining: 19.6s
# 500:	learn: 0.6196445	total: 19.6s	remaining: 19.6s
# 501:	learn: 0.6195815	total: 19.7s	remaining: 19.5s
# 502:	learn: 0.6195316	total: 19.7s	remaining: 19.5s
# 503:	learn: 0.6194724	total: 19.7s	remaining: 19.4s
# 504:	learn: 0.6194253	total: 19.8s	remaining: 19.4s
# 505:	learn: 0.6193915	total: 19.8s	remaining: 19.3s
# 506:	learn: 0.6193384	total: 19.8s	remaining: 19.3s
# 507:	learn: 0.6192715	total: 19.9s	remaining: 19.2s
# 508:	learn: 0.6192137	total: 19.9s	remaining: 19.2s
# 509:	learn: 0.6191527	total: 19.9s	remaining: 19.1s
# 510:	learn: 0.6191167	total: 19.9s	remaining: 19.1s
# 511:	learn: 0.6190401	total: 20s	remaining: 19s
# 512:	learn: 0.6190017	total: 20s	remaining: 19s
# 513:	learn: 0.6189668	total: 20s	remaining: 18.9s
# 514:	learn: 0.6189117	total: 20.1s	remaining: 18.9s
# 515:	learn: 0.6188607	total: 20.1s	remaining: 18.8s
# 516:	learn: 0.6188315	total: 20.1s	remaining: 18.8s
# 517:	learn: 0.6187895	total: 20.1s	remaining: 18.7s
# 518:	learn: 0.6187315	total: 20.2s	remaining: 18.7s
# 519:	learn: 0.6186678	total: 20.2s	remaining: 18.7s
# 520:	learn: 0.6186155	total: 20.2s	remaining: 18.6s
# 521:	learn: 0.6185608	total: 20.3s	remaining: 18.6s
# 522:	learn: 0.6185206	total: 20.3s	remaining: 18.5s
# 523:	learn: 0.6184862	total: 20.3s	remaining: 18.5s
# 524:	learn: 0.6184605	total: 20.4s	remaining: 18.4s
# 525:	learn: 0.6183941	total: 20.4s	remaining: 18.4s
# 526:	learn: 0.6183583	total: 20.4s	remaining: 18.3s
# 527:	learn: 0.6182988	total: 20.5s	remaining: 18.3s
# 528:	learn: 0.6182652	total: 20.5s	remaining: 18.2s
# 529:	learn: 0.6182109	total: 20.5s	remaining: 18.2s
# 530:	learn: 0.6181498	total: 20.5s	remaining: 18.1s
# 531:	learn: 0.6181073	total: 20.6s	remaining: 18.1s
# 532:	learn: 0.6180476	total: 20.6s	remaining: 18s
# 533:	learn: 0.6180042	total: 20.6s	remaining: 18s
# 534:	learn: 0.6179525	total: 20.6s	remaining: 17.9s
# 535:	learn: 0.6179159	total: 20.7s	remaining: 17.9s
# 536:	learn: 0.6178584	total: 20.7s	remaining: 17.8s
# 537:	learn: 0.6178069	total: 20.7s	remaining: 17.8s
# 538:	learn: 0.6177491	total: 20.7s	remaining: 17.7s
# 539:	learn: 0.6176998	total: 20.8s	remaining: 17.7s
# 540:	learn: 0.6176694	total: 20.8s	remaining: 17.6s
# 541:	learn: 0.6176266	total: 20.8s	remaining: 17.6s
# 542:	learn: 0.6175837	total: 20.9s	remaining: 17.6s
# 543:	learn: 0.6175519	total: 20.9s	remaining: 17.5s
# 544:	learn: 0.6174761	total: 20.9s	remaining: 17.5s
# 545:	learn: 0.6174159	total: 21s	remaining: 17.4s
# 546:	learn: 0.6173733	total: 21s	remaining: 17.4s
# 547:	learn: 0.6173129	total: 21s	remaining: 17.3s
# 548:	learn: 0.6172560	total: 21s	remaining: 17.3s
# 549:	learn: 0.6172246	total: 21.1s	remaining: 17.2s
# 550:	learn: 0.6171924	total: 21.1s	remaining: 17.2s
# 551:	learn: 0.6171365	total: 21.1s	remaining: 17.1s
# 552:	learn: 0.6170929	total: 21.2s	remaining: 17.1s
# 553:	learn: 0.6170399	total: 21.2s	remaining: 17.1s
# 554:	learn: 0.6169867	total: 21.2s	remaining: 17s
# 555:	learn: 0.6169530	total: 21.3s	remaining: 17s
# 556:	learn: 0.6169064	total: 21.3s	remaining: 16.9s
# 557:	learn: 0.6168546	total: 21.3s	remaining: 16.9s
# 558:	learn: 0.6168089	total: 21.3s	remaining: 16.8s
# 559:	learn: 0.6167449	total: 21.4s	remaining: 16.8s
# 560:	learn: 0.6166876	total: 21.4s	remaining: 16.7s
# 561:	learn: 0.6166475	total: 21.4s	remaining: 16.7s
# 562:	learn: 0.6166181	total: 21.5s	remaining: 16.7s
# 563:	learn: 0.6165593	total: 21.5s	remaining: 16.6s
# 564:	learn: 0.6165064	total: 21.5s	remaining: 16.6s
# 565:	learn: 0.6164766	total: 21.5s	remaining: 16.5s
# 566:	learn: 0.6164450	total: 21.6s	remaining: 16.5s
# 567:	learn: 0.6163843	total: 21.6s	remaining: 16.4s
# 568:	learn: 0.6163378	total: 21.6s	remaining: 16.4s
# 663:	learn: 0.6117743	total: 25.1s	remaining: 12.7s
# 664:	learn: 0.6117205	total: 25.2s	remaining: 12.7s
# 665:	learn: 0.6116679	total: 25.2s	remaining: 12.7s
# 666:	learn: 0.6116331	total: 25.3s	remaining: 12.6s
# 667:	learn: 0.6115862	total: 25.3s	remaining: 12.6s
# 668:	learn: 0.6115362	total: 25.4s	remaining: 12.5s
# 669:	learn: 0.6114892	total: 25.4s	remaining: 12.5s
# 670:	learn: 0.6114483	total: 25.4s	remaining: 12.5s
# 671:	learn: 0.6114010	total: 25.5s	remaining: 12.4s
# 672:	learn: 0.6113469	total: 25.5s	remaining: 12.4s
# 673:	learn: 0.6112971	total: 25.5s	remaining: 12.4s
# 674:	learn: 0.6112531	total: 25.6s	remaining: 12.3s
# 675:	learn: 0.6111986	total: 25.6s	remaining: 12.3s
# 676:	learn: 0.6111514	total: 25.7s	remaining: 12.2s
# 677:	learn: 0.6111262	total: 25.7s	remaining: 12.2s
# 678:	learn: 0.6110831	total: 25.7s	remaining: 12.2s
# 679:	learn: 0.6110243	total: 25.8s	remaining: 12.1s
# 680:	learn: 0.6109916	total: 25.8s	remaining: 12.1s
# 681:	learn: 0.6109554	total: 25.9s	remaining: 12.1s
# 682:	learn: 0.6109066	total: 25.9s	remaining: 12s
# 683:	learn: 0.6108618	total: 26s	remaining: 12s
# 684:	learn: 0.6108244	total: 26s	remaining: 12s
# 685:	learn: 0.6107788	total: 26s	remaining: 11.9s
# 686:	learn: 0.6107220	total: 26.1s	remaining: 11.9s
# 687:	learn: 0.6106718	total: 26.1s	remaining: 11.8s
# 688:	learn: 0.6106269	total: 26.2s	remaining: 11.8s
# 689:	learn: 0.6105983	total: 26.2s	remaining: 11.8s
# 690:	learn: 0.6105622	total: 26.3s	remaining: 11.7s
# 691:	learn: 0.6105099	total: 26.3s	remaining: 11.7s
# 692:	learn: 0.6104654	total: 26.4s	remaining: 11.7s
# 693:	learn: 0.6104054	total: 26.4s	remaining: 11.6s
# 694:	learn: 0.6103787	total: 26.5s	remaining: 11.6s
# 695:	learn: 0.6103437	total: 26.5s	remaining: 11.6s
# 696:	learn: 0.6103159	total: 26.5s	remaining: 11.5s
# 697:	learn: 0.6102772	total: 26.6s	remaining: 11.5s
# 698:	learn: 0.6102224	total: 26.6s	remaining: 11.5s
# 699:	learn: 0.6101888	total: 26.7s	remaining: 11.4s
# 700:	learn: 0.6101480	total: 26.7s	remaining: 11.4s
# 701:	learn: 0.6101069	total: 26.7s	remaining: 11.4s
# 702:	learn: 0.6100502	total: 26.8s	remaining: 11.3s
# 703:	learn: 0.6100082	total: 26.8s	remaining: 11.3s
# 704:	learn: 0.6099694	total: 26.9s	remaining: 11.2s
# 705:	learn: 0.6099283	total: 26.9s	remaining: 11.2s
# 706:	learn: 0.6098792	total: 27s	remaining: 11.2s
# 707:	learn: 0.6098468	total: 27s	remaining: 11.1s
# 708:	learn: 0.6097999	total: 27.1s	remaining: 11.1s
# 709:	learn: 0.6097626	total: 27.1s	remaining: 11.1s
# 757:	learn: 0.6077012	total: 28.3s	remaining: 9.05s
# 758:	learn: 0.6076504	total: 28.4s	remaining: 9.01s
# 759:	learn: 0.6076041	total: 28.4s	remaining: 8.97s
# 760:	learn: 0.6075672	total: 28.4s	remaining: 8.93s
# 761:	learn: 0.6075124	total: 28.5s	remaining: 8.89s
# 762:	learn: 0.6074572	total: 28.5s	remaining: 8.85s
# 763:	learn: 0.6074204	total: 28.5s	remaining: 8.81s
# 764:	learn: 0.6073777	total: 28.5s	remaining: 8.77s
# 765:	learn: 0.6073374	total: 28.6s	remaining: 8.72s
# 766:	learn: 0.6073101	total: 28.6s	remaining: 8.68s
# 767:	learn: 0.6072772	total: 28.6s	remaining: 8.65s
# 768:	learn: 0.6072365	total: 28.7s	remaining: 8.61s
# 769:	learn: 0.6071922	total: 28.7s	remaining: 8.57s
# 770:	learn: 0.6071477	total: 28.7s	remaining: 8.53s
# 771:	learn: 0.6071222	total: 28.8s	remaining: 8.49s
# 772:	learn: 0.6070781	total: 28.8s	remaining: 8.45s
# 773:	learn: 0.6070319	total: 28.8s	remaining: 8.41s
# 774:	learn: 0.6069978	total: 28.8s	remaining: 8.37s
# 775:	learn: 0.6069586	total: 28.9s	remaining: 8.33s
# 776:	learn: 0.6069247	total: 28.9s	remaining: 8.29s
# 777:	learn: 0.6068731	total: 28.9s	remaining: 8.25s
# 778:	learn: 0.6068304	total: 28.9s	remaining: 8.21s
# 779:	learn: 0.6068061	total: 29s	remaining: 8.17s
# 780:	learn: 0.6067779	total: 29s	remaining: 8.13s
# 781:	learn: 0.6067368	total: 29s	remaining: 8.09s
# 782:	learn: 0.6066972	total: 29s	remaining: 8.05s
# 783:	learn: 0.6066541	total: 29.1s	remaining: 8.01s
# 784:	learn: 0.6066098	total: 29.1s	remaining: 7.97s
# 785:	learn: 0.6065722	total: 29.1s	remaining: 7.93s
# 786:	learn: 0.6065294	total: 29.2s	remaining: 7.9s
# 787:	learn: 0.6064929	total: 29.2s	remaining: 7.87s
# 788:	learn: 0.6064669	total: 29.3s	remaining: 7.83s
# 789:	learn: 0.6064207	total: 29.3s	remaining: 7.79s
# 790:	learn: 0.6063721	total: 29.3s	remaining: 7.75s
# 791:	learn: 0.6063253	total: 29.4s	remaining: 7.71s
# 792:	learn: 0.6062910	total: 29.4s	remaining: 7.67s
# 793:	learn: 0.6062718	total: 29.4s	remaining: 7.63s
# 794:	learn: 0.6062419	total: 29.4s	remaining: 7.59s
# 795:	learn: 0.6062126	total: 29.5s	remaining: 7.55s
# 796:	learn: 0.6061749	total: 29.5s	remaining: 7.52s
# 797:	learn: 0.6061355	total: 29.6s	remaining: 7.48s
# 798:	learn: 0.6061014	total: 29.6s	remaining: 7.44s
# 799:	learn: 0.6060505	total: 29.6s	remaining: 7.4s
# 800:	learn: 0.6060283	total: 29.6s	remaining: 7.37s
# 801:	learn: 0.6059868	total: 29.7s	remaining: 7.33s
# 802:	learn: 0.6059559	total: 29.7s	remaining: 7.29s
# 803:	learn: 0.6059008	total: 29.8s	remaining: 7.26s
# 804:	learn: 0.6058641	total: 29.8s	remaining: 7.22s
# 805:	learn: 0.6058210	total: 29.9s	remaining: 7.18s
# 806:	learn: 0.6057870	total: 29.9s	remaining: 7.15s
# 807:	learn: 0.6057517	total: 29.9s	remaining: 7.12s
# 808:	learn: 0.6057117	total: 30s	remaining: 7.08s
# 809:	learn: 0.6056642	total: 30s	remaining: 7.04s
# 810:	learn: 0.6056113	total: 30.1s	remaining: 7.01s
# 811:	learn: 0.6055741	total: 30.1s	remaining: 6.97s
# 812:	learn: 0.6055364	total: 30.1s	remaining: 6.93s
# 813:	learn: 0.6055042	total: 30.2s	remaining: 6.9s
# 814:	learn: 0.6054596	total: 30.2s	remaining: 6.86s
# 815:	learn: 0.6054319	total: 30.3s	remaining: 6.83s
# 816:	learn: 0.6053922	total: 30.3s	remaining: 6.79s
# 817:	learn: 0.6053477	total: 30.4s	remaining: 6.75s
# 818:	learn: 0.6053123	total: 30.4s	remaining: 6.72s
# 819:	learn: 0.6052769	total: 30.4s	remaining: 6.68s
# 820:	learn: 0.6052564	total: 30.5s	remaining: 6.65s
# 821:	learn: 0.6052213	total: 30.5s	remaining: 6.61s
# 822:	learn: 0.6051974	total: 30.6s	remaining: 6.58s
# 823:	learn: 0.6051521	total: 30.6s	remaining: 6.54s
# 824:	learn: 0.6051193	total: 30.7s	remaining: 6.5s
# 825:	learn: 0.6050897	total: 30.7s	remaining: 6.47s
# 826:	learn: 0.6050458	total: 30.8s	remaining: 6.43s
# 827:	learn: 0.6050116	total: 30.8s	remaining: 6.4s
# 828:	learn: 0.6049887	total: 30.8s	remaining: 6.36s
# 829:	learn: 0.6049372	total: 30.9s	remaining: 6.33s
# 830:	learn: 0.6049081	total: 30.9s	remaining: 6.29s
# 831:	learn: 0.6048557	total: 31s	remaining: 6.26s
# 832:	learn: 0.6048136	total: 31s	remaining: 6.22s
# 833:	learn: 0.6047657	total: 31.1s	remaining: 6.19s
# 834:	learn: 0.6047404	total: 31.1s	remaining: 6.15s
# 835:	learn: 0.6047141	total: 31.2s	remaining: 6.11s
# 836:	learn: 0.6046651	total: 31.2s	remaining: 6.08s
# 837:	learn: 0.6046174	total: 31.3s	remaining: 6.04s
# 838:	learn: 0.6045841	total: 31.3s	remaining: 6s
# 839:	learn: 0.6045446	total: 31.3s	remaining: 5.97s
# 840:	learn: 0.6045000	total: 31.4s	remaining: 5.93s
# 841:	learn: 0.6044691	total: 31.4s	remaining: 5.9s
# 842:	learn: 0.6044380	total: 31.5s	remaining: 5.86s
# 843:	learn: 0.6043958	total: 31.5s	remaining: 5.82s
# 844:	learn: 0.6043556	total: 31.6s	remaining: 5.79s
# 845:	learn: 0.6043252	total: 31.6s	remaining: 5.75s
# 846:	learn: 0.6042709	total: 31.6s	remaining: 5.71s
# 847:	learn: 0.6042424	total: 31.7s	remaining: 5.68s
# 848:	learn: 0.6042084	total: 31.7s	remaining: 5.64s
# 849:	learn: 0.6041649	total: 31.8s	remaining: 5.61s
# 850:	learn: 0.6041400	total: 31.8s	remaining: 5.57s
# 992:	learn: 0.5987670	total: 37.2s	remaining: 262ms
# 993:	learn: 0.5987308	total: 37.2s	remaining: 224ms
# 994:	learn: 0.5987008	total: 37.2s	remaining: 187ms
# 995:	learn: 0.5986742	total: 37.2s	remaining: 150ms
# 996:	learn: 0.5986297	total: 37.3s	remaining: 112ms
# 997:	learn: 0.5985915	total: 37.3s	remaining: 74.7ms
# 998:	learn: 0.5985684	total: 37.3s	remaining: 37.4ms
# 999:	learn: 0.5985318	total: 37.4s	remaining: 0us

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

def roc_auc_plot(y_true, y_proba, label=' ', l='-', lw=1.0, auc=None, color='blue'):
    fpr, tpr, _ = roc_curve(y_true, y_proba)
    plt.plot(fpr, tpr, linestyle=l, linewidth=lw, label="%s (AUC = %.2f)" % (label, auc), color=color)

# Individual AUC values for each algorithm
auc_svm = 0.64
auc_lr = 0.60
auc_gnb = 0.60  # AUC for GNB
auc_dtree = 0.67
auc_ranfor = 0.76
auc_xgb = 0.66
auc_knn = 0.62
auc_adaboost = 0.62
auc_ffn = 0.64
auc_catboost = 0.66

# Plot ROC curve
plt.figure(figsize=(12, 8))

roc_auc_plot(y_test_resampled, svm_model.predict_proba(X_test_resampled.values)[:, 1], label='SVM', l='-', lw=2.0, auc=auc_svm, color='red')  # Red line for SVM
roc_auc_plot(y_test_resampled, logit_model.predict_proba(X_test_resampled.values)[:, 1], label='Logistic regression', l='-', lw=2.0, auc=auc_lr, color='blue')  # Blue line for LR
roc_auc_plot(y_test_resampled, gnb_model.predict_proba(X_test_resampled.values)[:, 1], label='GNB', l='-', lw=2.0, auc=auc_gnb, color='green')  # Green line for GNB
roc_auc_plot(y_test_resampled, dtree_model.predict_proba(X_test_resampled.values)[:, 1], label='Decision tree ', l='-', lw=2.0, auc=auc_dtree, color='purple')  # Purple line for DT
roc_auc_plot(y_test_resampled, ranfor_model.predict_proba(X_test_resampled.values)[:, 1], label='Random forest', l='-', lw=2.0, auc=auc_ranfor, color='orange')  # Orange line for RF
roc_auc_plot(y_test_resampled, xgb_model.predict_proba(X_test_resampled.values)[:, 1], label='eXGBoost', l='-', lw=2.0, auc=auc_xgb, color='cyan')  # Cyan line for XGB
roc_auc_plot(y_test_resampled, knn_model.predict_proba(X_test_resampled.values)[:, 1], label='KNN', l='-', lw=2.0, auc=auc_knn, color='magenta')  # Magenta line for KNN
roc_auc_plot(y_test_resampled, adaboost_model.predict_proba(X_test_resampled.values)[:, 1], label='AdaBoost', l='-', lw=2.0, auc=auc_adaboost, color='brown')  # Brown line for AdaBoost
roc_auc_plot(y_test_resampled, fnn_model.predict(X_test_resampled_std), label='FFNN', l='--', lw=2.0, auc=auc_ffn, color='black')  # Black dotted line for FFNN
roc_auc_plot(y_test_resampled, catboost_model.predict_proba(X_test_resampled.values)[:, 1], label='CatBoost', l='-', lw=2.0, auc=auc_catboost, color='gray')  # Gray line for CatBoost

plt.plot([0, 1], [0, 1], color='k', linewidth=0.5, linestyle='--')
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operator Characteristic curves')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.show()
# Out:
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
